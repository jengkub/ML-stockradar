# %%
# Raw Package
import numpy as np
import pandas as pd
from datetime import timedelta, datetime
#Data Source
import yfinance as yf

#Data viz
import plotly.graph_objs as go

import datetime as _dt
import sqlite3

from selenium import webdriver
from selenium.webdriver.common.by import By 

from bs4 import BeautifulSoup
import requests

# %%
msft = yf.Ticker("AOT.BK")
hist = msft.history(period="5y", interval="1wk")
hist.index.time == _dt.time(0)
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %%
# Raw Package
import numpy as np
import pandas as pd

#Data Source
import yfinance as yf

#Data viz
import plotly.graph_objs as go
import sqlite3

conn = sqlite3.connect("test.sqlite")
cur = conn.cursor()
ticker = 'AOT.BK'
query = "select * from stock_table where `ticker` == '%s'" % ticker
r_df = pd.read_sql(query,conn)
#declare figure
fig = go.Figure()

#Candlestick
fig.add_trace(go.Candlestick(x=r_df.Datetime,
                open=r_df.Open,
                high=r_df.High,
                low=r_df.Low,
                close=r_df.Close, name = 'market data'))

# Add titles
fig.update_layout(
    title='AOT live share price evolution',
    yaxis_title='Stock Price (THB per Shares)')

# X-Axes
fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=15, label="15m", step="minute", stepmode="backward"),
            dict(count=45, label="45m", step="minute", stepmode="backward"),
            dict(count=1, label="HTD", step="hour", stepmode="todate"),
            dict(count=3, label="3h", step="hour", stepmode="backward"),
            dict(step="all")
        ])
    )
)

#Show
fig.show()

# %% [markdown]
# CSV

# %%
import csv

# open the file in the write mode
f = open('data.csv', 'a')

# create the csv writer
writer = csv.writer(f)

# write a row to the csv file
writer.writerow([Ticker])
f.close()
data.to_csv("data.csv",mode='a')

# %%
#clear csv file
f = open('data.csv', 'w')

# create the csv writer
writer = csv.writer(f)

# write a row to the csv file
writer.writerow('')

# close the file
f.close()

# %%
#test ระบบ
import csv

# open the file in the write mode
with open('data.csv', 'a') as f:
    # create the csv writer
    writer = csv.writer(f)

    # write a row to the csv file
    writer.writerow([Ticker])

data.to_csv("data.csv",mode='a')

# %%
import csv
with open("test.csv",'r') as file:
    reader = csv.reader(file)
    for row in reader:
        if row[7] == 'GC=F':
            print(row)

# %%
import csv
import datetime
#read csv
with open("test.csv",'r') as file:
    reader = csv.reader(file)
    for row in reader:
        if row[7] == 'NKE':
            last = row
#update
x = datetime.datetime.now()
count = 0
DayM = 0
DayMo365 = {'1':31,'2':28,'3':31,'4':30,'5':31,'6':30,'7':31,'8':31,'9':30,'10':31,'11':30,'12':31}
DayMo366 = {'1':31,'2':29,'3':31,'4':30,'5':31,'6':30,'7':31,'8':31,'9':30,'10':31,'11':30,'12':31}
LastDate = last[0].split()[0].split('-')
print(LastDate)
DiffMo = int(x.month) - int(LastDate[1])
DiffYe = int(x.year) - int(LastDate[0])
if DiffYe == 0:
    if DiffMo == 0:
        DiffDay = int(x.day) - int(LastDate[2])
        if DiffDay != 0:
            DiffDay = str(DiffDay) + 'd'
            data = yf.download(tickers='NKE', period=DiffDay, interval='1h')
    elif DiffMo != 0 :
        for u in range(DiffMo):
            DayM = DayM + DayMo365[str(int(LastDate[1])+count)]
            count += 1
        DiffDay = DayM - int(LastDate[2]) + int(x.day)
        DiffDay = str(DiffDay) + 'd'
        data = yf.download(tickers='NKE', period=DiffDay, interval='1h')
elif DiffYe != 0:
    dayly = 0
    dayn = 0
    for j in range(1,int(LastDate[1])):
        dayly = dayly + DayMo365[str(j)]
    for i in range(1,int(x.month)):
        dayn = dayn + DayMo365[str(i)]
    DiffDay = (365*DiffYe) - dayly + dayn - int(LastDate[2]) + int(x.day)
    DiffDay = str(DiffDay) + 'd'
    data = yf.download(tickers='NKE', period=DiffDay, interval='1h')

for i in data.index.day:
    if data.index.year[count] == int(LastDate[0]):
        if data.index.month[count] == int(LastDate[1]):
            if i == int(LastDate[2])+1:
                break
    count += 1

data['ticker'] = 'NKE'
data = data.iloc[count:,:]
data
data.to_csv('test.csv',mode='a',header=False)
# Out:
# ['2022', '09', '12']
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ดึงหุ้น 100 ตัว

# %%
#save 100 stock
from selenium import webdriver
from selenium.webdriver.common.by import By 

stock = []
 
op = webdriver.ChromeOptions()
op.add_argument('headless') 
driver = webdriver.Chrome(options=op) 
driver.get("https://www.set.or.th/th/market/index/set100/overview")

elements = driver.find_elements(By.XPATH, "//div[@class='symbol pt-1']")
for element in elements:
    stock.append(element.text)

driver.quit()

print(stock)
# Out:
# ['AAV', 'ACE', 'ADVANC', 'AMATA', 'AOT', 'AP', 'AWC', 'BAM', 'BANPU', 'BBL', 'BCH', 'BCP', 'BCPG', 'BDMS', 'BEC', 'BEM', 'BGRIM', 'BH', 'BLA', 'BTS', 'BYD', 'CBG', 'CENTEL', 'CHG', 'CK', 'CKP', 'COM7', 'CPALL', 'CPF', 'CPN', 'CRC', 'DELTA', 'DOHOME', 'DTAC', 'EA', 'EGCO', 'EPG', 'ESSO', 'FORTH', 'GLOBAL', 'GPSC', 'GULF', 'GUNKUL', 'HANA', 'HMPRO', 'INTUCH', 'IRPC', 'IVL', 'JAS', 'JMART', 'JMT', 'KBANK', 'KCE', 'KEX', 'KKP', 'KTB', 'KTC', 'LH', 'MEGA', 'MINT', 'MTC', 'NEX', 'ONEE', 'OR', 'ORI', 'OSP', 'PLANB', 'PSL', 'PTG', 'PTT', 'PTTEP', 'PTTGC', 'QH', 'RATCH', 'RBF', 'RCL', 'SABUY', 'SAWAD', 'SCB', 'SCC', 'SCGP', 'SINGER', 'SPALI', 'SPRC', 'STA', 'STARK', 'STGT', 'TCAP', 'THANI', 'THG', 'TIDLOR', 'TIPH', 'TISCO', 'TOP', 'TQM', 'TRUE', 'TTB', 'TU', 'VGI', 'WHA']

# %%
import pandas as pd
from yahoo_fin import stock_info as si
df2 = pd.DataFrame( si.tickers_nasdaq() )
sym2 = set( symbol for symbol in df2[0].values.tolist() )
len(sym2)
# Out:
# 5434

# %%
import yfinance as yf

msft = yf.Ticker("MSFT")

# get stock info
msft.news
# Out:
# [{'uuid': '046099a2-0491-36dc-a954-04b44c4f9102',
#   'title': 'Alphabet Versus ChatGPT. Who Wins?',
#   'publisher': 'TipRanks',
#   'link': 'https://finance.yahoo.com/news/alphabet-versus-chatgpt-wins-173939411.html',
#   'providerPublishTime': 1676050779,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/4FzKAKjrM4p2ulgEiPpmWw--~B/aD02NjU7dz0xMDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/tipranks_452/4bb03c6967c9ecfb7731a0ee06862c47',
#      'width': 1000,
#      'height': 665,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/2It6uSDgDrkDtmZ9mdpl.A--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/tipranks_452/4bb03c6967c9ecfb7731a0ee06862c47',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['GOOGL', 'MSFT']},
#  {'uuid': 'e49fa276-06fb-4383-a9f7-2aa7e76abe16',
#   'title': 'What it’s like to use Microsoft’s AI-powered Bing',
#   'publisher': 'Yahoo Finance',
#   'link': 'https://finance.yahoo.com/news/what-its-like-to-use-microsofts-ai-powered-bing-172634489.html',
#   'providerPublishTime': 1676049994,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/KOfyJrMYvwz7yAqGd8a5hQ--~B/aD0yMzYyO3c9MzU0MzthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2023-01/39c79ef0-a968-11ed-9f57-5a120bbe52a8',
#      'width': 3543,
#      'height': 2362,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/qdRDfETkJFKyWXo2Q65ADQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://s.yimg.com/os/creatr-uploaded-images/2023-01/39c79ef0-a968-11ed-9f57-5a120bbe52a8',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MSFT', 'GOOG', 'GOOGL']},
#  {'uuid': 'd8ac37ab-5f53-37f9-a491-44739bf07a67',
#   'title': 'Big Tech Is Great, Until Your Phone Is Swiped in Brazil',
#   'publisher': 'TheStreet.com',
#   'link': 'https://finance.yahoo.com/m/d8ac37ab-5f53-37f9-a491-44739bf07a67/big-tech-is-great%2C-until-your.html',
#   'providerPublishTime': 1676049480,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/
',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MSFT', 'GOOG', 'GOOGL']}]

# %%
print(msft.history)
# Out:
# <bound method TickerBase.history of yfinance.Ticker object <MSFT>>

# %%
SET100 = list()
for i in range(len(stock)):
    SET100.append(stock[i]+'.BK')
print(SET100)
# Out:
# ['AAV.BK', 'ACE.BK', 'ADVANC.BK', 'AMATA.BK', 'AOT.BK', 'AP.BK', 'AWC.BK', 'BAM.BK', 'BANPU.BK', 'BBL.BK', 'BCH.BK', 'BCP.BK', 'BCPG.BK', 'BDMS.BK', 'BEC.BK', 'BEM.BK', 'BGRIM.BK', 'BH.BK', 'BLA.BK', 'BTS.BK', 'BYD.BK', 'CBG.BK', 'CENTEL.BK', 'CHG.BK', 'CK.BK', 'CKP.BK', 'COM7.BK', 'CPALL.BK', 'CPF.BK', 'CPN.BK', 'CRC.BK', 'DELTA.BK', 'DOHOME.BK', 'DTAC.BK', 'EA.BK', 'EGCO.BK', 'EPG.BK', 'ESSO.BK', 'FORTH.BK', 'GLOBAL.BK', 'GPSC.BK', 'GULF.BK', 'GUNKUL.BK', 'HANA.BK', 'HMPRO.BK', 'INTUCH.BK', 'IRPC.BK', 'IVL.BK', 'JAS.BK', 'JMART.BK', 'JMT.BK', 'KBANK.BK', 'KCE.BK', 'KEX.BK', 'KKP.BK', 'KTB.BK', 'KTC.BK', 'LH.BK', 'MEGA.BK', 'MINT.BK', 'MTC.BK', 'NEX.BK', 'ONEE.BK', 'OR.BK', 'ORI.BK', 'OSP.BK', 'PLANB.BK', 'PSL.BK', 'PTG.BK', 'PTT.BK', 'PTTEP.BK', 'PTTGC.BK', 'QH.BK', 'RATCH.BK', 'RBF.BK', 'RCL.BK', 'SABUY.BK', 'SAWAD.BK', 'SCB.BK', 'SCC.BK', 'SCGP.BK', 'SINGER.BK', 'SPALI.BK', 'SPRC.BK', 'STA.BK', 'STARK.BK', 'STGT.BK', 'TCAP.BK', 'THANI.BK', 'THG.BK', 'TIDLOR.BK', 'TIPH.BK', 'TISCO.BK', 'TOP.BK', 'TQM.BK', 'TRUE.BK', 'TTB.BK', 'TU.BK', 'VGI.BK', 'WHA.BK']

# %%
from bs4 import BeautifulSoup
import requests

stockgroup = []
substockgroup = []

for i in stock:
    url = requests.get("https://www.settrade.com/th/equities/quote/"+i+"/company-profile/profile")
    soup = BeautifulSoup(url.content, "html.parser")
    data = soup.find_all("div",{"class":"fs-14px text-middle-gray m-0"})
    stockgroup.append(data[5].text)
    substockgroup.append(data[6].text)

# %%
stockgroup = [x.replace('\n', '').replace(' ','') for x in stockgroup if x is not None]
substockgroup = [x.replace('\n', '').replace(' ','') for x in substockgroup if x is not None]

print(stockgroup)
print(substockgroup)
len(stockgroup)
# Out:
# ['บริการ', 'ทรัพยากร', 'เทคโนโลยี', 'อสังหาริมทรัพย์และก่อสร้าง', 'บริการ', 'อสังหาริมทรัพย์และก่อสร้าง', 'อสังหาริมทรัพย์และก่อสร้าง', 'ธุรกิจการเงิน', 'ทรัพยากร', 'ธุรกิจการเงิน', 'บริการ', 'ทรัพยากร', 'ทรัพยากร', 'บริการ', 'บริการ', 'บริการ', 'ทรัพยากร', 'บริการ', 'ธุรกิจการเงิน', 'บริการ', 'ธุรกิจการเงิน', 'เกษตรและอุตสาหกรรมอาหาร', 'บริการ', 'บริการ', 'อสังหาริมทรัพย์และก่อสร้าง', 'ทรัพยากร', 
 'พลังงานและสาธารณูปโภค', 'พลังงานและสาธารณูปโภค', 'พลังงานและสาธารณูปโภค', 'ปิโตรเคมีและเคมีภัณฑ์', 'พัฒนาอสังหาริมทรัพย์', 'พลังงานและสาธารณูปโภค', 'อาหารและเครื่องดื่ม', 'ขนส่งและโลจิสติกส์', 'พาณิชย์', 'เงินทุนและหลักทรัพย์', 'ธนาคาร', 'วัสดุก่อสร้าง', 'บรรจุภัณฑ์', 'พาณิชย์', 'พัฒนาอสังหาริมทรัพย์', 'พลังงานและสาธารณูปโภค', 'ธุรกิจการเกษตร', 'วัสดุอุตสาหกรรมและเครื่องจักร', 'ของใช้ส่วนตัวและเวชภัณฑ์', 'ธนาคาร', 'เงินทุนและหลักทรัพย์', 'การแพทย์', 'เงินทุนและหลักทรัพย์', 'ประกันภัยและประกันชีวิต', 'ธนาคาร', 'พลังงานและสาธารณูปโภค', 'ประกันภัยและประกันชีวิต', 'เทคโนโลยีสารสนเทศและการสื่อสาร', 'ธนาคาร', 'อาหารและเครื่องดื่ม', 'สื่อและสิ่งพิมพ์', 'พัฒนาอสังหาริมทรัพย์']
# 100

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By 

head= []
finacetype = []
finace = []
string = []
 
op = webdriver.ChromeOptions()
op.add_argument('headless') 
driver = webdriver.Chrome(options=op) 
driver.get("https://www.settrade.com/th/equities/quote/AAV/financial-statement/five-years")

elements = driver.find_elements(By.XPATH, "//table/thead/tr/th/div")
for element in elements:
    head.append(element.text)

elements = driver.find_elements(By.XPATH, "//table/tbody/tr/th")
for element in elements:
    finacetype.append(element.text)

elements = driver.find_elements(By.XPATH, "//table/tbody/tr/td[@class='column-sticky']")
for element in elements:
    finace.append(element.text)

elements = driver.find_elements(By.XPATH, "//table/tbody/tr/td/div/div")
for element in elements:
    string.append(element.text)

driver.quit()

# %%
print (head)
annual = []

for i in head:
    a = i.split("\n")
    i = " ".join(a)
    annual.append(a[1])
print(annual)

year1 = []
date1 = []
month = {"ม.ค.":"01", "ก.พ.":"02", "มี.ค.":"03", "เม.ย.":"04", "พ.ค.":"05", "มิ.ย.":"06", "ก.ค.":"07", "ส.ค.":"08", "ก.ย.":"09", "ต.ค.":"10", "พ.ย.":"11", "ธ.ค.":"12"}
for i in annual:
    a = i.split(" ")
    a[2] = str(int(a[2])-543)
    year1.append(a[2])
    a[1] = month[a[1]]
    if len(a[0]) == 1 :
        a[0] = str(0)+a[0]
    a.reverse()
    i = "-".join(a)
    date1.append(i)
    

print(year1)
print(date1)

# print (finacetype)
# print (finace)
# print (string)
# Out:
# ['YE/62\n31 ธ.ค. 2562', 'YE/63\n31 ธ.ค. 2563', 'YE/64\n31 ธ.ค. 2564', '9M/65\n30 ก.ย. 2565']
# ['31 ธ.ค. 2562', '31 ธ.ค. 2563', '31 ธ.ค. 2564', '30 ก.ย. 2565']
# ['2019', '2020', '2021', '2022']
# ['2019-12-31', '2020-12-31', '2021-12-31', '2022-09-30']

# %%
dic1 = {}
dic2 = {}
lista = string[len(head)*14:]
column2 = 0
where = 14
n = 0
month = {"ม.ค.":"01", "ก.พ.":"02", "มี.ค.":"03", "เม.ย.":"04", "พ.ค.":"05", "มิ.ย.":"06", "ก.ค.":"07", "ส.ค.":"08", "ก.ย.":"09", "ต.ค.":"10", "พ.ย.":"11", "ธ.ค.":"12"}
date2 = []
date3 = []
year2 = []

for i in lista:
    try:
        if i == '-':
            dic2.setdefault(finace[where], []).append(None)
        else:
            a = i.split(",")
            i = "".join(a)
            i = float(i)
            dic2.setdefault(finace[where], []).append(i)
        n += 1
        if n % column2 == 0:
            where += 1
    except ValueError :
        n += 1
        column2 = n
        date2.append(i)  
    except ZeroDivisionError:
        pass

for i in date2:
    a = i.split(" ")
    a[2] = str(int(a[2])-543)
    year2.append(a[2])
    a[1] = month[a[1]]
    if len(a[0]) == 1 :
        a[0] = str(0)+a[0]
    a.reverse()
    i = "-".join(a)
    date3.append(i)

print(date2)
print(dic2)
print(year2)
# Out:
# ['30 ธ.ค. 2562', '30 ธ.ค. 2563', '30 ธ.ค. 2564', '30 ธ.ค. 2565', '13 ม.ค. 2566']
# {'ราคาล่าสุด (บาท)': [2.24, 2.36, 2.54, 3.06, 3.02], 'มูลค่าหลักทรัพย์ตามราคาตลาด (ล้านบาท)': [10864.0, 11446.0, 25091.57, 37222.71, 36736.14], 'มูลค่าทางบัญชีต่อหุ้น (บาท)': [4.12, 3.11, 1.71, 0.45, 0.45], 'P/E (เท่า)': [None, None, None, None, None], 'P/BV (เท่า)': [0.54, 0.76, 3.11, 6.81, 6.72], 'อัตราส่วนเงินปันผลตอบแทน (%)': [14.96, None, None, None, None]}
# ['2019', '2020', '2021', '2022', '2023']

# %%
def check(list1, list2):
    result = 0
    for i in list1:
        if i == list2[0]:
            break
        else:
            result+=1
    return result

print(check(['2019', '2020', '2021', '2022'],['2019', '2020', '2021', '2022','2023']))
# Out:
# 0

# %%
column1 = len(head)
row = 14
number = column1*row
where = 0
n = 0
for i in string:
    if i == '-':
        dic1.setdefault(finace[where], []).append(None)
    else:
        a = i.split(",")
        i = "".join(a)
        i = float(i)
        dic1.setdefault(finace[where], []).append(i)
    n += 1
    if n % column1 == 0:
        if len(year1) != len(year2):
            dic1.setdefault(finace[where], []).append(None)
        elif len(year1) == len(year2) and year1[0] != year2[0]:
            dic1.setdefault(finace[where], []).append(None)
        where += 1
    if n == number:
        break

print(dic1)
# Out:
# {'สินทรัพย์รวม (ล้านบาท)': [62902.56, 67977.67, 71208.33, 66670.81, None], 'หนี้สินรวม (ล้านบาท)': [35214.09, 50617.36, 54379.53, 61956.02, None], 'ส่วนผู้ถือหุ้น (ล้านบาท)': [19943.88, 14266.11, 20201.1, 4714.79, None], 'ทุนที่ออกและชำระแล้ว (ล้านบาท)': [485.0, 485.0, 987.86, 1173.57, None], 'รายได้รวม (ล้านบาท)': [41202.63, 16260.96, 4558.62, 9525.39, None], 'รายได้จากการดำเนินงาน (ล้านบาท)': [40180.65, 13633.87, 3828.47, 9289.43, None], 'รวมต้นทุนและค่าใช้จ่าย (ล้านบาท)': [41653.13, 23788.08, 16358.82, 22260.29, None], 'กำไรก่อนต้นทุนทางการเงินและภาษี (ล้านบาท)': [-100.03, -7527.12, -11800.2, -12734.9, None], 'กำไรสุทธิ (ล้านบาท)': [-474.0, -4764.09, -6647.49, -11144.39, None], 'กำไร (บาท / หุ้น)': [-0.1, -0.98, -1.3, -0.97, None], 'ROA (%)': [-0.16, -11.5, -16.96, -22.62, None], 'ROE (%)': [-2.35, -27.85, -38.57, -180.36, None], 'อัตรากำไรสุทธิ (%)': [-2.1, -53.3, -262.32, -118.93, None], 'อัตราส่วนหนี้สินต่อส่วนของผู้ถือหุ้น (เท่า)': [1.27, 2.92, 3.23, 13.14, None]}

# %%
key1 = list(dic1.keys())
value1 = list(dic1.values())
key2 = list(dic2.keys())
value2 = list(dic2.values())
print(key1)
print(value1)
print()
print(key2)
print(value2)
print()
print(len(date1))
print(len(date3))

year = set(year1 + year2)
year = list(year)
year.sort()
print(year)
# Out:
# ['สินทรัพย์รวม (ล้านบาท)', 'หนี้สินรวม (ล้านบาท)', 'ส่วนผู้ถือหุ้น (ล้านบาท)', 'ทุนที่ออกและชำระแล้ว (ล้านบาท)', 'รายได้รวม (ล้านบาท)', 'รายได้จากการดำเนินงาน (ล้านบาท)', 'รวมต้นทุนและค่าใช้จ่าย (ล้านบาท)', 'กำไรก่อนต้นทุนทางการเงินและภาษี (ล้านบาท)', 'กำไรสุทธิ (ล้านบาท)', 'กำไร (บาท / หุ้น)', 'ROA (%)', 'ROE (%)', 'อัตรากำไรสุทธิ (%)', 'อัตราส่วนหนี้สินต่อส่วนของผู้ถือหุ้น (เท่า)']
# [[62902.56, 67977.67, 71208.33, 66670.81, None], [35214.09, 50617.36, 54379.53, 61956.02, None], [19943.88, 14266.11, 20201.1, 4714.79, None], [485.0, 485.0, 987.86, 1173.57, None], [41202.63, 16260.96, 4558.62, 9525.39, None], [40180.65, 13633.87, 3828.47, 9289.43, None], [41653.13, 23788.08, 16358.82, 22260.29, None], [-100.03, -7527.12, -11800.2, -12734.9, None], [-474.0, -4764.09, -6647.49, -11144.39, None], [-0.1, -0.98, -1.3, -0.97, None], [-0.16, -11.5, -16.96, -22.62, None], [-2.35, -27.85, -38.57, -180.36, None], [-2.1, -53.3, -262.32, -118.93, None], [1.27, 2.92, 3.23, 13.14, None]]
#
# ['ราคาล่าสุด (บาท)', 'มูลค่าหลักทรัพย์ตามราคาตลาด (ล้านบาท)', 'มูลค่าทางบัญชีต่อหุ้น (บาท)', 'P/E (เท่า)', 'P/BV (เท่า)', 'อัตราส่วนเงินปันผลตอบแทน (%)']
# [[2.24, 2.36, 2.54, 3.06, 3.02], [10864.0, 11446.0, 25091.57, 37222.71, 36736.14], [4.12, 3.11, 1.71, 0.45, 0.45], [None, None, None, None, None], [0.54, 0.76, 3.11, 6.81, 6.72], [14.96, None, None, None, None]]
#
# 4
# 5
# ['2019', '2020', '2021', '2022', '2023']

# %%
def check(list1, list2):
    result = 0
    for i in list1:
        if i == list2[0]:
            break
        else:
            result+=1
    return result

print(check(year1,year2))
# Out:
# 0

# %%
def check(list1, list2):
    result = 0
    for i in list1:
        if i == list2[0]:
            break
        else:
            result+=1
    return result

con = sqlite3.connect("stock.sqlite")

cur = con.cursor()
if year1[0] == year2[0]:
    print('a')
    for i in range(len(year)):
        if i != len(year)-1:
            cur.execute("INSERT INTO stock_financial VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)",("AAV", date1[i], value1[0][i], value1[1][i], value1[2][i], value1[3][i], value1[4][i], value1[5][i], value1[6][i], value1[7][i], value1[8][i], value1[9][i], value1[10][i], value1[11][i], value1[12][i], value1[13][i], date3[i], value2[0][i], value2[1][i], value2[2][i], value2[3][i], value2[4][i], value2[5][i], year[i],))
        else:
            cur.execute("INSERT INTO stock_financial VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)",("AAV", None, value1[0][i], value1[1][i], value1[2][i], value1[3][i], value1[4][i], value1[5][i], value1[6][i], value1[7][i], value1[8][i], value1[9][i], value1[10][i], value1[11][i], value1[12][i], value1[13][i], date3[i], value2[0][i], value2[1][i], value2[2][i], value2[3][i], value2[4][i], value2[5][i], year[i],))
    print('f')
else:
    dif = check(year1,year2)
    j = check(year1,year2)
    for i in range(len(year)):
        if i != len(year)-1 and dif <= 0:
            print(i)
            cur.execute("INSERT INTO stock_financial VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)",("AAV", date1[i], value1[0][i], value1[1][i], value1[2][i], value1[3][i], value1[4][i], value1[5][i], value1[6][i], value1[7][i], value1[8][i], value1[9][i], value1[10][i], value1[11][i], value1[12][i], value1[13][i], date3[i-j], value2[0][i-j], value2[1][i-j], value2[2][i-j], value2[3][i-j], value2[4][i-j], value2[5][i-j], year[i],))
        elif dif > 0:
            print('a')
            cur.execute("INSERT INTO stock_financial VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)",("AAV", date1[i], value1[0][i], value1[1][i], value1[2][i], value1[3][i], value1[4][i], value1[5][i], value1[6][i], value1[7][i], value1[8][i], value1[9][i], value1[10][i], value1[11][i], value1[12][i], value1[13][i], date3[i], None, None, None, None, None, None, year[i],))
        else:
            cur.execute("INSERT INTO stock_financial VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)",("AAV", None, value1[0][i], value1[1][i], value1[2][i], value1[3][i], value1[4][i], value1[5][i], value1[6][i], value1[7][i], value1[8][i], value1[9][i], value1[10][i], value1[11][i], value1[12][i], value1[13][i], date3[i-j], value2[0][i-j], value2[1][i-j], value2[2][i-j], value2[3][i-j], value2[4][i-j], value2[5][i-j], year[i],))
        dif -= 1
    print('s')
con.commit()
# Out:
# a
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[326], line 19
#      17             cur.execute("INSERT INTO stock_financial VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)",("AAV", date1[i], value1[0][i], value1[1][i], value1[2][i], value1[3][i], value1[4][i], value1[5][i], value1[6][i], value1[7][i], value1[8][i], value1[9][i], value1[10][i], value1[11][i], value1[12][i], value1[13][i], date3[i], value2[0][i], value2[1][i], value2[2][i], value2[3][i], value2[4][i], value2[5][i], year[i],))
#      18         else:
# ---> 19             cur.execute("INSERT INTO stock_financial VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)",("AAV", None, value1[0][i], value1[1][i], value1[2][i], value1[3][i], value1[4][i], value1[5][i], value1[6][i], value1[7][i], value1[8][i], value1[9][i], value1[10][i], value1[11][i], value1[12][i], value1[13][i], date3[i], value2[0][i], value2[1][i], value2[2][i], value2[3][i], value2[4][i], value2[5][i], year[i],))
#      20     print('f')
#      21 else:
#
# IndexError: list index out of range

# %%
def check(list1, list2):
    result = 0
    for i in list1:
        if i == list2[0]:
            break
        else:
            result+=1
    return result

con = sqlite3.connect("stock.sqlite")

cur = con.cursor()
if year1[0] == year2[0]:
    print('a')
    for i in range(len(year)):
        if i != len(year)-1:
            cur.execute("INSERT INTO stock_financial VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)",("AAV", date1[i], value1[0][i], value1[1][i], value1[2][i], value1[3][i], value1[4][i], value1[5][i], value1[6][i], value1[7][i], value1[8][i], value1[9][i], value1[10][i], value1[11][i], value1[12][i], value1[13][i], date3[i], value2[0][i], value2[1][i], value2[2][i], value2[3][i], value2[4][i], value2[5][i], year[i],))
        else:
            cur.execute("INSERT INTO stock_financial VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)",("AAV", None, value1[0][i], value1[1][i], value1[2][i], value1[3][i], value1[4][i], value1[5][i], value1[6][i], value1[7][i], value1[8][i], value1[9][i], value1[10][i], value1[11][i], value1[12][i], value1[13][i], date3[i], value2[0][i], value2[1][i], value2[2][i], value2[3][i], value2[4][i], value2[5][i], year[i],))
    print('f')
else:
    dif = check(year1,year2)
    j = check(year1,year2)
    for i in range(len(year)):
        if i != len(year)-1 and dif <= 0:
            print(i)
            print("AAV", date1[i], value1[0][i], value1[1][i], value1[2][i], value1[3][i], value1[4][i], value1[5][i], value1[6][i], value1[7][i], value1[8][i], value1[9][i], value1[10][i], value1[11][i], value1[12][i], value1[13][i], date3[i-j], value2[0][i-j], value2[1][i-j], value2[2][i-j], value2[3][i-j], value2[4][i-j], value2[5][i-j], year[i],)
        elif dif > 0:
            print('a')
            print("AAV", date1[i], value1[0][i], value1[1][i], value1[2][i], value1[3][i], value1[4][i], value1[5][i], value1[6][i], value1[7][i], value1[8][i], value1[9][i], value1[10][i], value1[11][i], value1[12][i], value1[13][i], date3[i], None, None, None, None, None, None, year[i],)
        elif i == len(year)-1 and dif <= 0:
            print("AAV", None, value1[0][i], value1[1][i], value1[2][i], value1[3][i], value1[4][i], value1[5][i], value1[6][i], value1[7][i], value1[8][i], value1[9][i], value1[10][i], value1[11][i], value1[12][i], value1[13][i], date3[i-j], value2[0][i-j], value2[1][i-j], value2[2][i-j], value2[3][i-j], value2[4][i-j], value2[5][i-j], year[i],)
        dif -= 1
    print('s')
con.commit()
# Out:
# a
# AAV 2020-12-31 7480.91 5376.03 2104.68 3810.0 3216.12 3126.78 2461.33 759.46 633.86 16.64 10.15 30.12 19.71 2.55 2021-12-30 None None None None None None 2020
# 1
# AAV 2021-12-31 9305.45 2459.95 6845.34 4762.5 5438.12 5346.79 4344.13 1094.09 828.38 0.42 13.04 18.51 15.23 0.36 2021-12-30 10.8 25717.5 None 29.13 None None 2021
# 2
# AAV 2022-09-30 9294.95 2306.15 6988.62 4762.5 4780.54 4689.11 4020.4 761.31 593.32 0.25 11.8 16.45 12.41 0.33 2022-12-30 7.95 18930.94 2.93 23.7 2.71 0.87 2022
# AAV None None None None None None None None None None None None None None None 2023-01-06 7.7 18335.63 2.93 22.96 2.62 0.9 2023
# s

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By 

for j, k in zip(stock, SET100):
    head= []
    finacetype = []
    finace = []
    string = []
    
    op = webdriver.ChromeOptions()
    op.add_argument('headless') 
    driver = webdriver.Chrome(options=op) 
    driver.get("https://www.settrade.com/th/equities/quote/"+j+"/financial-statement/five-years")

    elements = driver.find_elements(By.XPATH, "//table/thead/tr/th/div")
    for element in elements:
        head.append(element.text)

    elements = driver.find_elements(By.XPATH, "//table/tbody/tr/th")
    for element in elements:
        finacetype.append(element.text)

    elements = driver.find_elements(By.XPATH, "//table/tbody/tr/td[@class='column-sticky']")
    for element in elements:
        finace.append(element.text)

    elements = driver.find_elements(By.XPATH, "//table/tbody/tr/td/div/div")
    for element in elements:
        string.append(element.text)

    annual = []

    for i in head:
        a = i.split("\n")
        i = " ".join(a)
        annual.append(a[1])

    year1 = []
    date1 = []
    month = {"ม.ค.":"01", "ก.พ.":"02", "มี.ค.":"03", "เม.ย.":"04", "พ.ค.":"05", "มิ.ย.":"06", "ก.ค.":"07", "ส.ค.":"08", "ก.ย.":"09", "ต.ค.":"10", "พ.ย.":"11", "ธ.ค.":"12"}
    for i in annual:
        a = i.split(" ")
        a[2] = str(int(a[2])-543)
        year1.append(a[2])
        a[1] = month[a[1]]
        if len(a[0]) == 1 :
            a[0] = str(0)+a[0]
        a.reverse()
        i = "-".join(a)
        date1.append(i)

    dic1 = {}
    dic2 = {}
    lista = string[len(head)*14:]
    column2 = 0
    where = 14
    n = 0
    month = {"ม.ค.":"01", "ก.พ.":"02", "มี.ค.":"03", "เม.ย.":"04", "พ.ค.":"05", "มิ.ย.":"06", "ก.ค.":"07", "ส.ค.":"08", "ก.ย.":"09", "ต.ค.":"10", "พ.ย.":"11", "ธ.ค.":"12"}
    date2 = []
    date3 = []
    year2 = []

    for i in lista:
        try:
            if i == '-':
                dic2.setdefault(finace[where], []).append(None)
            else:
                a = i.split(",")
                i = "".join(a)
                i = float(i)
                dic2.setdefault(finace[where], []).append(i)
            n += 1
            if n % column2 == 0:
                where += 1
        except ValueError :
            n += 1
            column2 = n
            date2.append(i)  
        except ZeroDivisionError:
            pass

    for i in date2:
        a = i.split(" ")
        a[2] = str(int(a[2])-543)
        year2.append(a[2])
        a[1] = month[a[1]]
        if len(a[0]) == 1 :
            a[0] = str(0)+a[0]
        a.reverse()
        i = "-".join(a)
        date3.append(i)

    column1 = len(head)
    row = 14
    number = column1*row
    where = 0
    n = 0
    for i in string:
        if i == '-':
            dic1.setdefault(finace[where], []).append(None)
        else:
            a = i.split(",")
            i = "".join(a)
            i = float(i)
            dic1.setdefault(finace[where], []).append(i)
        n += 1
        if n % column1 == 0:
            if len(year1) != len(year2):
                dic1.setdefault(finace[where], []).append(None)
            elif len(year1) == len(year2) and year1[0] != year2[0]:
                dic1.setdefault(finace[where], []).append(None)
            where += 1
        if n == number:
            break

    print(j)
    print(year1)
    print(year2)
    key1 = list(dic1.keys())
    value1 = list(dic1.values())
    key2 = list(dic2.keys())
    value2 = list(dic2.values())
    
    year = set(year1 + year2)
    year = list(year)
    year.sort()

    def check(list1, list2):
        result = 0
        for i in list1:
            if i == list2[0]:
                break
            else:
                result+=1
        return result

    con = sqlite3.connect("stock.sqlite")

    cur = con.cursor()
    if year1[0] == year2[0]:
        for i in range(len(year)):
            if i != len(year)-1:
                cur.execute("INSERT INTO stock_financial VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)",(k, date1[i], value1[0][i], value1[1][i], value1[2][i], value1[3][i], value1[4][i], value1[5][i], value1[6][i], value1[7][i], value1[8][i], value1[9][i], value1[10][i], value1[11][i], value1[12][i], value1[13][i], date3[i], value2[0][i], value2[1][i], value2[2][i], value2[3][i], value2[4][i], value2[5][i], year[i],))
            else:
                cur.execute("INSERT INTO stock_financial VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)",(k, None, value1[0][i], value1[1][i], value1[2][i], value1[3][i], value1[4][i], value1[5][i], value1[6][i], value1[7][i], value1[8][i], value1[9][i], value1[10][i], value1[11][i], value1[12][i], value1[13][i], date3[i], value2[0][i], value2[1][i], value2[2][i], value2[3][i], value2[4][i], value2[5][i], year[i],))
    else:
        dif = check(year1,year2)
        j = check(year1,year2)
        for i in range(len(year)):
            if i != len(year)-1 and dif <= 0:
                cur.execute("INSERT INTO stock_financial VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)",(k, date1[i], value1[0][i], value1[1][i], value1[2][i], value1[3][i], value1[4][i], value1[5][i], value1[6][i], value1[7][i], value1[8][i], value1[9][i], value1[10][i], value1[11][i], value1[12][i], value1[13][i], date3[i-j], value2[0][i-j], value2[1][i-j], value2[2][i-j], value2[3][i-j], value2[4][i-j], value2[5][i-j], year[i],))
            elif dif > 0:
                cur.execute("INSERT INTO stock_financial VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)",(k, date1[i], value1[0][i], value1[1][i], value1[2][i], value1[3][i], value1[4][i], value1[5][i], value1[6][i], value1[7][i], value1[8][i], value1[9][i], value1[10][i], value1[11][i], value1[12][i], value1[13][i], None, None, None, None, None, None, None, year[i],))
            else:
                cur.execute("INSERT INTO stock_financial VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)",(k, None, value1[0][i], value1[1][i], value1[2][i], value1[3][i], value1[4][i], value1[5][i], value1[6][i], value1[7][i], value1[8][i], value1[9][i], value1[10][i], value1[11][i], value1[12][i], value1[13][i], date3[i-j], value2[0][i-j], value2[1][i-j], value2[2][i-j], value2[3][i-j], value2[4][i-j], value2[5][i-j], year[i],))
            dif -= 1
   
    con.commit()
# Out:
# AAV
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# ACE
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# ADVANC
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# AMATA
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# AOT
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# AP
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# AWC
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# BAM
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# BANPU
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# BBL
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# BCH
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# BCP
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# BCPG
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# BDMS
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# BEC
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# BEM
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# BGRIM
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# BH
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# BLA
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# BTS
# ['2019', '2020', '2021', '2022', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# BYD
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# CBG
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# CENTEL
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# CHG
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# CK
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# CKP
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# COM7
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# CPALL
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# CPF
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# CPN
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# CRC
# ['2019', '2020', '2021', '2022']
# ['2020', '2021', '2022', '2023']
# DELTA
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# DOHOME
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# DTAC
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# EA
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# EGCO
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# EPG
# ['2019', '2020', '2021', '2022', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# ESSO
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# FORTH
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# GLOBAL
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# GPSC
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# GULF
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# GUNKUL
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# HANA
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# HMPRO
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# INTUCH
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# IRPC
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# IVL
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# JAS
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# JMART
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# JMT
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# KBANK
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# KCE
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# KEX
# ['2019', '2020', '2021', '2022']
# ['2020', '2021', '2022', '2023']
# KKP
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# KTB
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# KTC
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# LH
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# MEGA
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# MINT
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# MTC
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# NEX
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# ONEE
# ['2020', '2021', '2022']
# ['2021', '2022', '2023']
# OR
# ['2019', '2020', '2021', '2022']
# ['2021', '2022', '2023']
# ORI
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# OSP
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# PLANB
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# PSL
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# PTG
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# PTT
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# PTTEP
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# PTTGC
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# QH
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# RATCH
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# RBF
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# RCL
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# SABUY
# ['2019', '2020', '2021', '2022']
# ['2020', '2021', '2022', '2023']
# SAWAD
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# SCB
# ['2022']
# ['2022', '2023']
# SCC
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# SCGP
# ['2019', '2020', '2021', '2022']
# ['2020', '2021', '2022', '2023']
# SINGER
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# SPALI
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# SPRC
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# STA
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# STARK
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# STGT
# ['2019', '2020', '2021', '2022']
# ['2020', '2021', '2022', '2023']
# TCAP
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# THANI
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# THG
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# TIDLOR
# ['2020', '2021', '2022']
# ['2021', '2022', '2023']
# TIPH
# ['2021', '2022']
# ['2021', '2022', '2023']
# TISCO
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# TOP
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# TQM
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# TRUE
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# TTB
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# TU
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# VGI
# ['2019', '2020', '2021', '2022', '2022']
# ['2019', '2020', '2021', '2022', '2023']
# WHA
# ['2019', '2020', '2021', '2022']
# ['2019', '2020', '2021', '2022', '2023']

# %% [markdown]
# แบ่งหมวดหมู่กลุ่มอุตสาหกรรม

# %%
con = sqlite3.connect("stock.sqlite")

cur = con.cursor()
for i, j, k in zip(SET100, stockgroup, substockgroup):
    cur.execute("INSERT INTO stock_info VALUES (? ,? ,?)",(i, j, k,))
con.commit()

# %%
con = sqlite3.connect("stock.sqlite")

cur = con.cursor()
r_df = pd.read_sql("select * from stock_info",con)                    
print(r_df)
# Out:
#        Ticker              Industry Group                          Sector
# 0      AAV.BK                      บริการ              ขนส่งและโลจิสติกส์
# 1      ACE.BK                    ทรัพยากร           พลังงานและสาธารณูปโภค
# 2   ADVANC.BK                   เทคโนโลยี  เทคโนโลยีสารสนเทศและการสื่อสาร
# 3    AMATA.BK  อสังหาริมทรัพย์และก่อสร้าง            พัฒนาอสังหาริมทรัพย์
# 4      AOT.BK                      บริการ              ขนส่งและโลจิสติกส์
# ..        ...                         ...                             ...
# 95    TRUE.BK                   เทคโนโลยี  เทคโนโลยีสารสนเทศและการสื่อสาร
# 96     TTB.BK               ธุรกิจการเงิน                          ธนาคาร
# 97      TU.BK     เกษตรและอุตสาหกรรมอาหาร             อาหารและเครื่องดื่ม
# 98     VGI.BK                      บริการ                สื่อและสิ่งพิมพ์
# 99     WHA.BK  อสังหาริมทรัพย์และก่อสร้าง            พัฒนาอสังหาริมทรัพย์
#
# [100 rows x 3 columns]

# %% [markdown]
# Update database

# %%
import sqlite3
import datetime
conn = sqlite3.connect("stock.sqlite")
cur = conn.cursor()
ticker = 'AOT.BK'
query = "select * from stock_table where `Ticker` == '%s'" % ticker
r_df = pd.read_sql(query,conn)
last = r_df.tail(1).Datetime.to_string().split()
LastDate = last[1].split()[0].split('-')
print(LastDate)
x = datetime.datetime.now()
count = 0
DayM = 0
down = 0
DayMo365 = {'1':31,'2':28,'3':31,'4':30,'5':31,'6':30,'7':31,'8':31,'9':30,'10':31,'11':30,'12':31}
DiffMo = int(x.month) - int(LastDate[1])
DiffYe = int(x.year) - int(LastDate[0])
if DiffYe == 0:
    if DiffMo == 0:
        DiffDay = int(x.day) - int(LastDate[2])
        if DiffDay != 0:
            pass
    elif DiffMo != 0 :
        for u in range(DiffMo):
            DayM = DayM + DayMo365[str(int(LastDate[1])+count)]
            count += 1
        DiffDay = DayM - int(LastDate[2]) + int(x.day)
elif DiffYe != 0:
    dayly = 0
    dayn = 0
    for j in range(1,int(LastDate[1])):
        dayly = dayly + DayMo365[str(j)]
    for i in range(1,int(x.month)):
        dayn = dayn + DayMo365[str(i)]
    DiffDay = (365*DiffYe) - dayly + dayn - int(LastDate[2]) + int(x.day)
    
DiffDay = str(DiffDay) + 'd'
data = yf.download(tickers=ticker, period=DiffDay, interval='1h')
print(DiffDay)
for i in data.index.day:
    if data.index.year[count] == int(LastDate[0]):
        if data.index.month[count] == int(LastDate[1]):
            if i == int(LastDate[2])+1:
                break
    count += 1

ok = r_df.tail(1).Datetime.to_string().split()[2]
if ok == '10:00:00':
    down = 5
elif ok == '11:00:00':
    down = 4
elif ok == '12:00:00':
    down = 3
elif ok == '14:00:00':
    down = 2
elif ok == '15:00:00':
    down = 1
elif ok == '16:00:00':
    down = 0

count = count - down
data['ticker'] = ticker
data = data.iloc[count:,:]
print(data)
data.to_sql('stock_table',con=conn,if_exists='append',index=True)
cur.close()
# Out:
# ['2023', '01', '06']
# [*********************100%***********************]  1 of 1 completed
# 1d
#                      Open  High    Low  Close  Adj Close   Volume  ticker
# Datetime
# 2023-01-06 16:00:00  75.5  75.5  75.25   75.5       75.5  2117220  AOT.BK

# %%
data = yf.download(tickers='MSFT', period='max', interval='1m')
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Datetime
# 2023-02-03 13:53:00-05:00  259.070007  259.170013  258.959991  259.140015
# 2023-02-03 13:54:00-05:00  259.109985  259.154999  258.959991  258.980011
# 2023-02-03 13:55:00-05:00  258.980011  259.160004  258.885010  258.894989
# 2023-02-03 13:56:00-05:00  258.910004  259.200012  258.910004  259.029999
# 2023-02-03 13:57:00-05:00  259.010010  259.089996  258.949005  259.009888
# ...                               ...         ...         ...         ...
# 2023-02-10 13:47:00-05:00  261.875000  262.010010  261.875000  262.000000
# 2023-02-10 13:48:00-05:00  261.970001  262.144989  261.970001  262.089996
# 2023-02-10 13:49:00-05:00  262.079987  262.174988  262.043701  262.149994
# 2023-02-10 13:50:00-05:00  262.140015  262.190002  262.029999  262.160004
# 2023-02-10 13:51:00-05:00  262.149994  262.149994  262.010010  262.019989
#
#                             Adj Close  Volume
# Datetime
# 2023-02-03 13:53:00-05:00  259.140015       0
# 2023-02-03 13:54:00-05:00  258.980011   56935
# 2023-02-03 13:55:00-05:00  258.894989   45367
# 2023-02-03 13:56:00-05:00  259.029999   42661
# 2023-02-03 13:57:00-05:00  259.009888   28873
# ...                               ...     ...
# 2023-02-10 13:47:00-05:00  262.000000   14396
# 2023-02-10 13:48:00-05:00  262.089996   19596
# 2023-02-10 13:49:00-05:00  262.149994   16411
# 2023-02-10 13:50:00-05:00  262.160004   22662
# 2023-02-10 13:51:00-05:00  262.019989   18316
#
# [1948 rows x 6 columns]

# %% [markdown]
# Create new table

# %%
import sqlite3

# Create a SQL connection to our SQLite database
con = sqlite3.connect("stock.sqlite")

cur = con.cursor()
cur.execute("CREATE TABLE stock_info (Ticker VARCHAR(255) PRIMARY KEY, [Industry Group] VARCHAR(255), Sector VARCHAR(255));")
con.commit()

# %%
import sqlite3

# Create a SQL connection to our SQLite database
con = sqlite3.connect("stock.sqlite")

cur = con.cursor()
cur.execute("CREATE TABLE stock_table_mo (Datetime DATETIME, Open real, High real, Low real, Close real, Adj Close real, Volume integer, Ticker VARCHAR(255), FOREIGN KEY(Ticker) REFERENCES stock_info(Ticker));")
con.commit()

# %%
import sqlite3

# Create a SQL connection to our SQLite database
con = sqlite3.connect("stock.sqlite")

cur = con.cursor()
cur.execute("CREATE TABLE stock_news (Datetime DATETIME, Title VARCHAR(500), Link VARCHAR(500), Body VARCHAR(20000), Ticker VARCHAR(255), FOREIGN KEY(Ticker) REFERENCES stock_info(Ticker));")
con.commit()

# %%
import sqlite3

# Create a SQL connection to our SQLite database
con = sqlite3.connect("stock.sqlite")

cur = con.cursor()
cur.execute("CREATE TABLE stock_financial (Ticker VARCHAR(255), [Financial Period] DATETIME, [Total Assets] real, [Total Liabilities] real, Equity real, [Issued and paid-up share capital] real, [Gross Profit] real, [Operating Revenue] real, [Total Costs and Expenses] real, [Profit Before Finance Costs and Income Tax Expenses] real, [Net Profit] real, [Profit] real, [ROA] real, [ROE] real, [Net Profit Margin] real, [Debt to Equity Ratio] real, [Important Stats] DATETIME, [Last Price] real, [Market Capitalization] real, [Book Value Per Share] real, [P/E] real, [P/BV] real, [Dividend Yield] real, Year CHAR(20), FOREIGN KEY(Ticker) REFERENCES stock_info(Ticker));")
con.commit()

# %% [markdown]
# Insert database

# %%
con = sqlite3.connect("stock.sqlite")

df_list = list()
cur = con.cursor()
for ticker in SET100:
    data = yf.download(tickers=ticker, period='max', interval='1mo',progress=False)
    for d in range(len(data.index)):
        date_format = '%Y-%m-%d %H:%M:%S'
        date_obj = datetime.strptime(str(data.index[d]), date_format)
        cur.execute("INSERT INTO stock_table_mo (Datetime, Open, High, Low, Close, Adj, Volume, Ticker) VALUES (? ,? ,? ,? ,? ,? ,? ,? )",(date_obj, data.Open[d], data.High[d], data.Low[d], data.Close[d], data['Adj Close'][d], int(data.Volume[d]), ticker,))
con.commit()

# %%
conn = sqlite3.connect("stock.sqlite")
cur = conn.cursor()
r_df = pd.read_sql("SELECT stock_table.Open, stock_info.Sector FROM stock_table INNER JOIN stock_info ON stock_table.Ticker = stock_info.Ticker;",conn)
print(r_df)
# Out:
#          Open                Sector
# 0        2.52    ขนส่งและโลจิสติกส์
# 1        2.52    ขนส่งและโลจิสติกส์
# 2        2.52    ขนส่งและโลจิสติกส์
# 3        2.50    ขนส่งและโลจิสติกส์
# 4        2.52    ขนส่งและโลจิสติกส์
# ...       ...                   ...
# 283139   4.02  พัฒนาอสังหาริมทรัพย์
# 283140   4.04  พัฒนาอสังหาริมทรัพย์
# 283141   4.08  พัฒนาอสังหาริมทรัพย์
# 283142   4.06  พัฒนาอสังหาริมทรัพย์
# 283143  75.50    ขนส่งและโลจิสติกส์
#
# [283144 rows x 2 columns]

# %%
import sqlite3

# Create a SQL connection to our SQLite database
con = sqlite3.connect("stock.sqlite")

cur = con.cursor()
cur.execute("CREATE TABLE time (Datetime DATETIME );")
con.commit()

# %%
import sqlite3

# Create a SQL connection to our SQLite database
con = sqlite3.connect("stock.sqlite")

cur = con.cursor()
cur.execute("DROP TABLE stock_financial;")
con.commit()

# %%
conn = sqlite3.connect("stock.sqlite")
cur = conn.cursor()
r_df = pd.read_sql("SELECT Datetime FROM stock_table WHERE Datetime > '2023-01-06 00:00:00' and ticker = 'AOT.BK';",conn)
print(r_df.Datetime[0])
# Out:
# 2023-01-06 10:00:00

# %%
date_format = '%Y-%m-%d %H:%M:%S'
date_obj = datetime.strptime('2023-01-06 10:00:00', date_format)
time = date_obj.strftime("%H:%M:%S")
print(time)
# Out:
# 10:00:00

# %%
conn = sqlite3.connect("stock.sqlite")
cur = conn.cursor()
r_df = pd.read_sql("SELECT * FROM stock_table_hr;",conn)
print(r_df)
# Out:
#                    Datetime   Open   High    Low  Close  Adj Close    Volume  \
# 0       2021-01-07 10:00:00   2.52   2.54   2.50   2.50       2.50         0
# 1       2021-01-07 11:00:00   2.52   2.52   2.50   2.50       2.50   1410000
# 2       2021-01-07 12:00:00   2.52   2.52   2.50   2.52       2.52   1260500
# 3       2021-01-07 14:00:00   2.50   2.52   2.50   2.50       2.50   1681000
# 4       2021-01-07 15:00:00   2.52   2.52   2.48   2.50       2.50   1821800
# ...                     ...    ...    ...    ...    ...        ...       ...
# 283139  2023-01-06 12:00:00   4.02   4.06   4.02   4.04       4.04   7454130
# 283140  2023-01-06 14:00:00   4.04   4.08   4.04   4.08       4.08   8064758
# 283141  2023-01-06 15:00:00   4.08   4.08   4.04   4.06       4.06  16710135
# 283142  2023-01-06 16:00:00   4.06   4.08   4.04   4.06       4.06  12858025
# 283143  2023-01-06 16:00:00  75.50  75.50  75.25  75.50      75.50   2117220
#
#         Ticker
# 0       AAV.BK
# 1       AAV.BK
# 2       AAV.BK
# 3       AAV.BK
# 4       AAV.BK
# ...        ...
# 283139  WHA.BK
# 283140  WHA.BK
# 283141  WHA.BK
# 283142  WHA.BK
# 283143  AOT.BK
#
# [283144 rows x 8 columns]

# %%
# Create a SQL connection to our SQLite database
con = sqlite3.connect("stock.sqlite")

cur = con.cursor()
cur.execute("ALTER TABLE stock_info DROP COLUMN [Total Assets];")
con.commit()

# %%
import sqlite3
# Create a SQL connection to our SQLite database
con = sqlite3.connect("stock.sqlite")

cur = con.cursor()
cur.execute("UPDATE stock_info SET [Index] = 'SET100';")
con.commit()

# %% [markdown]
# Holiday

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By 

holiday = []
 
op = webdriver.ChromeOptions()
op.add_argument('headless') 
driver = webdriver.Chrome(options=op) 
driver.get("https://www.infoquest.co.th/holidays/year-2566")

elements = driver.find_elements(By.XPATH, "//*[@id='post-235553']/div/div/section/div/div/div/div/div/figure[2]/table/tbody/tr/td[2]")
for element in elements:
    holiday.append(element.text)

driver.quit()

print(holiday)
# Out:
# ['2 มกราคม', '6 มีนาคม', '6 เมษายน', '13 เมษายน', '14 เมษายน', '17 เมษายน', '1 พฤษภาคม', '4 พฤษภาคม', '5 พฤษภาคม', '17 พฤษภาคม', '5 มิถุนายน', '28 กรกฎาคม', '1 สิงหาคม', '2 สิงหาคม', '14 สิงหาคม', '13 ตุลาคม', '23 ตุลาคม', '5 ธันวาคม', '11 ธันวาคม']

# %%
date = []
sadman = {'มกราคม':'01','กุมภาพันธ์':'02','มีนาคม':'03','เมษายน':'04','พฤษภาคม':'05','มิถุนายน':'06','กรกฎาคม':'07','สิงหาคม':'08','กันยายน':'09','ตุลาคม':'10','พฤศจิกายน':'11','ธันวาคม':'12'}
for i in holiday:
    day = i.split()[0]
    if int(day) < 10 :
        day = '0'+day
    mount = i.split()[1]
    num = sadman[mount]
    holidayDate = day + '-' + str(num)
    date.append(holidayDate)
print(date)
# Out:
# ['02-01', '06-03', '06-04', '13-04', '14-04', '17-04', '01-05', '04-05', '05-05', '17-05', '05-06', '28-07', '01-08', '02-08', '14-08', '13-10', '23-10', '05-12', '11-12']

# %%
from tkinter import ttk
import tkinter as tk
import sqlite3

def View():
    con1 = sqlite3.connect("stock.sqlite")
    cur1 = con1.cursor()
    cur1.execute("SELECT [Financial Period], [Total Assets], [Total Liabilities], Equity, [Issued and paid-up share capital], [Gross Profit], [Operating Revenue], [Total Costs and Expenses], [Profit Before Finance Costs and Income Tax Expenses], [Net Profit], [Profit], [ROA], [ROE], [Net Profit Margin], [Debt to Equity Ratio], [Important Stats], [Last Price], [Market Capitalization], [Book Value Per Share], [P/E], [P/BV], [Dividend Yield], Year FROM stock_financial where Ticker='SCB.BK'")

    rows = cur1.fetchall()    
    n = len(rows[0])
    head = []
    listhead = ['Financial Period', 'Total Assets', 'Total Liabilities', 'Equity', 'Issued and paid-up share capital', 'Gross Profit', 'Operating Revenue', 'Total Costs and Expenses', 'Profit Before Finance Costs and Income Tax Expenses', 'Net Profit', 'Profit', 'ROA', 'ROE', 'Net Profit Margin', 'Debt to Equity Ratio', 'Important Stats', 'Last Price', 'Market Capitalization', 'Book Value Per Share', 'P/E', 'P/BV', 'Dividend Yield', 'Year']
    
    
    if n == 5:
            for i in range(n-1):
                tree.insert('', tk.END, values=(listhead[i], rows[0][i], rows[1][i], rows[2][i], rows[3][i], rows[4][i]))        

    if len(rows) == 2:
        for i in range(n-1):
            tree.insert('', tk.END, values=(listhead[i], rows[0][i], rows[1][i], None, None, None))         
            print(i)

    con1.close()


root = tk.Tk()
root.geometry('1920x1080')

tree = ttk.Treeview(root, columns=("Head","2019","2020","2021","2022","2023"), show='headings',height=24)

tree.heading("Head", text="Head")
tree.column("Head", width=300)

tree.heading("2019", text="2019")
tree.column("2019", width=150)

tree.heading("2020", text="2020")
tree.column("2020", width=150)

tree.heading("2021", text="2021")
tree.column("2021", width=150)

tree.heading("2022", text="2022")
tree.column("2022", width=150)

tree.heading("2023", text="2023")
tree.column("2023", width=150)



tree.pack()

button1 = tk.Button(text="Display data", command=View)

button1.pack(pady=10)
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[179], line 58
#      55 button1 = tk.Button(text="Display data", command=View)
#      57 button1.pack(pady=10)
# ---> 58 root.mainloop()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.3568.0_x64__qbz5n2kfra8p0\lib\tkinter\__init__.py:1429, in Misc.mainloop(self, n)
#    1427 def mainloop(self, n=0):
#    1428     """Call the mainloop of Tk."""
# -> 1429     self.tk.mainloop(n)
#
# KeyboardInterrupt:

# %% [markdown]
# GUI งบทางการเงิน

# %%
from tkinter import ttk
import tkinter as tk
import yfinance as yf
import sqlite3
import pandas as pd

root=tk.Tk()
 
# setting the windows size
root.geometry('1920x1080')
  
# declaring string variable
# for storing name and password
Ticker=tk.StringVar()
dl_ticker=tk.StringVar()
  
# defining a function that will
# get the name and password and
# print them on the screen
def submit():
    global Fail_label
    name=Ticker.get()
    name = name.upper()
    conn = sqlite3.connect("stock.sqlite")
    cur = conn.cursor()
    query = "SELECT [Financial Period], [Total Assets], [Total Liabilities], Equity, [Issued and paid-up share capital], [Gross Profit], [Operating Revenue], [Total Costs and Expenses], [Profit Before Finance Costs and Income Tax Expenses], [Net Profit], [Profit], [ROA], [ROE], [Net Profit Margin], [Debt to Equity Ratio], [Important Stats], [Last Price], [Market Capitalization], [Book Value Per Share], [P/E], [P/BV], [Dividend Yield], Year FROM stock_financial where Ticker == '%s'" % name
    try:
        cur.execute(query)
        rows = cur.fetchall()    
        
        listhead = ['Financial Period', 'Total Assets', 'Total Liabilities', 'Equity', 'Issued and paid-up share capital', 'Gross Profit', 'Operating Revenue', 'Total Costs and Expenses', 'Profit Before Finance Costs and Income Tax Expenses', 'Net Profit', 'Profit', 'ROA', 'ROE', 'Net Profit Margin', 'Debt to Equity Ratio', 'Important Stats', 'Last Price', 'Market Capitalization', 'Book Value Per Share', 'P/E', 'P/BV', 'Dividend Yield', 'Year']
        print(rows)
        if not rows:
            try:
                print(2)
                Fail_label = tk.Label(root, text = 'not found on DB you want to dowload?', font=('calibre',10, 'bold'))
                Fail_label.grid(row=5,column=0)
                dl_btn=tk.Button(root,text = 'Dowload', command = DL)
                dl_btn.grid(row=5,column=2)
            except:
                raise NameError
        n = len(rows[0])
        
        if len(rows) == 5:
            for i in range(n-1):
                tree.insert('', tk.END, values=(listhead[i], rows[0][i], rows[1][i], rows[2][i], rows[3][i], rows[4][i]))

        elif len(rows) == 4:
            for i in range(n-1):
                tree.insert('', tk.END, values=(listhead[i], None, rows[0][i], rows[1][i], rows[2][i], rows[3][i]))         

        elif len(rows) == 3:
            for i in range(n-1):
                tree.insert('', tk.END, values=(listhead[i], None, None, rows[0][i], rows[1][i], rows[2][i])) 

        elif len(rows) == 2:
            for i in range(n-1):
                tree.insert('', tk.END, values=(listhead[i], None, None, None, rows[0][i], rows[1][i]))

        elif len(rows) == 1:
            for i in range(n-1):
                tree.insert('', tk.END, values=(listhead[i], None, None, None, None, rows[0][i])) 

        conn.close()
    except :
        # print(1)
        Fail_label = tk.Label(root, textvariable = 'Error not such that ticker', font=('calibre',10, 'bold'))
     
def DL():
    try:
        name=Ticker.get()
        name = name.upper()
        data = yf.download(tickers=name, period='max', interval='1mo')
        if data.empty:
            raise NameError
        else:
            print(data)
    except:
        
        Fail_label = tk.Label(root, textvariable = 'Error not such that ticker', font=('calibre',10, 'bold'))
        Fail_label.grid(row=3,column=0)

def clear_input():
   name_entry.delete(0, 'end')

def clear_table():
   name_entry.delete(0, 'end')
   tree.delete(*tree.get_children())
   Fail_label  = tk.Label(root, text = 'not found on DB you want to dowload?', font=('calibre',10, 'bold'))

# creating a label for
# name using widget Label
name_label = tk.Label(root, text = 'Enter Ticker Here', font=('calibre',10, 'bold'))
  
# creating a entry for input
# name using widget Entry
name_entry = tk.Entry(root,textvariable = Ticker, font=('calibre',10,'normal'))
  
# creating a button using the widget
# Button that will call the submit function
sub_btn=tk.Button(root,text = 'Submit', command=lambda:[submit()])
  
# placing the label and entry in
# the required position using grid
# method
name_label.grid(row=0,column=0)
name_entry.grid(row=0,column=1)
sub_btn.grid(row=2,column=1)

tree = ttk.Treeview(root, columns=("Financial statements","2019","2020","2021","2022","2023"), show='headings',height=24)

tree.heading("Financial statements", text="Financial statements")
tree.column("Financial statements", width=300)

tree.heading("2019", text="2019")
tree.column("2019", width=150)

tree.heading("2020", text="2020")
tree.column("2020", width=150)

tree.heading("2021", text="2021")
tree.column("2021", width=150)

tree.heading("2022", text="2022")
tree.column("2022", width=150)

 5371.62, 13315.33, 5088.0, 5739.67, 5726.92, 4158.32, 1749.31, 1505.68, 0.15, 9.95, 11.9, 26.23, 0.4, '2021-12-30', 3.5, 35616.0, 1.27, 25.58, 2.75, 1.37, '2021'), ('2022-09-30', 19758.94, 5514.6, 14186.55, 5088.0, 5086.59, 5073.45, 3979.21, 1292.32, 1087.95, 0.11, 9.02, 10.73, 21.38, 0.39, '2022-12-30', 2.7, 27475.2, 1.4, 18.75, 1.92, 0.75, '2022'), (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '2023-01-13', 2.68, 27271.68, 1.41, 18.55, 1.9, 0.75, '2023')]
# []
# 2

# %%
import tkinter as tk
from tkinter import ttk
import yfinance as yf
import sqlite3
import pandas as pd

root=tk.Tk()
 
# setting the windows size
root.geometry('1920x1080')
  
# declaring string variable
# for storing name and password
Ticker=tk.StringVar()
dl_ticker=tk.StringVar()
  
# defining a function that will
# get the name and password and
# print them on the screen
def submit():
    name=Ticker.get()
    name = name.upper()
    conn = sqlite3.connect("stock.sqlite")
    cur = conn.cursor()
    query = "SELECT [Financial Period], [Total Assets], [Total Liabilities], Equity, [Issued and paid-up share capital], [Gross Profit], [Operating Revenue], [Total Costs and Expenses], [Profit Before Finance Costs and Income Tax Expenses], [Net Profit], [Profit], [ROA], [ROE], [Net Profit Margin], [Debt to Equity Ratio], [Important Stats], [Last Price], [Market Capitalization], [Book Value Per Share], [P/E], [P/BV], [Dividend Yield], Year FROM stock_financial where Ticker == '%s'" % name
    try:
        cur.execute(query)
        if not rows:
            try:
                notice_label = tk.Label(root, text = 'not found on DB you want to dowlaod?', font=('calibre',10, 'bold'))
                notice_label.grid(row=4,column=0)
                dl_btn=tk.Button(root,text = 'Dowload', command = DL)
                dl_btn.grid(row=2,column=4)
            except:
                raise NameError
        rows = cur.fetchall()    
        n = len(rows[0])
        listhead = ['Financial Period', 'Total Assets', 'Total Liabilities', 'Equity', 'Issued and paid-up share capital', 'Gross Profit', 'Operating Revenue', 'Total Costs and Expenses', 'Profit Before Finance Costs and Income Tax Expenses', 'Net Profit', 'Profit', 'ROA', 'ROE', 'Net Profit Margin', 'Debt to Equity Ratio', 'Important Stats', 'Last Price', 'Market Capitalization', 'Book Value Per Share', 'P/E', 'P/BV', 'Dividend Yield', 'Year']
        print(rows)

        if len(rows) == 5:
            for i in range(n-1):
                tree.insert('', tk.END, values=(listhead[i], rows[0][i], rows[1][i], rows[2][i], rows[3][i], rows[4][i]))

        elif len(rows) == 4:
            for i in range(n-1):
                tree.insert('', tk.END, values=(listhead[i], None, rows[0][i], rows[1][i], rows[2][i], rows[3][i]))         

        elif len(rows) == 3:
            for i in range(n-1):
                tree.insert('', tk.END, values=(listhead[i], None, None, rows[0][i], rows[1][i], rows[2][i])) 

        elif len(rows) == 2:
            for i in range(n-1):
                tree.insert('', tk.END, values=(listhead[i], None, None, None, rows[0][i], rows[1][i]))

        elif len(rows) == 1:
            for i in range(n-1):
                tree.insert('', tk.END, values=(listhead[i], None, None, None, None, rows[0][i]))  
        
        
        else:
            print(r_df)
    except:
        print(1)
        Fail_label = tk.Label(root, text = 'Error not such that ticker', font=('calibre',10, 'bold'))
        Fail_label.grid(row=5,column=0)
     
def DL():
    try:
        name=Ticker.get()
        name = name.upper()
        data = yf.download(tickers=name, period='max', interval='1mo')
        if data.empty:
            raise NameError
        else:
            print(data)
    except:
        Fail_label = tk.Label(root, text = 'Error not such that ticker', font=('calibre',10, 'bold'))
        Fail_label.grid(row=3,column=0)

def clear_input():
   name_entry.delete(0, 'end')

def clear_table():
   name_entry.delete(0, 'end')
   tree.delete(*tree.get_children())

# creating a label for
# name using widget Label
name_label = tk.Label(root, text = 'Enter Ticker Here', font=('calibre',10, 'bold'))
  
# creating a entry for input
# name using widget Entry
name_entry = tk.Entry(root,textvariable = Ticker, font=('calibre',10,'normal'))
  
# creating a button using the widget
# Button that will call the submit function
sub_btn=tk.Button(root,text = 'Submit', command = submit)
  
# placing the label and entry in
# the required position using grid
# method
name_label.grid(row=0,column=0)
name_entry.grid(row=0,column=1)
sub_btn.grid(row=2,column=1)

tree = ttk.Treeview(root, columns=("Head","2019","2020","2021","2022","2023"), show='headings',height=24)

tree.heading("Head", text="Head")
tree.column("Head", width=300)

tree.heading("2019", text="2019")
tree.column("2019", width=150)

tree.heading("2020", text="2020")
tree.column("2020", width=150)

tree.heading("2021", text="2021")
tree.column("2021", width=150)

tree.heading("2022", text="2022")
tree.column("2022", width=150)

tree.heading("2023", text="2023")
tree.column("2023", width=150)

tree.grid(row=3,column=1)

clear_btn=tk.Button(root,text = 'Clear', command=clear_table)
clear_btn.grid(row=4,column=1)
  
# performing an infinite loop
# for the window to display
root.mainloop()
# Out:
# 1

# %% [markdown]
# PyQT

# %%
import sys

from PyQt5.QtWebEngineWidgets import QWebEnginePage
from PyQt5.QtWidgets import QApplication
from PyQt5.QtCore import QUrl
from PyQt5.QtWebEngineWidgets import QWebEngineView

url = 'http://127.0.0.1:8050/'

app = QApplication(sys.argv)

# QWebEngineView
browser = QWebEngineView()
browser.load(QUrl(url))
browser.show()

sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# c:\Users\Best\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3465: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import pandas as pd
from yfinance import info as si
df2 = pd.DataFrame( si.tickers_nasdaq() )
sym2 = set( symbol for symbol in df2[0].values.tolist() )
print(sym2)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 from yfinance import info as si
#       3 df2 = pd.DataFrame( si.tickers_nasdaq() )
#       4 sym2 = set( symbol for symbol in df2[0].values.tolist() )
#
# ImportError: cannot import name 'info' from 'yfinance' (C:\Users\Best\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\yfinance\__init__.py)

# %% [markdown]
# Scraping News

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By 
import sqlite3
from datetime import datetime

# Create a SQL connection to our SQLite database
con = sqlite3.connect("stock.sqlite")
cur = con.cursor()

def link(alink, stock):
    all_link = []

    op = webdriver.ChromeOptions()
    op.add_argument('headless') 
    driver = webdriver.Chrome(options=op) 
    driver.get(alink)
    numlink = driver.find_elements(By.XPATH, '//*[@id="posts-container"]/li')
    if numlink == []:
        return False

    #get all news link in page
    for i in range(len(numlink)):
        link = driver.find_element(By.XPATH, '//*[@id="posts-container"]/li['+ str(i+1) +']/div/h2/a')
        all_link.append(link.get_attribute("href"))

    #scrap news
    for i in all_link:
        try:
            driver.get(i)
            get_url = driver.current_url
            title = driver.find_element(By.XPATH, "//*[@id='the-post']/header/div/h1")
            date = driver.find_element(By.XPATH, '//*[@id="single-post-meta"]/span')
            tag = driver.find_elements(By.XPATH, '//a[@rel="tag"]')

            date = date.text.split("/")
            date.reverse()
            if int(date[0]) < 2019:
                return False
            date = "-".join(date)
            date_format = "%Y-%m-%d"
            date_obj = datetime.strptime(date, date_format)

            
            for ticker in tag: 
                if ticker.text in stock:
                    print(get_url)
                    print(title.text)
                    print(date)   
                    print(ticker.text)
                    cur.execute("INSERT INTO stock_news VALUES (?, ?, ?, ?)",(date_obj, title.text, get_url, ticker.text,))
                    
            print('---------------------------------------------------')
            
        except:
            pass
    con.commit()

def nextpage(alink, ticker):
    num = 1
    op = webdriver.ChromeOptions()
    op.add_argument('headless') 
    # op.add_argument('headless') 
    driver = webdriver.Chrome(options=op) 
    #next page
    driver.get(alink)

    while True:
        num += 1
        run = link('https://www.kaohoon.com/tag/'+ticker+'/page/'+str(num), stock)
        if run == False:
            print('stop')
            break






# driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By 
import sqlite3
from datetime import datetime

# Create a SQL connection to our SQLite database
con = sqlite3.connect("stock.sqlite")
cur = con.cursor()

def link(alink, stock):
    all_link = []
    temp = []
    op = webdriver.ChromeOptions()
    op.add_argument('headless') 
    driver = webdriver.Chrome(options=op) 
    driver.get(alink)
    numlink = driver.find_elements(By.XPATH, '//div[@class="tie-col-md-11 tie-col-sm-10 tie-col-xs-10"]/a')
    if numlink == []:
        return False
    
    for k in numlink:
        all_link.append(k.get_attribute("href"))
    

    #scrap news
    for i in all_link:
        try:
            driver.get(i)
            get_url = driver.current_url
            title = driver.find_element(By.XPATH, "//*[@id='the-post']/header/div/h1")
            date = driver.find_element(By.XPATH, '//*[@id="single-post-meta"]/span')
            tag = driver.find_elements(By.XPATH, '//a[@rel="tag"]')
            body = driver.find_element(By.XPATH, '//*[@id="the-post"]/div[5]')


            date = date.text.split("/")
            date.reverse()
            if int(date[0]) < 2019:
                return False
            date = "-".join(date)
            date_format = "%Y-%m-%d"
            date_obj = datetime.strptime(date, date_format)

            
            for ticker in tag: 
                if ticker.text in stock:
                    query = "SELECT * FROM stock_news WHERE DATETIME = '%s' AND Title = '%s' AND Link = '%s' AND Ticker = '%s'" %(date_obj, title.text, get_url, ticker.text)
                    cur.execute(query)
                    data = cur.fetchall()
                    print(data)
                    if data != []:
                         pass
                    else:
                        print(get_url)
                        print(title.text)
                        print(date_obj)   
                        print(ticker.text)
                        print(body.text)
                        cur.execute("INSERT INTO stock_news VALUES (?, ?, ?, ?, ?)",(date_obj, title.text, get_url, body.text, ticker.text,))
                    
            print('---------------------------------------------------')
            
        except:
            pass
    con.commit()

def nextpage(alink):
    num = 1
    op = webdriver.ChromeOptions()
    op.add_argument('headless') 
    driver = webdriver.Chrome(options=op) 
    #next page
    driver.get(alink)
    case = True

    while case == True:
        num += 1
        run = link('https://www.kaohoon.com/latest-news/page/'+str(num), stock)
        if run == False:
            print('stop')
            return 'Stop'

# %%
work = True
while work == True:
    try:
        link('https://www.kaohoon.com/latest-news', stock)
        re = nextpage('https://www.kaohoon.com/latest-news')
        if re == 'Stop':
            work = False
    except:
        print('Error')
# Out:
# []
# ---------------------------------------------------
# []
# ---------------------------------------------------
# []
# ---------------------------------------------------
# []
# ---------------------------------------------------
# ---------------------------------------------------
# []
# ---------------------------------------------------
# []
# ---------------------------------------------------
# ---------------------------------------------------
# []
# []
# []
# []
# []
# ---------------------------------------------------
# ---------------------------------------------------
# []
# ---------------------------------------------------
# []
# ---------------------------------------------------
# ---------------------------------------------------
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ---------------------------------------------------
# ---------------------------------------------------
# ---------------------------------------------------
# ---------------------------------------------------
# ---------------------------------------------------
# ---------------------------------------------------
# ---------------------------------------------------
# ---------------------------------------------------
# ---------------------------------------------------
# [('2023-02-13 00:00:00', 'GLOBAL โชว์งบปี 65 กำไรพุ่ง 3.48 พันล้าน เคาะปันผลหุ้น-เงินสด XD 24 ก.พ.นี้', 'https://www.kaohoon.com/news/588052', 'GLOBAL')]
# https://www.kaohoon.com/news/588052
# GLOBAL โชว์งบปี 65 กำไรพุ่ง 3.48 พันล้าน เคาะปันผลหุ้น-เงินสด XD 24 ก.พ.นี้
# 2023-02-13 00:00:00
# GLOBAL
# บริษัท สยามโกลบอลเฮ้าส์ จำกัด (มหาชน) หรือ GLOBAL รายงานผลการดำเนินงานปี 65 สิ้นสุดวันที่ 31 ธ.ค.65 ดังนี้
# โดยผลการดำเนินงานมีกำไรเพิ่มขึ้นเนื่องจากรายได้รวมในปี 65 เท่ากับ 35,978.40 ล้านบาท เพิ่มขึ้นจากปี 2564 จำนวน 1,862.29 ล้านบาท หรือเพิ่มขึ้น 5.46% ประกอบด้วย รายได้จากการขาย เท่ากับ 35,270.33 ล้านบาท เพิ่มขึ้น 1,772.53 ล้านบาท หรือ เพิ่มขึ้น 5.29% เป็นผลจากยอดขายของสาขาเดิมที่เพิ่มขึ้นและการเปิดสาขาใหม่เพิ่มในปี 2565 อีก 2 สาขา
# นอกจากนี้รายได้อื่น เท่ากับ 708.06 ล้านบาท เพิ่มขึ้น 89.75 ล้านบาท หรือเพิ่มขึ้น 14.51% โดยมีปัจจัยหลักจากการเพิ่มขึ้นของรายได้เงินสนับสนุนจากคู่ค้า รายได้บริหารคลังสินค้า และรายได้ค่าขนส่ง
# ทั้งนี้บริษัทฯ ประกาศจ่ายปันผลจากงวดดำเนินงานวันที่ 1 ม.ค. 2565 ถึงวันที่ 31 ธ.ค. 2565 โดยจ่ายปันผลเป็นหุ้นปันผลและเงินสด ซึ่งจ่ายหุ้นเป็นปันผล (หุ้นเดิม : หุ้นปันผล) ในอัตรา 24.00 : 1.00 โดยอัตราการจ่ายปันผลเป็นหุ้น 0.0416666665 บาท ส่วนจ่ายปันผลเป็นเงินสดในอัตรา 0.2546296296 บาท/หุ้น ทั้งนี้อัตราการจ่ายปันผลรวม 0.2962962961 บาท/หุ้น กำหนดขึ้นเครื่องหมาย XD วันที่ 24 ก.พ.66 และกำหนดจ่ายเงินปันผลในวันที่ 11 พ.ค.66
# “สุเชษฐ์” แนะ 6 หุ้นน่าลงทุน รับธีมการลงทุนต่างชาติ-เลือกตั้ง
# “สุเชษฐ์” จัด 3 หุ้นเก็งกำไร หลัง SET รีบาวด์
# Tags
# สยามโกลบอลเฮ้าส์
# หุ้น GLOBAL
# GLOBAL
# 1193
# ---------------------------------------------------
# ---------------------------------------------------
# [('2023-02-13 00:00:00', 'จับตา GULF วิ่ง! รอรับปันผล “อินทัช-ไทยคม” กว่า 2 พันล้าน', 'https://www.kaohoon.com/news/588032', 'INTUCH'), ('2023-02-13 00:00:00', 'จับตา GULF วิ่ง! รอรับปันผล “อินทัช-ไทยคม” กว่า 2 พันล้าน', 'https://www.kaohoon.com/news/588032', 'INTUCH')]
# https://www.kaohoon.com/news/588032
# จับตา GULF วิ่ง! รอรับปันผล “อินทัช-ไทยคม” กว่า 2 พันล้าน
# 2023-02-13 00:00:00
# INTUCH
# ผู้สื่อข่าวรายงานว่า ที่ประชุมคณะกรรมการบริษัท อินทัช โฮลดิ้งส์ จำกัด (มหาชน) หรือ INTUCH มีมติอนุมัติจ่ายปันผลงวดครึ่งหลังปี 65 อัตราหุ้นละ 1.56 บาท คิดเป็นเงินประมาณ 5,002 ล้านบาท วันที่ไม่ได้รับสิทธิปันผล (XD) วันที่ 23 ก.พ.66 และกำหนดวันจ่ายเงินปันผลวันที่ 21 เม.ย. 66
# ขณะเดียวบริษัท ไทยคม จำกัด (มหาชน) หรือ THCOM ประกาศจ่ายเงินปันผลประจำปี 2565 อัตราหุ้นละ 0.50 บาท วันที่ไม่ได้รับสิทธิปันผล (XD) วันที่ 3 เม.ย.66 กำหนดรายชื่อผู้ถือหุ้น (Record Date) ที่มีสิทธิรับเงินปันผลวันที่ 4 เม.ย. 66 และกำหนดวันจ่ายเงินปันผลวันที่ 26 เม.ย. 66
# ทั้งนี้จากการปันผลของ INTUCH และ THCOM จะส่งผลให้บริษัท กัลฟ์ เอ็นเนอร์จี ดีเวลลอปเมนท์ จำกัด (มหาชน) หรือ GULF ในฐานะผู้ถือหุ้นใหญ่ของทั้ง 2 บริษัท ได้รับเงินปันผลรวมกว่า 2.3 พันล้านบาท โดย GULF ถือหุ้นใน INTUCH  สัดส่วน 41.15% หรือประมาณ 1,320 ล้านหุ้น และถือหุ้นใน THCOM สัดส่วน 41.13% หรือประมาณ 451 ล้านหุ้น
# Tags
# THCOM
# INTUCH
# ปันผล
# กัลฟ์ เอ็นเนอร์จี ดีเวลลอปเมนท์
# ไทยคม
# GULF
# อินทัช โฮลดิ้งส์
# ราคาหุ้น GULF
# 950
# [('2023-02-13 00:00:00', 'จับตา GULF วิ่ง! รอรับปันผล “อินทัช-ไทยคม” กว่า 2 พันล้าน', 'https://www.kaohoon.com/news/588032', 'GULF'), ('2023-02-13 00:00:00', 'จับตา GULF วิ่ง! รอรับปันผล “อินทัช-ไทยคม” กว่า 2 พันล้าน', 'https://www.kaohoon.com/news/588032', 'GULF')]
# https://www.kaohoon.com/news/588032
# จับตา GULF วิ่ง! รอรับปันผล “อินทัช-ไทยคม” กว่า 2 พันล้าน
# 2023-02-13 00:00:00
# GULF
# ผู้สื่อข่าวรายงานว่า ที่ประชุมคณะกรรมการบริษัท อินทัช โฮลดิ้งส์ จำกัด (มหาชน) หรือ INTUCH มีมติอนุมัติจ่ายปันผลงวดครึ่งหลังปี 65 อัตราหุ้นละ 1.56 บาท คิดเป็นเงินประมาณ 5,002 ล้านบาท วันที่ไม่ได้รับสิทธิปันผล (XD) วันที่ 23 ก.พ.66 และกำหนดวันจ่ายเงินปันผลวันที่ 21 เม.ย. 66
# ขณะเดียวบริษัท ไทยคม จำกัด (มหาชน) หรือ THCOM ประกาศจ่ายเงินปันผลประจำปี 2565 อัตราหุ้นละ 0.50 บาท วันที่ไม่ได้รับสิทธิปันผล (XD) วันที่ 3 เม.ย.66 กำหนดรายชื่อผู้ถือหุ้น (Record Date) ที่มีสิทธิรับเงินปันผลวันที่ 4 เม.ย. 66 และกำหนดวันจ่ายเงินปันผลวันที่ 26 เม.ย. 66
# ทั้งนี้จากการปันผลของ INTUCH และ THCOM จะส่งผลให้บริษัท กัลฟ์ เอ็นเนอร์จี ดีเวลลอปเมนท์ จำกัด (มหาชน) หรือ GULF ในฐานะผู้ถือหุ้นใหญ่ของทั้ง 2 บริษัท ได้รับเงินปันผลรวมกว่า 2.3 พันล้านบาท โดย GULF ถือหุ้นใน INTUCH  สัดส่วน 41.15% หรือประมาณ 1,320 ล้านหุ้น และถือหุ้นใน THCOM สัดส่วน 41.13% หรือประมาณ 451 ล้านหุ้น
# Tags
# THCOM
# INTUCH
# ปันผล
# กัลฟ์ เอ็นเนอร์จี ดีเวลลอปเมนท์
# ไทยคม
# GULF
# อินทัช โฮลดิ้งส์
# ราคาหุ้น GULF
# 950
# ---------------------------------------------------
# ---------------------------------------------------
# ---------------------------------------------------
# ---------------------------------------------------
# ---------------------------------------------------
# [('2023-02-13 00:00:00', 'โบรกแห่อัพเป้า ADVANC สูงลิ่ว 257 บ. ลุ้นเสร็จดีล 3BB ไตรมาส 2/66', 'https://www.kaohoon.com/news/588029', 'ADVANC')]
# https://www.kaohoon.com/news/588029
# โบรกแห่อัพเป้า ADVANC สูงลิ่ว 257 บ. ลุ้นเสร็จดีล 3BB ไตรมาส 2/66
# 2023-02-13 00:00:00
# ADVANC
# ผู้สื่อข่าวรายงานว่า จากประชุมกลุ่มนักวิเคราะห์ร่วมกับผู้บริหารบริษัท แอดวานซ์ อินโฟร์ เซอร์วิส จำกัด (มหาชน) หรือ ADVANC วันที่ 10 ก.พ.ที่ผ่านมา หลังจากบริษัทได้ประกาศผลประกอบการประจำไตรมาส 4/2565 และประจำปี 2565 ออกมาสูงกว่าที่นักวิเคราะห์ประมาณการไว้ก่อนหน้านี้
# ล่าสุดนักวิเคราะห์ บริษัทหลักทรัพย์ โนมูระ พัฒนสิน จำกัด (มหาชน) มีมุมมองเชิงบวกประชุมนักวิเคราะห์ที่ผ่านมา โดยผู้บริหารคาดแนวโน้มการแข่งขันลดลง โดย AIS ตั้งเป้ารายได้ปีนี้เติบโต 3-5% (ไม่รวมดีลซื้อบริษัท ทริปเปิลที บรอดแบนด์ จำกัด (มหาชน) หรือ 3BB) และ EBITDA จะเติบโตระดับกลาง เน้นการสร้างการเติบโตรายได้ที่มีคุณภาพ เช่น กลุ่มมือถือเน้น 5G และการถอนโปรฯ ที่ไม่สร้างกำไรออก ควบคู่กับกลยุทธ์การออกแพ็กแกจร่วมกัน (FMC) ระหว่างมือถือและบรอดแบนด์ โดยบริษัทตั้งงบลงทุนปี 2566 ไว้ที่ 27,000-30,000 ล้านบาท (ไม่รวมดีลซื้อ 3BB)
# สำหรับการแข่งขันราคาธุรกิจมือถือเริ่มแผ่วลง หลังไตรมาสที่ผ่านมา ADVANC ทยอยถอนโปรโมชั่นราคาถูก (ไม่สร้างกำไร) ออกจากตลาด และปลายไตรมาสคู่แข่งขันเริ่มขยับราคาแพ็กเกจขึ้นเช่นกัน อย่างไรก็ตามบริษัทยังไม่มีแนวคิดปรับนโยบายจ่ายเงินปันผลจากปัจจุบันไม่ต่ำกว่า 70% ของกำไรสุทธิทั้งปี หลังปีที่ผ่านมาจ่ายปันผลคิดเป็น Payout กว่า 88% ขึ้นจากปี 2564 ที่จ่าย 85%
# ส่วนความคืบหน้าโครงการต่าง ๆ ดีลซื้อกองทุนรวมโครงสร้างพื้นฐานบรอดแบนด์อินเทอร์เน็ต จัสมิน หรือ JASIF และ 3BB อาจล่าช้ากว่าแผนเดิมเล็กน้อย คาดเสร็จในไตรมาส 2/2566 จากเดิมไตรมาส 1/2566 และดีลการร่วมบริหารคลื่น 700 MHz ของบริษัท โทรคมนาคมแห่งชาติ จำกัด (มหาชน) หรือ NT ปัจจุบันอยู่ในขั้นตอนการพิจารณาของสภาพัฒน์ คาดชัดเจนมากขึ้นในเดือนหน้าก่อนที่ให้ครม.อนุมัติต่อไป
# ขณะที่ ดีลร่วมสร้าง Data center กับกลุ่มสิงเทล และบริษัท กัลฟ์ เอ็นเนอร์จี ดีเวลลอปเมนท์ จำกัด (มหาชน) หรือ GULF ปัจจุบันหาพื้นที่ได้แล้ว คาดเฟสแรกสร้างศูนย์ data center ขนาด 20 เมกะวัตต์ก่อน คาดให้บริการเชิงพาณิชย์ในปี 2568
# แรงซื้อ “บลูชิพ” พยุง SET ปิดบวก 0.32 จุด แนวโน้มพรุ่งนี้ไซด์เวย์ ลุ้นเงินเฟ้อสหรัฐ
# SET ปิดเช้ารีบาวด์ 1 จุด เก็งกำไรรายตัว-รอเงินเฟ้อสหรัฐ
# สำหรับแนวคิดขายสินทรัพย์จัดตั้งกองทุน AISIF เบื้องต้นผู้บริหารมองเป็นหนึ่งทางเลือกในการระดมทุน และที่ผ่านมามีการพิจารณาถึงแนวคิดดังกล่าว แต่ยังไม่มีข้อสรุป เพราะต้องคำนึงถึงผลดีและผลเสียประกอบด้วย ทั้งนี้จากแนวโน้มการแข่งขันด้านราคาที่ลดลง ดังนั้นจึงยังคงแนะนำ “ซื้อ” ราคาเป้าหมาย 252 บาท เลือกเป็น Top pick
# ด้านบริษัทหลักทรัพย์ บัวหลวง จำกัด (มหาชน) ระบุ AIS ให้เป้าผลการดำเนินงานปี 2566 ได้แก่ รายได้บริการหลักเพิ่มขึ้น 3-5% และ EBITDA เพิ่มขึ้น 4-6% โดยบัวหลวงมองว่าอัตราการเติบโตของรายได้บริการหลักที่ 3-5% ในปี 2566 จะได้รับแรงหนุนจากการฟื้นตัวของเศรษฐกิจไทยจากกลุ่มท่องเที่ยว ผลประโยชน์จากการเปิดประเทศจีน และอัตราเงินเฟ้อที่ลดต่ำลง
# ขณะที่ EBITDA ที่เติบโต 4-6% จะสะท้อนการใช้เทคโนโลยีอัจฉริยะเพื่อสร้างประสบการณ์ให้กับลูกค้าที่แตกต่างออกไป ไม่เหมือนเดิม หรือ “Cognitive Tech-Co” จะผลักดันให้ต้นทุนการดำเนินงานลดลงผ่านการใช้ระบบโครงข่ายอัจฉริยะ รวมถึงการปรับปรุงกระบวนการและระบบไอที นอกจากนี้บริษัทยังมีแผนที่จะเพิ่มประสิทธิภาพของการใช้งบลงทุน โดยจะทำการลดทราฟฟิกการใช้งานที่สร้างมูลค่าในระดับต่ำ และย้ายทราฟฟิกการใช้งานดังกล่าวไปยังโครงข่าย 5G รายได้ธุรกิจบรอดแบนด์บ้านมีแนวโน้มเติบโตระดับตัวเลขสองหลักสำหรับในปี 2566 โดยเป้าหมายจำนวนผู้ใช้บริการบรอดแบนด์บ้าน ณ สิ้นปี 2566 อยู่ที่ 2.5 ล้านราย
# โดยประมาณการกําไรหลักไตรมาส 1/2566 ที่ 6.9 พันล้านบาท เพิ่มขึ้น 10% จากช่วงเดียวกันของปีก่อน และเพิ่มขึ้น 3% จากไตรมาสก่อน
# ทั้งนี้ บัวหลวงได้ปรับประมาณกำไรสุทธิปี 2566 เพิ่มขึ้นอีก 5% เป็น 2.64 หมื่นล้านบาท เพื่อสะท้อนประมาณการรายได้บริการหลักที่เพิ่มขึ้นอีก 1.5% จากประมาณการเดิมที่ 1.38 แสนล้านบาท พร้อมทั้งปรับราคาเป้าหมายใหม่เป็น 257 บาท โดยมีอัตราผลตอบแทนจากเงินปันผล 4%
# นายพิสุทธิ์ งามวิจิตวงศ์ ผู้อำนวยการอาวุโส ฝ่ายวิเคราะห์หลักทรัพย์ บริษัทหลักทรัพย์ กสิกรไทย จำกัด (มหาชน) เปิดเผยว่า ผู้บริหารของ AIS คาดแนวโน้มการแข่งขันในปี 2566 จะค่อย ๆ ลดลง โดยรายได้จะเติบโตประมาณ 3-5% ขณะที่ EBITDA จะเติบโตประมาณ 4-6%
# ส่วนการแข่งขันเน็ตบ้านจะลดลงเรื่อย ๆ หลังจาก AIS ควบรวมกิจการของ 3BB ภายในไตรมาสที่ 2/2566 นี้ ซึ่งปัจจุบัน AIS ได้ปรับขึ้นค่าบริการเป็น 399 บาทต่อเดือน จากเดิม 299 บาทต่อเดือน
# ขณะที่ บริการมือถือ AIS เริ่มถอนแพ็กเกจราคาถูกออก ทำให้การแข่งขันระหว่างค่ายมือถือลดลง ทำให้มีมาร์จิ้นของแต่ละบริษัทดีขึ้น โดยบล.กสิกรไทย ประเมินกำไรของ ADVANC จะเติบโต 7% เมื่อเทียบกับปีก่อนหน้า สำหรับการตั้งกองทุนโครงสร้างพื้นฐาน ขณะนี้ยังต้องรอให้การควบรวมกิจการกับ 3BB เสร็จสิ้นก่อน ซึ่งคาดว่าจะเกิดขึ้นภายในไตรมาสที่ 2/2566 นี้
# บริษัทหลักทรัพย์ ดาโอ (ประเทศไทย) จำกัด (มหาชน) ระบุว่า บริษัท แอดวานซ์ อินโฟร์ เซอร์วิส จำกัด (มหาชน) หรือ ADVANC กำไรปกติไตรมาส 4/2565 ตามคาด และปัจจัยบวกเริ่มชัด หนุน sentiment ดีขึ้น จึงปรับคำแนะนำขึ้นเป็น “ซื้อ” และปรับราคาเป้าหมายขึ้นเป็น 230.00 บาท/หุ้น จากเดิม 210.00 บาท/หุ้น จากการปรับไปใช้ราคาเป้าหมายปี 2566 และกลับมาให้น้ำหนักกับปัจจัยบวกเพิ่มขึ้น (การฟื้นตัวของเศรษฐกิจจากการกลับมาของนักท่องเที่ยว, แนวโน้มค่าไฟฟ้าที่ peak out ในครึ่งปีแรกของปี 2566, การปิดดีล 3BB และ JASIF และ TRUE และ DTAC ทำให้การแข่งขันระยะยาวลดลง
# รวมถึงโอกาสการขายสินทรัพย์โครงข่ายเพื่อขยายโอกาสทางธุรกิจ หากดีล 3BB และ JASIF สำเร็จ ก็จะประเมินเป็น upside ขณะที่ระยะยาวการใช้งาน Data ที่เพิ่มขึ้นของลูกค้าจะเป็นปัจจัยสำคัญในการขับเคลื่อน โดยราคาหุ้นจะกลับมา outperform SET ได้ระยะถัดไป จากปัจจัยบวกที่กล่าวถึงข้างต้น ซึ่งจะทยอยเห็นพัฒนาการตั้งแต่ปลายไตรมาส 1/2566 เป็นต้นไป
# นายสมชัย เลิศสุทธิวงค์ ประธานเจ้าหน้าที่บริหาร ADVANC เปิดเผยว่า ที่ประชุมคณะกรรมการบริษัท วันที่ 9 ก.พ. 2566 มีมติให้เสนอที่ประชุมสามัญผู้ถือหุ้นประจําปี 2566 วันที่ 27 มีนาคม 2566 เวลา 14.00 น. ณ โรงแรมเซ็นทาราแกรนด์ เซ็นทรัลพลาซา ลาดพร้าว โดยให้พิจารณาวาระสำคัญ คือ พิจารณาอนุมัติการออกและเสนอขายหุ้นกู้ในวงเงินไม่เกิน 100,000 ล้านบาท และการพิจารณาอนุมัติจัดสรรกําไรสุทธิประจําปี 2565 เป็นเงินปันผลให้แก่ผู้ถือหุ้น อัตรา 7.69 บาทต่อหุ้น โดยได้มีการจ่ายเงินปันผลระหว่างกาลวันที่ 6 ก.ย. 2565 อัตรา 3.45 บาทต่อหุ้น คงเหลือจ่ายปันผลสําหรับงวดนี้ 4.24 บาทต่อหุ้น
# Tags
# JASIF
# ADVANC
# บล.โนมูระ พัฒนสิน
# กสิกรไทย
# 3BB
# กัลฟ์ เอ็นเนอร์จี ดีเวลลอปเมนท์
# GULF
# กองทุนรวมโครงสร้างพื้นฐาน
# Data Center
# ทริปเปิลที บรอดแบนด์
# หุ้น ADVANC
# แอดวานซ์ อินโฟร์ เซอร์วิส
# กลุ่มสิงเทล
# 5810
# [('2023-02-13 00:00:00', 'โบรกแห่อัพเป้า ADVANC สูงลิ่ว 257 บ. ลุ้นเสร็จดีล 3BB ไตรมาส 2/66', 'https://www.kaohoon.com/news/588029', 'GULF')]
# https://www.kaohoon.com/news/588029
# โบรกแห่อัพเป้า ADVANC สูงลิ่ว 257 บ. ลุ้นเสร็จดีล 3BB ไตรมาส 2/66
# 2023-02-13 00:00:00
# GULF
# ผู้สื่อข่าวรายงานว่า จากประชุมกลุ่มนักวิเคราะห์ร่วมกับผู้บริหารบริษัท แอดวานซ์ อินโฟร์ เซอร์วิส จำกัด (มหาชน) หรือ ADVANC วันที่ 10 ก.พ.ที่ผ่านมา หลังจากบริษัทได้ประกาศผลประกอบการประจำไตรมาส 4/2565 และประจำปี 2565 ออกมาสูงกว่าที่นักวิเคราะห์ประมาณการไว้ก่อนหน้านี้
# ล่าสุดนักวิเคราะห์ บริษัทหลักทรัพย์ โนมูระ พัฒนสิน จำกัด (มหาชน) มีมุมมองเชิงบวกประชุมนักวิเคราะห์ที่ผ่านมา โดยผู้บริหารคาดแนวโน้มการแข่งขันลดลง โดย AIS ตั้งเป้ารายได้ปีนี้เติบโต 3-5% (ไม่รวมดีลซื้อบริษัท ทริปเปิลที บรอดแบนด์ จำกัด (มหาชน) หรือ 3BB) และ EBITDA จะเติบโตระดับกลาง เน้นการสร้างการเติบโตรายได้ที่มีคุณภาพ เช่น กลุ่มมือถือเน้น 5G และการถอนโปรฯ ที่ไม่สร้างกำไรออก ควบคู่กับกลยุทธ์การออกแพ็กแกจร่วมกัน (FMC) ระหว่างมือถือและบรอดแบนด์ โดยบริษัทตั้งงบลงทุนปี 2566 ไว้ที่ 27,000-30,000 ล้านบาท (ไม่รวมดีลซื้อ 3BB)
# สำหรับการแข่งขันราคาธุรกิจมือถือเริ่มแผ่วลง หลังไตรมาสที่ผ่านมา ADVANC ทยอยถอนโปรโมชั่นราคาถูก (ไม่สร้างกำไร) ออกจากตลาด และปลายไตรมาสคู่แข่งขันเริ่มขยับราคาแพ็กเกจขึ้นเช่นกัน อย่างไรก็ตามบริษัทยังไม่มีแนวคิดปรับนโยบายจ่ายเงินปันผลจากปัจจุบันไม่ต่ำกว่า 70% ของกำไรสุทธิทั้งปี หลังปีที่ผ่านมาจ่ายปันผลคิดเป็น Payout กว่า 88% ขึ้นจากปี 2564 ที่จ่าย 85%
# ส่วนความคืบหน้าโครงการต่าง ๆ ดีลซื้อกองทุนรวมโครงสร้างพื้นฐานบรอดแบนด์อินเทอร์เน็ต จัสมิน หรือ JASIF และ 3BB อาจล่าช้ากว่าแผนเดิมเล็กน้อย คาดเสร็จในไตรมาส 2/2566 จากเดิมไตรมาส 1/2566 และดีลการร่วมบริหารคลื่น 700 MHz ของบริษัท โทรคมนาคมแห่งชาติ จำกัด (มหาชน) หรือ NT ปัจจุบันอยู่ในขั้นตอนการพิจารณาของสภาพัฒน์ คาดชัดเจนมากขึ้นในเดือนหน้าก่อนที่ให้ครม.อนุมัติต่อไป
# ขณะที่ ดีลร่วมสร้าง Data center กับกลุ่มสิงเทล และบริษัท กัลฟ์ เอ็นเนอร์จี ดีเวลลอปเมนท์ จำกัด (มหาชน) หรือ GULF ปัจจุบันหาพื้นที่ได้แล้ว คาดเฟสแรกสร้างศูนย์ data center ขนาด 20 เมกะวัตต์ก่อน คาดให้บริการเชิงพาณิชย์ในปี 2568
# แรงซื้อ “บลูชิพ” พยุง SET ปิดบวก 0.32 จุด แนวโน้มพรุ่งนี้ไซด์เวย์ ลุ้นเงินเฟ้อสหรัฐ
# SET ปิดเช้ารีบาวด์ 1 จุด เก็งกำไรรายตัว-รอเงินเฟ้อสหรัฐ
# สำหรับแนวคิดขายสินทรัพย์จัดตั้งกองทุน AISIF เบื้องต้นผู้บริหารมองเป็นหนึ่งทางเลือกในการระดมทุน และที่ผ่านมามีการพิจารณาถึงแนวคิดดังกล่าว แต่ยังไม่มีข้อสรุป เพราะต้องคำนึงถึงผลดีและผลเสียประกอบด้วย ทั้งนี้จากแนวโน้มการแข่งขันด้านราคาที่ลดลง ดังนั้นจึงยังคงแนะนำ “ซื้อ” ราคาเป้าหมาย 252 บาท เลือกเป็น Top pick
# ด้านบริษัทหลักทรัพย์ บัวหลวง จำกัด (มหาชน) ระบุ AIS ให้เป้าผลการดำเนินงานปี 2566 ได้แก่ รายได้บริการหลักเพิ่มขึ้น 3-5% และ EBITDA เพิ่มขึ้น 4-6% โดยบัวหลวงมองว่าอัตราการเติบโตของรายได้บริการหลักที่ 3-5% ในปี 2566 จะได้รับแรงหนุนจากการฟื้นตัวของเศรษฐกิจไทยจากกลุ่มท่องเที่ยว ผลประโยชน์จากการเปิดประเทศจีน และอัตราเงินเฟ้อที่ลดต่ำลง
# ขณะที่ EBITDA ที่เติบโต 4-6% จะสะท้อนการใช้เทคโนโลยีอัจฉริยะเพื่อสร้างประสบการณ์ให้กับลูกค้าที่แตกต่างออกไป ไม่เหมือนเดิม หรือ “Cognitive Tech-Co” จะผลักดันให้ต้นทุนการดำเนินงานลดลงผ่านการใช้ระบบโครงข่ายอัจฉริยะ รวมถึงการปรับปรุงกระบวนการและระบบไอที นอกจากนี้บริษัทยังมีแผนที่จะเพิ่มประสิทธิภาพของการใช้งบลงทุน โดยจะทำการลดทราฟฟิกการใช้งานที่สร้างมูลค่าในระดับต่ำ และย้ายทราฟฟิกการใช้งานดังกล่าวไปยังโครงข่าย 5G รายได้ธุรกิจบรอดแบนด์บ้านมีแนวโน้มเติบโตระดับตัวเลขสองหลักสำหรับในปี 2566 โดยเป้าหมายจำนวนผู้ใช้บริการบรอดแบนด์บ้าน ณ สิ้นปี 2566 อยู่ที่ 2.5 ล้านราย
# โดยประมาณการกําไรหลักไตรมาส 1/2566 ที่ 6.9 พันล้านบาท เพิ่มขึ้น 10% จากช่วงเดียวกันของปีก่อน และเพิ่มขึ้น 3% จากไตรมาสก่อน
# ทั้งนี้ บัวหลวงได้ปรับประมาณกำไรสุทธิปี 2566 เพิ่มขึ้นอีก 5% เป็น 2.64 หมื่นล้านบาท เพื่อสะท้อนประมาณการรายได้บริการหลักที่เพิ่มขึ้นอีก 1.5% จากประมาณการเดิมที่ 1.38 แสนล้านบาท พร้อมทั้งปรับราคาเป้าหมายใหม่เป็น 257 บาท โดยมีอัตราผลตอบแทนจากเงินปันผล 4%
# นายพิสุทธิ์ งามวิจิตวงศ์ ผู้อำนวยการอาวุโส ฝ่ายวิเคราะห์หลักทรัพย์ บริษัทหลักทรัพย์ กสิกรไทย จำกัด (มหาชน) เปิดเผยว่า ผู้บริหารของ AIS คาดแนวโน้มการแข่งขันในปี 2566 จะค่อย ๆ ลดลง โดยรายได้จะเติบโตประมาณ 3-5% ขณะที่ EBITDA จะเติบโตประมาณ 4-6%
# ส่วนการแข่งขันเน็ตบ้านจะลดลงเรื่อย ๆ หลังจาก AIS ควบรวมกิจการของ 3BB ภายในไตรมาสที่ 2/2566 นี้ ซึ่งปัจจุบัน AIS ได้ปรับขึ้นค่าบริการเป็น 399 บาทต่อเดือน จากเดิม 299 บาทต่อเดือน
# ขณะที่ บริการมือถือ AIS เริ่มถอนแพ็กเกจราคาถูกออก ทำให้การแข่งขันระหว่างค่ายมือถือลดลง ทำให้มีมาร์จิ้นของแต่ละบริษัทดีขึ้น โดยบล.กสิกรไทย ประเมินกำไรของ ADVANC จะเติบโต 7% เมื่อเทียบกับปีก่อนหน้า สำหรับการตั้งกองทุนโครงสร้างพื้นฐาน ขณะนี้ยังต้องรอให้การควบรวมกิจการกับ 3BB เสร็จสิ้นก่อน ซึ่งคาดว่าจะเกิดขึ้นภายในไตรมาสที่ 2/2566 นี้
# บริษัทหลักทรัพย์ ดาโอ (ประเทศไทย) จำกัด (มหาชน) ระบุว่า บริษัท แอดวานซ์ อินโฟร์ เซอร์วิส จำกัด (มหาชน) หรือ ADVANC กำไรปกติไตรมาส 4/2565 ตามคาด และปัจจัยบวกเริ่มชัด หนุน sentiment ดีขึ้น จึงปรับคำแนะนำขึ้นเป็น “ซื้อ” และปรับราคาเป้าหมายขึ้นเป็น 230.00 บาท/หุ้น จากเดิม 210.00 บาท/หุ้น จากการปรับไปใช้ราคาเป้าหมายปี 2566 และกลับมาให้น้ำหนักกับปัจจัยบวกเพิ่มขึ้น (การฟื้นตัวของเศรษฐกิจจากการกลับมาของนักท่องเที่ยว, แนวโน้มค่าไฟฟ้าที่ peak out ในครึ่งปีแรกของปี 2566, การปิดดีล 3BB และ JASIF และ TRUE และ DTAC ทำให้การแข่งขันระยะยาวลดลง
# รวมถึงโอกาสการขายสินทรัพย์โครงข่ายเพื่อขยายโอกาสทางธุรกิจ หากดีล 3BB และ JASIF สำเร็จ ก็จะประเมินเป็น upside ขณะที่ระยะยาวการใช้งาน Data ที่เพิ่มขึ้นของลูกค้าจะเป็นปัจจัยสำคัญในการขับเคลื่อน โดยราคาหุ้นจะกลับมา outperform SET ได้ระยะถัดไป จากปัจจัยบวกที่กล่าวถึงข้างต้น ซึ่งจะทยอยเห็นพัฒนาการตั้งแต่ปลายไตรมาส 1/2566 เป็นต้นไป
# นายสมชัย เลิศสุทธิวงค์ ประธานเจ้าหน้าที่บริหาร ADVANC เปิดเผยว่า ที่ประชุมคณะกรรมการบริษัท วันที่ 9 ก.พ. 2566 มีมติให้เสนอที่ประชุมสามัญผู้ถือหุ้นประจําปี 2566 วันที่ 27 มีนาคม 2566 เวลา 14.00 น. ณ โรงแรมเซ็นทาราแกรนด์ เซ็นทรัลพลาซา ลาดพร้าว โดยให้พิจารณาวาระสำคัญ คือ พิจารณาอนุมัติการออกและเสนอขายหุ้นกู้ในวงเงินไม่เกิน 100,000 ล้านบาท และการพิจารณาอนุมัติจัดสรรกําไรสุทธิประจําปี 2565 เป็นเงินปันผลให้แก่ผู้ถือหุ้น อัตรา 7.69 บาทต่อหุ้น โดยได้มีการจ่ายเงินปันผลระหว่างกาลวันที่ 6 ก.ย. 2565 อัตรา 3.45 บาทต่อหุ้น คงเหลือจ่ายปันผลสําหรับงวดนี้ 4.24 บาทต่อหุ้น
# Tags
# JASIF
# ADVANC
# บล.โนมูระ พัฒนสิน
# กสิกรไทย
# 3BB
# กัลฟ์ เอ็นเนอร์จี ดีเวลลอปเมนท์
# GULF
# กองทุนรวมโครงสร้างพื้นฐาน
# Data Center
# ทริปเปิลที บรอดแบนด์
# หุ้น ADVANC
# แอดวานซ์ อินโฟร์ เซอร์วิส
# กลุ่มสิงเทล
# 5810
# ---------------------------------------------------
# ---------------------------------------------------
# ---------------------------------------------------
# ---------------------------------------------------
# ---------------------------------------------------
# ---------------------------------------------------
# ---------------------------------------------------
# ---------------------------------------------------
# [('2023-02-13 00:00:00', 'ขายหนีตาย?', 'https://www.kaohoon.com/column/588002', 'AP')]
# https://www.kaohoon.com/column/588002
# ขายหนีตาย?
# 2023-02-13 00:00:00
# AP
# สถานการณ์ของตลาดหุ้นไทยเมื่อสัปดาห์ที่ผ่านมา สร้างความเจ็บช้ำให้กับเดี๊ยนเป็นอย่างมาก เพราะโดนรินขายตั้งแต่ต้นสัปดาห์ และโดนขายหนักสุดในช่วงกลางสัปดาห์ ก่อนที่ดัชนีจะไหลลงมาเรื่อย ๆ จนสุดท้ายยืนปิดที่ระดับ 1,664.57จุด ลบไป 4.60 จุด ด้วยมูลค่าการซื้อขาย 5.89 หมื่นล้านบาท ซึ่งสวนทางกับปัจจัยบวกที่ทยอยถูกเปิดออกมาทีละเรื่องแบบนี้..เป็นใครไม่โซแซดบ้างล่ะคะ
# โดยเฉพาะการขายหุ้นอย่างหนักของพวก “กองทุน” กับ “ต่างชาติ” ถือเป็นแรงฉุดที่ทำให้ทุกอย่างเปลี่ยนไปในทางร้ายจนยากที่จะกู้กลับให้มาดีดั่งเดิม และยังทำให้โมเมนตัมของตลาดหุ้นเปลี่ยนเป็นแกว่งตัวลงแบบนี้ “โมนิก้า” คงพูดได้แค่ว่า ขายหนีตายดีกว่ากระมัง! เพราะสถานการณ์หลายอย่างเปลี่ยนไปจากที่คาดการณ์ไว้แบบสุดกู่ เดี๊ยนเลยไม่อยากจะฝืนเชื่อในสิ่งที่เริ่มเป็นไปไม่ได้นะจ๊ะ
# เนื่องจากก่อนหน้านี้ “โมนิก้า” ได้จำลองสถานการณ์ตลาดหุ้นไทยว่า ไม่มีเรื่องไหนที่ต้องกังวลอีกแล้ว หลังตลาดหุ้นไทยตอบรับกับข่าวร้ายไปหมดแล้ว และที่เหลือก็เป็นเรื่องของผลงานจะฟื้นตัวขนาดไหน? พอเอาเข้าจริงดันกลายเป็นหนังคนละม้วน เดี๊ยนมองว่า วันนี้ตลาดหุ้นไทยควรจะเด้งกลับเสียที! หากไม่เด้งเหมือนที่สัญญาณเทคนิคบอกไว้ ก็ต้องยอมตัดใจเพื่อไม่ให้เจ็บหนักไปกว่านี้นะคะ
# เหมือนกับการไหลลงของแบงก์ตราใบโพธิ์ SCB ก็เป็นเรื่องที่สร้างความประหลาดใจให้กับ “โมนิก้า” มากพอสมควร เพราะเมื่อดูตามท้องเรื่องที่เกิดขึ้น ไม่น่าจะมีประเด็นไหนที่กดราคาหุ้นลงมาต่ำร้อย แต่สุดท้ายราคาหุ้นก็ลงมายืนจ่อที่ระดับ 100.50 บาท ลบไป 3 บาท หรือลงไป 2.90% ด้วยมูลค่าการซื้อขาย 3 พันล้านบาท จึงกลายเป็นจังหวะที่ต้องชิ่งหนีโดยด่วน หากวันนี้ไม่เด้งกลับอย่างมั่นคงเจ้าค่ะ
# ส่วนรายที่อยู่ในทิศทางลงลูกเดียว จนหาทางกลับบ้านไม่เจอ “โมนิก้า” คงมองไปที่หุ้นขายไก่ขายหมู CPF แบบไม่ลังเลใจ เพราะดูจากโอกาสในการทำกำไรสวย ๆ มันแทบจะเป็นไปไม่ได้เลย ไม่ว่าจะราคาเนื้อสัตว์ที่อยู่ในช่วงลงต่อเนื่อง และเรื่องต้นทุนอาหารสัตว์ที่สูงขึ้น หรือแม้กระทั่งความกังวลเกี่ยวกับไข้หวัดนก ล้วนเป็นประเด็นที่กดดันให้นักเล่นต้องขายหุ้นออกไปก่อน และทำให้หุ้นลงมาปิดที่ 22.90 บาท ลบไป 0.30 บาท หรือลงไป 1.30% ด้วยมูลค่าการซื้อขาย 650 ล้านบาทไงล่ะคะ
# JMT โชว์งบปี 65 กำไร 1.7 พันลบ. รับส่วนแบ่งกำไร JK AMC หนุน
# BEM โบรกแนะซื้อเป้า 10.80 บ. รับผู้โดยสาร MRT ม.ค. โตทะลัก 114% แตะ 3.7 แสนเที่ยว/วัน
# ในเมื่อเม้าท์ถึงหุ้นที่มีแรงกดดันเยอะ และราคาหุ้นเอาแต่ลงอย่างเดียว “โมนิก้า” คงต้องมองไปที่หุ้น JMT แบบไม่ลังเลใจแม้แต่นิดเดียว เพราะเป็นหุ้นที่แมงลือเม้าท์กันให้แซ่ดว่า กำไรจะออกมาเท่านั้น..กำไรจะออกมาเท่านี้ เดี๊ยนเลยอยากแจ้งให้ทุกคนรู้ว่า วันนี้รู้กัน! เพราะทั้งกลุ่มจะประกาศงบพร้อมกัน และทุกอย่างจะอธิบายให้รู้ว่า การยืนปิดที่ระดับ 50.50 บาท ลบไป 1.50 บาท หรือลงไป 2.90% ด้วยมูลค่าการซื้อขาย 586 ล้านบาท เมคเซ้นส์ขนาดไหนจ้า!
# สถานการณ์ข้างต้นทำให้ “โมนิก้า” ต้องขอเอ่ยถึงหุ้นลีสซิ่งตัวแม่อย่าง SAWAD ขึ้นมาอีกครั้ง เพราะกราฟหุ้นสวนทางกับหุ้นลีสซิ่งตัวอื่นที่อยู่ในขาลง แถมเมื่อวันศุกร์ยังสามารถยืนปิดที่ระดับ 55.50 บาท บวกไป 0.50 บาท หรือขึ้นไป 0.90% ด้วยมูลค่าการซื้อขาย 357 ล้านบาท ทั้งที่ภาพรวมของตลาดหุ้นแดงโร่แบบนี้ กลายเป็นภาพสะท้อนที่ส่งสัญญาณให้รู้ว่า หุ้นมีโอกาส “ไปต่อ” กระมัง!..ลองไปคิดดูนะจ๊ะ
# ส่วนรายที่ขึ้นต่อเนื่องเป็นเวลานาน “โมนิก้า” คงมองไปที่เสือซุ่มอย่าง AP เป็นรายถัดมาแบบไม่ลังเลใจ หลังราคาหุ้นไต่เพดานบินอย่างช้า ๆ เป็นเวลาร่วม 5 เดือน เดี๊ยนถึงอยากให้แฟนคลับประเมินการยืนปิดที่ระดับ 12.30 บาท บวกไป 0.50 บาท หรือขึ้นไป 4.25% ด้วยมูลค่าการซื้อขาย 737 ล้านบาท ท่ามกลาง PE 6.50 เท่า พ่วงด้วยยีลด์ในระดับ 4% คือทางเลือกอันดับต้น ๆ ของคนที่มีเงินเย็นใช่อ๊ะป่าว?
# ปิดท้ายกันที่หุ้นร้อนอย่าง MPIC กันดีกว่า เพราะการทะยานขึ้นอย่างบ้าคลั่งในเที่ยวนี้ เขาว่ากันว่า เจ้าของมีแผนเตรียมขายทิ้ง และดูเหมือนการเจรจาเที่ยวนี้จะคืบหน้าไปมาก บรรดานกรู้ถึงกระโจนใส่อย่างเมามันร่วม 2 สัปดาห์ ซึ่งเป็นการพลิกหุ้นแบบสุดขั้ว และทำให้ราคาหุ้นพุ่งขึ้นไปทำราคาสูงสุดที่ระดับ 2.76 บาท ก่อนจะโรยตัวลงมาปิดที่ 2.40 บาท บวกไป 0.02 บาท หรือขึ้นไป 0.85% ด้วยมูลค่าการซื้อขาย 68 ล้านบาท และเมื่อเทียบกับค่าตัวก่อนหน้านี้อยู่ที่ 1.40 บาท น้องโมบอกได้แค่ว่า ไม่ธรรมดานะจะบอกให้
# Tags
# AP
# JMT
# MPIC
# เจาะกระดาน
# หุ้นไทย
# หุ้นวันนี้
# ข่าวหุ้นวันนี้
# โมนิก้า
# SET
# CPF
# หุ้นเด่น
# SCB
# SAWAD
# 3806
# [('2023-02-13 00:00:00', 'ขายหนีตาย?', 'https://www.kaohoon.com/column/588002', 'JMT')]
# https://www.kaohoon.com/column/588002
# ขายหนีตาย?
# 2023-02-13 00:00:00
# JMT
# สถานการณ์ของตลาดหุ้นไทยเมื่อสัปดาห์ที่ผ่านมา สร้างความเจ็บช้ำให้กับเดี๊ยนเป็นอย่างมาก เพราะโดนรินขายตั้งแต่ต้นสัปดาห์ และโดนขายหนักสุดในช่วงกลางสัปดาห์ ก่อนที่ดัชนีจะไหลลงมาเรื่อย ๆ จนสุดท้ายยืนปิดที่ระดับ 1,664.57จุด ลบไป 4.60 จุด ด้วยมูลค่าการซื้อขาย 5.89 หมื่นล้านบาท ซึ่งสวนทางกับปัจจัยบวกที่ทยอยถูกเปิดออกมาทีละเรื่องแบบนี้..เป็นใครไม่โซแซดบ้างล่ะคะ
# โดยเฉพาะการขายหุ้นอย่างหนักของพวก “กองทุน” กับ “ต่างชาติ” ถือเป็นแรงฉุดที่ทำให้ทุกอย่างเปลี่ยนไปในทางร้ายจนยากที่จะกู้กลับให้มาดีดั่งเดิม และยังทำให้โมเมนตัมของตลาดหุ้นเปลี่ยนเป็นแกว่งตัวลงแบบนี้ “โมนิก้า” คงพูดได้แค่ว่า ขายหนีตายดีกว่ากระมัง! เพราะสถานการณ์หลายอย่างเปลี่ยนไปจากที่คาดการณ์ไว้แบบสุดกู่ เดี๊ยนเลยไม่อยากจะฝืนเชื่อในสิ่งที่เริ่มเป็นไปไม่ได้นะจ๊ะ
# เนื่องจากก่อนหน้านี้ “โมนิก้า” ได้จำลองสถานการณ์ตลาดหุ้นไทยว่า ไม่มีเรื่องไหนที่ต้องกังวลอีกแล้ว หลังตลาดหุ้นไทยตอบรับกับข่าวร้ายไปหมดแล้ว และที่เหลือก็เป็นเรื่องของผลงานจะฟื้นตัวขนาดไหน? พอเอาเข้าจริงดันกลายเป็นหนังคนละม้วน เดี๊ยนมองว่า วันนี้ตลาดหุ้นไทยควรจะเด้งกลับเสียที! หากไม่เด้งเหมือนที่สัญญาณเทคนิคบอกไว้ ก็ต้องยอมตัดใจเพื่อไม่ให้เจ็บหนักไปกว่านี้นะคะ
# เหมือนกับการไหลลงของแบงก์ตราใบโพธิ์ SCB ก็เป็นเรื่องที่สร้างความประหลาดใจให้กับ “โมนิก้า” มากพอสมควร เพราะเมื่อดูตามท้องเรื่องที่เกิดขึ้น ไม่น่าจะมีประเด็นไหนที่กดราคาหุ้นลงมาต่ำร้อย แต่สุดท้ายราคาหุ้นก็ลงมายืนจ่อที่ระดับ 100.50 บาท ลบไป 3 บาท หรือลงไป 2.90% ด้วยมูลค่าการซื้อขาย 3 พันล้านบาท จึงกลายเป็นจังหวะที่ต้องชิ่งหนีโดยด่วน หากวันนี้ไม่เด้งกลับอย่างมั่นคงเจ้าค่ะ
# ส่วนรายที่อยู่ในทิศทางลงลูกเดียว จนหาทางกลับบ้านไม่เจอ “โมนิก้า” คงมองไปที่หุ้นขายไก่ขายหมู CPF แบบไม่ลังเลใจ เพราะดูจากโอกาสในการทำกำไรสวย ๆ มันแทบจะเป็นไปไม่ได้เลย ไม่ว่าจะราคาเนื้อสัตว์ที่อยู่ในช่วงลงต่อเนื่อง และเรื่องต้นทุนอาหารสัตว์ที่สูงขึ้น หรือแม้กระทั่งความกังวลเกี่ยวกับไข้หวัดนก ล้วนเป็นประเด็นที่กดดันให้นักเล่นต้องขายหุ้นออกไปก่อน และทำให้หุ้นลงมาปิดที่ 22.90 บาท ลบไป 0.30 บาท หรือลงไป 1.30% ด้วยมูลค่าการซื้อขาย 650 ล้านบาทไงล่ะคะ
# JMT โชว์งบปี 65 กำไร 1.7 พันลบ. รับส่วนแบ่งกำไร JK AMC หนุน
# BEM โบรกแนะซื้อเป้า 10.80 บ. รับผู้โดยสาร MRT ม.ค. โตทะลัก 114% แตะ 3.7 แสนเที่ยว/วัน
# ในเมื่อเม้าท์ถึงหุ้นที่มีแรงกดดันเยอะ และราคาหุ้นเอาแต่ลงอย่างเดียว “โมนิก้า” คงต้องมองไปที่หุ้น JMT แบบไม่ลังเลใจแม้แต่นิดเดียว เพราะเป็นหุ้นที่แมงลือเม้าท์กันให้แซ่ดว่า กำไรจะออกมาเท่านั้น..กำไรจะออกมาเท่านี้ เดี๊ยนเลยอยากแจ้งให้ทุกคนรู้ว่า วันนี้รู้กัน! เพราะทั้งกลุ่มจะประกาศงบพร้อมกัน และทุกอย่างจะอธิบายให้รู้ว่า การยืนปิดที่ระดับ 50.50 บาท ลบไป 1.50 บาท หรือลงไป 2.90% ด้วยมูลค่าการซื้อขาย 586 ล้านบาท เมคเซ้นส์ขนาดไหนจ้า!
# สถานการณ์ข้างต้นทำให้ “โมนิก้า” ต้องขอเอ่ยถึงหุ้นลีสซิ่งตัวแม่อย่าง SAWAD ขึ้นมาอีกครั้ง เพราะกราฟหุ้นสวนทางกับหุ้นลีสซิ่งตัวอื่นที่อยู่ในขาลง แถมเมื่อวันศุกร์ยังสามารถยืนปิดที่ระดับ 55.50 บาท บวกไป 0.50 บาท หรือขึ้นไป 0.90% ด้วยมูลค่าการซื้อขาย 357 ล้านบาท ทั้งที่ภาพรวมของตลาดหุ้นแดงโร่แบบนี้ กลายเป็นภาพสะท้อนที่ส่งสัญญาณให้รู้ว่า หุ้นมีโอกาส “ไปต่อ” กระมัง!..ลองไปคิดดูนะจ๊ะ
# ส่วนรายที่ขึ้นต่อเนื่องเป็นเวลานาน “โมนิก้า” คงมองไปที่เสือซุ่มอย่าง AP เป็นรายถัดมาแบบไม่ลังเลใจ หลังราคาหุ้นไต่เพดานบินอย่างช้า ๆ เป็นเวลาร่วม 5 เดือน เดี๊ยนถึงอยากให้แฟนคลับประเมินการยืนปิดที่ระดับ 12.30 บาท บวกไป 0.50 บาท หรือขึ้นไป 4.25% ด้วยมูลค่าการซื้อขาย 737 ล้านบาท ท่ามกลาง PE 6.50 เท่า พ่วงด้วยยีลด์ในระดับ 4% คือทางเลือกอันดับต้น ๆ ของคนที่มีเงินเย็นใช่อ๊ะป่าว?
# ปิดท้ายกันที่หุ้นร้อนอย่าง MPIC กันดีกว่า เพราะการทะยานขึ้นอย่างบ้าคลั่งในเที่ยวนี้ เขาว่ากันว่า เจ้าของมีแผนเตรียมขายทิ้ง และดูเหมือนการเจรจาเที่ยวนี้จะคืบหน้าไปมาก บรรดานกรู้ถึงกระโจนใส่อย่างเมามันร่วม 2 สัปดาห์ ซึ่งเป็นการพลิกหุ้นแบบสุดขั้ว และทำให้ราคาหุ้นพุ่งขึ้นไปทำราคาสูงสุดที่ระดับ 2.76 บาท ก่อนจะโรยตัวลงมาปิดที่ 2.40 บาท บวกไป 0.02 บาท หรือขึ้นไป 0.85% ด้วยมูลค่าการซื้อขาย 68 ล้านบาท และเมื่อเทียบกับค่าตัวก่อนหน้านี้อยู่ที่ 1.40 บาท น้องโมบอกได้แค่ว่า ไม่ธรรมดานะจะบอกให้
# Tags
# AP
# JMT
# MPIC
# เจาะกระดาน
# หุ้นไทย
# หุ้นวันนี้
# ข่าวหุ้นวันนี้
# โมนิก้า
# SET
# CPF
# หุ้นเด่น
# SCB
# SAWAD
# 3806
# [('2023-02-13 00:00:00', 'ขายหนีตาย?', 'https://www.kaohoon.com/column/588002', 'CPF')]
# https://www.kaohoon.com/column/588002
# ขายหนีตาย?
# 2023-02-13 00:00:00
# CPF
# สถานการณ์ของตลาดหุ้นไทยเมื่อสัปดาห์ที่ผ่านมา สร้างความเจ็บช้ำให้กับเดี๊ยนเป็นอย่างมาก เพราะโดนรินขายตั้งแต่ต้นสัปดาห์ และโดนขายหนักสุดในช่วงกลางสัปดาห์ ก่อนที่ดัชนีจะไหลลงมาเรื่อย ๆ จนสุดท้ายยืนปิดที่ระดับ 1,664.57จุด ลบไป 4.60 จุด ด้วยมูลค่าการซื้อขาย 5.89 หมื่นล้านบาท ซึ่งสวนทางกับปัจจัยบวกที่ทยอยถูกเปิดออกมาทีละเรื่องแบบนี้..เป็นใครไม่โซแซดบ้างล่ะคะ
# โดยเฉพาะการขายหุ้นอย่างหนักของพวก “กองทุน” กับ “ต่างชาติ” ถือเป็นแรงฉุดที่ทำให้ทุกอย่างเปลี่ยนไปในทางร้ายจนยากที่จะกู้กลับให้มาดีดั่งเดิม และยังทำให้โมเมนตัมของตลาดหุ้นเปลี่ยนเป็นแกว่งตัวลงแบบนี้ “โมนิก้า” คงพูดได้แค่ว่า ขายหนีตายดีกว่ากระมัง! เพราะสถานการณ์หลายอย่างเปลี่ยนไปจากที่คาดการณ์ไว้แบบสุดกู่ เดี๊ยนเลยไม่อยากจะฝืนเชื่อในสิ่งที่เริ่มเป็นไปไม่ได้นะจ๊ะ
# เนื่องจากก่อนหน้านี้ “โมนิก้า” ได้จำลองสถานการณ์ตลาดหุ้นไทยว่า ไม่มีเรื่องไหนที่ต้องกังวลอีกแล้ว หลังตลาดหุ้นไทยตอบรับกับข่าวร้ายไปหมดแล้ว และที่เหลือก็เป็นเรื่องของผลงานจะฟื้นตัวขนาดไหน? พอเอาเข้าจริงดันกลายเป็นหนังคนละม้วน เดี๊ยนมองว่า วันนี้ตลาดหุ้นไทยควรจะเด้งกลับเสียที! หากไม่เด้งเหมือนที่สัญญาณเทคนิคบอกไว้ ก็ต้องยอมตัดใจเพื่อไม่ให้เจ็บหนักไปกว่านี้นะคะ
# เหมือนกับการไหลลงของแบงก์ตราใบโพธิ์ SCB ก็เป็นเรื่องที่สร้างความประหลาดใจให้กับ “โมนิก้า” มากพอสมควร เพราะเมื่อดูตามท้องเรื่องที่เกิดขึ้น ไม่น่าจะมีประเด็นไหนที่กดราคาหุ้นลงมาต่ำร้อย แต่สุดท้ายราคาหุ้นก็ลงมายืนจ่อที่ระดับ 100.50 บาท ลบไป 3 บาท หรือลงไป 2.90% ด้วยมูลค่าการซื้อขาย 3 พันล้านบาท จึงกลายเป็นจังหวะที่ต้องชิ่งหนีโดยด่วน หากวันนี้ไม่เด้งกลับอย่างมั่นคงเจ้าค่ะ
# ส่วนรายที่อยู่ในทิศทางลงลูกเดียว จนหาทางกลับบ้านไม่เจอ “โมนิก้า” คงมองไปที่หุ้นขายไก่ขายหมู CPF แบบไม่ลังเลใจ เพราะดูจากโอกาสในการทำกำไรสวย ๆ มันแทบจะเป็นไปไม่ได้เลย ไม่ว่าจะราคาเนื้อสัตว์ที่อยู่ในช่วงลงต่อเนื่อง และเรื่องต้นทุนอาหารสัตว์ที่สูงขึ้น หรือแม้กระทั่งความกังวลเกี่ยวกับไข้หวัดนก ล้วนเป็นประเด็นที่กดดันให้นักเล่นต้องขายหุ้นออกไปก่อน และทำให้หุ้นลงมาปิดที่ 22.90 บาท ลบไป 0.30 บาท หรือลงไป 1.30% ด้วยมูลค่าการซื้อขาย 650 ล้านบาทไงล่ะคะ
# JMT โชว์งบปี 65 กำไร 1.7 พันลบ. รับส่วนแบ่งกำไร JK AMC หนุน
# BEM โบรกแนะซื้อเป้า 10.80 บ. รับผู้โดยสาร MRT ม.ค. โตทะลัก 114% แตะ 3.7 แสนเที่ยว/วัน
# ในเมื่อเม้าท์ถึงหุ้นที่มีแรงกดดันเยอะ และราคาหุ้นเอาแต่ลงอย่างเดียว “โมนิก้า” คงต้องมองไปที่หุ้น JMT แบบไม่ลังเลใจแม้แต่นิดเดียว เพราะเป็นหุ้นที่แมงลือเม้าท์กันให้แซ่ดว่า กำไรจะออกมาเท่านั้น..กำไรจะออกมาเท่านี้ เดี๊ยนเลยอยากแจ้งให้ทุกคนรู้ว่า วันนี้รู้กัน! เพราะทั้งกลุ่มจะประกาศงบพร้อมกัน และทุกอย่างจะอธิบายให้รู้ว่า การยืนปิดที่ระดับ 50.50 บาท ลบไป 1.50 บาท หรือลงไป 2.90% ด้วยมูลค่าการซื้อขาย 586 ล้านบาท เมคเซ้นส์ขนาดไหนจ้า!
# สถานการณ์ข้างต้นทำให้ “โมนิก้า” ต้องขอเอ่ยถึงหุ้นลีสซิ่งตัวแม่อย่าง SAWAD ขึ้นมาอีกครั้ง เพราะกราฟหุ้นสวนทางกับหุ้นลีสซิ่งตัวอื่นที่อยู่ในขาลง แถมเมื่อวันศุกร์ยังสามารถยืนปิดที่ระดับ 55.50 บาท บวกไป 0.50 บาท หรือขึ้นไป 0.90% ด้วยมูลค่าการซื้อขาย 357 ล้านบาท ทั้งที่ภาพรวมของตลาดหุ้นแดงโร่แบบนี้ กลายเป็นภาพสะท้อนที่ส่งสัญญาณให้รู้ว่า หุ้นมีโอกาส “ไปต่อ” กระมัง!..ลองไปคิดดูนะจ๊ะ
# ส่วนรายที่ขึ้นต่อเนื่องเป็นเวลานาน “โมนิก้า” คงมองไปที่เสือซุ่มอย่าง AP เป็นรายถัดมาแบบไม่ลังเลใจ หลังราคาหุ้นไต่เพดานบินอย่างช้า ๆ เป็นเวลาร่วม 5 เดือน เดี๊ยนถึงอยากให้แฟนคลับประเมินการยืนปิดที่ระดับ 12.30 บาท บวกไป 0.50 บาท หรือขึ้นไป 4.25% ด้วยมูลค่าการซื้อขาย 737 ล้านบาท ท่ามกลาง PE 6.50 เท่า พ่วงด้วยยีลด์ในระดับ 4% คือทางเลือกอันดับต้น ๆ ของคนที่มีเงินเย็นใช่อ๊ะป่าว?
# ปิดท้ายกันที่หุ้นร้อนอย่าง MPIC กันดีกว่า เพราะการทะยานขึ้นอย่างบ้าคลั่งในเที่ยวนี้ เขาว่ากันว่า เจ้าของมีแผนเตรียมขายทิ้ง และดูเหมือนการเจรจาเที่ยวนี้จะคืบหน้าไปมาก บรรดานกรู้ถึงกระโจนใส่อย่างเมามันร่วม 2 สัปดาห์ ซึ่งเป็นการพลิกหุ้นแบบสุดขั้ว และทำให้ราคาหุ้นพุ่งขึ้นไปทำราคาสูงสุดที่ระดับ 2.76 บาท ก่อนจะโรยตัวลงมาปิดที่ 2.40 บาท บวกไป 0.02 บาท หรือขึ้นไป 0.85% ด้วยมูลค่าการซื้อขาย 68 ล้านบาท และเมื่อเทียบกับค่าตัวก่อนหน้านี้อยู่ที่ 1.40 บาท น้องโมบอกได้แค่ว่า ไม่ธรรมดานะจะบอกให้
# Tags
# AP
# JMT
# MPIC
# เจาะกระดาน
# หุ้นไทย
# หุ้นวันนี้
# ข่าวหุ้นวันนี้
# โมนิก้า
# SET
# CPF
# หุ้นเด่น
# SCB
# SAWAD
# 3806
# [('2023-02-13 00:00:00', 'ขายหนีตาย?', 'https://www.kaohoon.com/column/588002', 'SCB')]
# https://www.kaohoon.com/column/588002
# ขายหนีตาย?
# 2023-02-13 00:00:00
# SCB
# สถานการณ์ของตลาดหุ้นไทยเมื่อสัปดาห์ที่ผ่านมา สร้างความเจ็บช้ำให้กับเดี๊ยนเป็นอย่างมาก เพราะโดนรินขายตั้งแต่ต้นสัปดาห์ และโดนขายหนักสุดในช่วงกลางสัปดาห์ ก่อนที่ดัชนีจะไหลลงมาเรื่อย ๆ จนสุดท้ายยืนปิดที่ระดับ 1,664.57จุด ลบไป 4.60 จุด ด้วยมูลค่าการซื้อขาย 5.89 หมื่นล้านบาท ซึ่งสวนทางกับปัจจัยบวกที่ทยอยถูกเปิดออกมาทีละเรื่องแบบนี้..เป็นใครไม่โซแซดบ้างล่ะคะ
# โดยเฉพาะการขายหุ้นอย่างหนักของพวก “กองทุน” กับ “ต่างชาติ” ถือเป็นแรงฉุดที่ทำให้ทุกอย่างเปลี่ยนไปในทางร้ายจนยากที่จะกู้กลับให้มาดีดั่งเดิม และยังทำให้โมเมนตัมของตลาดหุ้นเปลี่ยนเป็นแกว่งตัวลงแบบนี้ “โมนิก้า” คงพูดได้แค่ว่า ขายหนีตายดีกว่ากระมัง! เพราะสถานการณ์หลายอย่างเปลี่ยนไปจากที่คาดการณ์ไว้แบบสุดกู่ เดี๊ยนเลยไม่อยากจะฝืนเชื่อในสิ่งที่เริ่มเป็นไปไม่ได้นะจ๊ะ
# เนื่องจากก่อนหน้านี้ “โมนิก้า” ได้จำลองสถานการณ์ตลาดหุ้นไทยว่า ไม่มีเรื่องไหนที่ต้องกังวลอีกแล้ว หลังตลาดหุ้นไทยตอบรับกับข่าวร้ายไปหมดแล้ว และที่เหลือก็เป็นเรื่องของผลงานจะฟื้นตัวขนาดไหน? พอเอาเข้าจริงดันกลายเป็นหนังคนละม้วน เดี๊ยนมองว่า วันนี้ตลาดหุ้นไทยควรจะเด้งกลับเสียที! หากไม่เด้งเหมือนที่สัญญาณเทคนิคบอกไว้ ก็ต้องยอมตัดใจเพื่อไม่ให้เจ็บหนักไปกว่านี้นะคะ
# เหมือนกับการไหลลงของแบงก์ตราใบโพธิ์ SCB ก็เป็นเรื่องที่สร้างความประหลาดใจให้กับ “โมนิก้า” มากพอสมควร เพราะเมื่อดูตามท้องเรื่องที่เกิดขึ้น ไม่น่าจะมีประเด็นไหนที่กดราคาหุ้นลงมาต่ำร้อย แต่สุดท้ายราคาหุ้นก็ลงมายืนจ่อที่ระดับ 100.50 บาท ลบไป 3 บาท หรือลงไป 2.90% ด้วยมูลค่าการซื้อขาย 3 พันล้านบาท จึงกลายเป็นจังหวะที่ต้องชิ่งหนีโดยด่วน หากวันนี้ไม่เด้งกลับอย่างมั่นคงเจ้าค่ะ
# ส่วนรายที่อยู่ในทิศทางลงลูกเดียว จนหาทางกลับบ้านไม่เจอ “โมนิก้า” คงมองไปที่หุ้นขายไก่ขายหมู CPF แบบไม่ลังเลใจ เพราะดูจากโอกาสในการทำกำไรสวย ๆ มันแทบจะเป็นไปไม่ได้เลย ไม่ว่าจะราคาเนื้อสัตว์ที่อยู่ในช่วงลงต่อเนื่อง และเรื่องต้นทุนอาหารสัตว์ที่สูงขึ้น หรือแม้กระทั่งความกังวลเกี่ยวกับไข้หวัดนก ล้วนเป็นประเด็นที่กดดันให้นักเล่นต้องขายหุ้นออกไปก่อน และทำให้หุ้นลงมาปิดที่ 22.90 บาท ลบไป 0.30 บาท หรือลงไป 1.30% ด้วยมูลค่าการซื้อขาย 650 ล้านบาทไงล่ะคะ
# JMT โชว์งบปี 65 กำไร 1.7 พันลบ. รับส่วนแบ่งกำไร JK AMC หนุน
# BEM โบรกแนะซื้อเป้า 10.80 บ. รับผู้โดยสาร MRT ม.ค. โตทะลัก 114% แตะ 3.7 แสนเที่ยว/วัน
# ในเมื่อเม้าท์ถึงหุ้นที่มีแรงกดดันเยอะ และราคาหุ้นเอาแต่ลงอย่างเดียว “โมนิก้า” คงต้องมองไปที่หุ้น JMT แบบไม่ลังเลใจแม้แต่นิดเดียว เพราะเป็นหุ้นที่แมงลือเม้าท์กันให้แซ่ดว่า กำไรจะออกมาเท่านั้น..กำไรจะออกมาเท่านี้ เดี๊ยนเลยอยากแจ้งให้ทุกคนรู้ว่า วันนี้รู้กัน! เพราะทั้งกลุ่มจะประกาศงบพร้อมกัน และทุกอย่างจะอธิบายให้รู้ว่า การยืนปิดที่ระดับ 50.50 บาท ลบไป 1.50 บาท หรือลงไป 2.90% ด้วยมูลค่าการซื้อขาย 586 ล้านบาท เมคเซ้นส์ขนาดไหนจ้า!
# สถานการณ์ข้างต้นทำให้ “โมนิก้า” ต้องขอเอ่ยถึงหุ้นลีสซิ่งตัวแม่อย่าง SAWAD ขึ้นมาอีกครั้ง เพราะกราฟหุ้นสวนทางกับหุ้นลีสซิ่งตัวอื่นที่อยู่ในขาลง แถมเมื่อวันศุกร์ยังสามารถยืนปิดที่ระดับ 55.50 บาท บวกไป 0.50 บาท หรือขึ้นไป 0.90% ด้วยมูลค่าการซื้อขาย 357 ล้านบาท ทั้งที่ภาพรวมของตลาดหุ้นแดงโร่แบบนี้ กลายเป็นภาพสะท้อนที่ส่งสัญญาณให้รู้ว่า หุ้นมีโอกาส “ไปต่อ” กระมัง!..ลองไปคิดดูนะจ๊ะ
# ส่วนรายที่ขึ้นต่อเนื่องเป็นเวลานาน “โมนิก้า” คงมองไปที่เสือซุ่มอย่าง AP เป็นรายถัดมาแบบไม่ลังเลใจ หลังราคาหุ้นไต่เพดานบินอย่างช้า ๆ เป็นเวลาร่วม 5 เดือน เดี๊ยนถึงอยากให้แฟนคลับประเมินการยืนปิดที่ระดับ 12.30 บาท บวกไป 0.50 บาท หรือขึ้นไป 4.25% ด้วยมูลค่าการซื้อขาย 737 ล้านบาท ท่ามกลาง PE 6.50 เท่า พ่วงด้วยยีลด์ในระดับ 4% คือทางเลือกอันดับต้น ๆ ของคนที่มีเงินเย็นใช่อ๊ะป่าว?
# ปิดท้ายกันที่หุ้นร้อนอย่าง MPIC กันดีกว่า เพราะการทะยานขึ้นอย่างบ้าคลั่งในเที่ยวนี้ เขาว่ากันว่า เจ้าของมีแผนเตรียมขายทิ้ง และดูเหมือนการเจรจาเที่ยวนี้จะคืบหน้าไปมาก บรรดานกรู้ถึงกระโจนใส่อย่างเมามันร่วม 2 สัปดาห์ ซึ่งเป็นการพลิกหุ้นแบบสุดขั้ว และทำให้ราคาหุ้นพุ่งขึ้นไปทำราคาสูงสุดที่ระดับ 2.76 บาท ก่อนจะโรยตัวลงมาปิดที่ 2.40 บาท บวกไป 0.02 บาท หรือขึ้นไป 0.85% ด้วยมูลค่าการซื้อขาย 68 ล้านบาท และเมื่อเทียบกับค่าตัวก่อนหน้านี้อยู่ที่ 1.40 บาท น้องโมบอกได้แค่ว่า ไม่ธรรมดานะจะบอกให้
# Tags
# AP
# JMT
# MPIC
# เจาะกระดาน
# หุ้นไทย
# หุ้นวันนี้
# ข่าวหุ้นวันนี้
# โมนิก้า
# SET
# CPF
# หุ้นเด่น
# SCB
# SAWAD
# 3806
# [('2023-02-13 00:00:00', 'ขายหนีตาย?', 'https://www.kaohoon.com/column/588002', 'SAWAD')]
# https://www.kaohoon.com/column/588002
# ขายหนีตาย?
# 2023-02-13 00:00:00
# SAWAD
# ADVERTISEMENT
# สถานการณ์ของตลาดหุ้นไทยเมื่อสัปดาห์ที่ผ่านมา สร้างความเจ็บช้ำให้กับเดี๊ยนเป็นอย่างมาก เพราะโดนรินขายตั้งแต่ต้นสัปดาห์ และโดนขายหนักสุดในช่วงกลางสัปดาห์ ก่อนที่ดัชนีจะไหลลงมาเรื่อย ๆ จนสุดท้ายยืนปิดที่ระดับ 1,664.57จุด ลบไป 4.60 จุด ด้วยมูลค่าการซื้อขาย 5.89 หมื่นล้านบาท ซึ่งสวนทางกับปัจจัยบวกที่ทยอยถูกเปิดออกมาทีละเรื่องแบบนี้..เป็นใครไม่โซแซดบ้างล่ะคะ
# โดยเฉพาะการขายหุ้นอย่างหนักของพวก “กองทุน” กับ “ต่างชาติ” ถือเป็นแรงฉุดที่ทำให้ทุกอย่างเปลี่ยนไปในทางร้ายจนยากที่จะกู้กลับให้มาดีดั่งเดิม และยังทำให้โมเมนตัมของตลาดหุ้นเปลี่ยนเป็นแกว่งตัวลงแบบนี้ “โมนิก้า” คงพูดได้แค่ว่า ขายหนีตายดีกว่ากระมัง! เพราะสถานการณ์หลายอย่างเปลี่ยนไปจากที่คาดการณ์ไว้แบบสุดกู่ เดี๊ยนเลยไม่อยากจะฝืนเชื่อในสิ่งที่เริ่มเป็นไปไม่ได้นะจ๊ะ
# เนื่องจากก่อนหน้านี้ “โมนิก้า” ได้จำลองสถานการณ์ตลาดหุ้นไทยว่า ไม่มีเรื่องไหนที่ต้องกังวลอีกแล้ว หลังตลาดหุ้นไทยตอบรับกับข่าวร้ายไปหมดแล้ว และที่เหลือก็เป็นเรื่องของผลงานจะฟื้นตัวขนาดไหน? พอเอาเข้าจริงดันกลายเป็นหนังคนละม้วน เดี๊ยนมองว่า วันนี้ตลาดหุ้นไทยควรจะเด้งกลับเสียที! หากไม่เด้งเหมือนที่สัญญาณเทคนิคบอกไว้ ก็ต้องยอมตัดใจเพื่อไม่ให้เจ็บหนักไปกว่านี้นะคะ
# เหมือนกับการไหลลงของแบงก์ตราใบโพธิ์ SCB ก็เป็นเรื่องที่สร้างความประหลาดใจให้กับ “โมนิก้า” มากพอสมควร เพราะเมื่อดูตามท้องเรื่องที่เกิดขึ้น ไม่น่าจะมีประเด็นไหนที่กดราคาหุ้นลงมาต่ำร้อย แต่สุดท้ายราคาหุ้นก็ลงมายืนจ่อที่ระดับ 100.50 บาท ลบไป 3 บาท หรือลงไป 2.90% ด้วยมูลค่าการซื้อขาย 3 พันล้านบาท จึงกลายเป็นจังหวะที่ต้องชิ่งหนีโดยด่วน หากวันนี้ไม่เด้งกลับอย่างมั่นคงเจ้าค่ะ
# ส่วนรายที่อยู่ในทิศทางลงลูกเดียว จนหาทางกลับบ้านไม่เจอ “โมนิก้า” คงมองไปที่หุ้นขายไก่ขายหมู CPF แบบไม่ลังเลใจ เพราะดูจากโอกาสในการทำกำไรสวย ๆ มันแทบจะเป็นไปไม่ได้เลย ไม่ว่าจะราคาเนื้อสัตว์ที่อยู่ในช่วงลงต่อเนื่อง และเรื่องต้นทุนอาหารสัตว์ที่สูงขึ้น หรือแม้กระทั่งความกังวลเกี่ยวกับไข้หวัดนก ล้วนเป็นประเด็นที่กดดันให้นักเล่นต้องขายหุ้นออกไปก่อน และทำให้หุ้นลงมาปิดที่ 22.90 บาท ลบไป 0.30 บาท หรือลงไป 1.30% ด้วยมูลค่าการซื้อขาย 650 ล้านบาทไงล่ะคะ
# JMT โชว์งบปี 65 กำไร 1.7 พันลบ. รับส่วนแบ่งกำไร JK AMC หนุน
# BEM โบรกแนะซื้อเป้า 10.80 บ. รับผู้โดยสาร MRT ม.ค. โตทะลัก 114% แตะ 3.7 แสนเที่ยว/วัน
# ในเมื่อเม้าท์ถึงหุ้นที่มีแรงกดดันเยอะ และราคาหุ้นเอาแต่ลงอย่างเดียว “โมนิก้า” คงต้องมองไปที่หุ้น JMT แบบไม่ลังเลใจแม้แต่นิดเดียว เพราะเป็นหุ้นที่แมงลือเม้าท์กันให้แซ่ดว่า กำไรจะออกมาเท่านั้น..กำไรจะออกมาเท่านี้ เดี๊ยนเลยอยากแจ้งให้ทุกคนรู้ว่า วันนี้รู้กัน! เพราะทั้งกลุ่มจะประกาศงบพร้อมกัน และทุกอย่างจะอธิบายให้รู้ว่า การยืนปิดที่ระดับ 50.50 บาท ลบไป 1.50 บาท หรือลงไป 2.90% ด้วยมูลค่าการซื้อขาย 586 ล้านบาท เมคเซ้นส์ขนาดไหนจ้า!
# สถานการณ์ข้างต้นทำให้ “โมนิก้า” ต้องขอเอ่ยถึงหุ้นลีสซิ่งตัวแม่อย่าง SAWAD ขึ้นมาอีกครั้ง เพราะกราฟหุ้นสวนทางกับหุ้นลีสซิ่งตัวอื่นที่อยู่ในขาลง แถมเมื่อวันศุกร์ยังสามารถยืนปิดที่ระดับ 55.50 บาท บวกไป 0.50 บาท หรือขึ้นไป 0.90% ด้วยมูลค่าการซื้อขาย 357 ล้านบาท ทั้งที่ภาพรวมของตลาดหุ้นแดงโร่แบบนี้ กลายเป็นภาพสะท้อนที่ส่งสัญญาณให้รู้ว่า หุ้นมีโอกาส “ไปต่อ” กระมัง!..ลองไปคิดดูนะจ๊ะ
# ส่วนรายที่ขึ้นต่อเนื่องเป็นเวลานาน “โมนิก้า” คงมองไปที่เสือซุ่มอย่าง AP เป็นรายถัดมาแบบไม่ลังเลใจ หลังราคาหุ้นไต่เพดานบินอย่างช้า ๆ เป็นเวลาร่วม 5 เดือน เดี๊ยนถึงอยากให้แฟนคลับประเมินการยืนปิดที่ระดับ 12.30 บาท บวกไป 0.50 บาท หรือขึ้นไป 4.25% ด้วยมูลค่าการซื้อขาย 737 ล้านบาท ท่ามกลาง PE 6.50 เท่า พ่วงด้วยยีลด์ในระดับ 4% คือทางเลือกอันดับต้น ๆ ของคนที่มีเงินเย็นใช่อ๊ะป่าว?
# ปิดท้ายกันที่หุ้นร้อนอย่าง MPIC กันดีกว่า เพราะการทะยานขึ้นอย่างบ้าคลั่งในเที่ยวนี้ เขาว่ากันว่า เจ้าของมีแผนเตรียมขายทิ้ง และดูเหมือนการเจรจาเที่ยวนี้จะคืบหน้าไปมาก บรรดานกรู้ถึงกระโจนใส่อย่างเมามันร่วม 2 สัปดาห์ ซึ่งเป็นการพลิกหุ้นแบบสุดขั้ว และทำให้ราคาหุ้นพุ่งขึ้นไปทำราคาสูงสุดที่ระดับ 2.76 บาท ก่อนจะโรยตัวลงมาปิดที่ 2.40 บาท บวกไป 0.02 บาท หรือขึ้นไป 0.85% ด้วยมูลค่าการซื้อขาย 68 ล้านบาท และเมื่อเทียบกับค่าตัวก่อนหน้านี้อยู่ที่ 1.40 บาท น้องโมบอกได้แค่ว่า ไม่ธรรมดานะจะบอกให้
# Tags
# AP
# JMT
# MPIC
# เจาะกระดาน
# หุ้นไทย
# หุ้นวันนี้
# ข่าวหุ้นวันนี้
# โมนิก้า
# SET
# CPF
# หุ้นเด่น
# SCB
# SAWAD
# 3820
# ---------------------------------------------------
# ---------------------------------------------------
# [('2023-02-13 00:00:00', 'มองตลาดหุ้นไทยปรับฐานเดือน ก.พ.', 'https://www.kaohoon.com/column/588000', 'CPF')]
# https://www.kaohoon.com/column/588000
# มองตลาดหุ้นไทยปรับฐานเดือน ก.พ.
# 2023-02-13 00:00:00
# CPF
# InnovestX มองว่าการจ้างงานนอกภาคเกษตรของสหรัฐฯ เพิ่มขึ้นเกินคาดมาก ขณะที่อัตราว่างงานลดลงต่ำสุดในรอบ 53 ปี ด้านรายได้เฉลี่ยรายสัปดาห์เพิ่มขึ้น 4.7% ในเดือน ม.ค. จากปีก่อนหน้า เร่งตัวจาก 3.6% ในเดือน ธ.ค. บ่งชี้ว่า ภาพตลาดแรงงานที่ยังคงแข็งแกร่งมาก โดยเฉพาะภาคบริการ ทำให้แรงกดดันเงินเฟ้อจากค่าจ้างเริ่มกลับมาเพิ่มขึ้น โดยตัวเลขการจ้างงาน non farm ที่เพิ่มขึ้นมากและขัดแย้งกับตัวเลขการจ้างงานภาคเอกชน (ADP) ที่ชะลอแรงกว่าคาด (1.1 แสนตำแหน่งจากคาดที่ 1.7 แสนตำแหน่ง)
# บ่งชี้ว่าธุรกิจที่จ้างงานมากน่าจะเป็นธุรกิจขนาดเล็กและธุรกิจบริการมากกว่า ซึ่งในระยะสั้นยังได้รับประโยชน์จากเงินออมส่วนเกินที่ยังมีอยู่ และผู้คนอาจจะออกมาจับจ่ายในช่วงต้นปี ทำให้มี demand ของแรงงาน Unskilled worker ภาคบริการ แต่ระยะต่อไป เมื่อเศรษฐกิจชะลอมากขึ้น ก็อาจนำมาสู่การปลดคนงานได้เช่นเดียวกัน
# ในส่วนของมุมมองจากประธาน Fed ยังคงมองว่าเงินเฟ้อเริ่มลดลงแล้ว (Disinflationary process has begun) แต่จะใช้เวลายาวนาน เพราะ Disinflation เกิดในตลาดสินค้า ซึ่งเป็น 25% ของเศรษฐกิจสหรัฐ (แต่อีก 75% เป็น Service ซึ่งยังมีเงินเฟ้ออยู่) ดังนั้น ถ้าข้อมูลยังดีต่อเนื่อง เช่น ตัวเลขตลาดแรงงานและ/หรือ เงินเฟ้อยังสูงอยู่ ก็มีแนวโน้มที่จะขึ้นดอกเบี้ยสูงเกินกว่าคาด ซึ่ง InnovestX มองว่า การที่ประธาน Fed เน้นว่าเงินเฟ้อเริ่มลง แม้ว่าจะต้องใช้เวลานานกว่าจะหมดนั้น เป็นส่วนสำคัญที่ทำให้ผลตอบแทนพันธบัตรสหรัฐฯ ปรับขึ้นในช่วงที่ผ่านมา ซึ่งภาพเงินเฟ้อจะอยู่ระดับสูงยาวนานขึ้น ประกอบกับ ตัวเลขเศรษฐกิจบางตัวที่ดูแข็งแกร่งขึ้น ทำให้ Fed ต้องคงดอกเบี้ยสูงมากขึ้น และ/หรือขึ้นดอกเบี้ยต่อเนื่อง
# ภาพดังกล่าว ทำให้ InnovestX เชื่อว่า Fed จะขึ้นดอกเบี้ยถึงระดับ 5-5.25% หรือสูงกว่านั้น และมองว่าในระยะต่อไป ความผันผวนในตลาดจะมีมากขึ้น จากความเสี่ยงเงินเฟ้อ การขึ้นดอกเบี้ย และต้นทุนการเงินที่จะกลับมาเพิ่มขึ้น รวมถึงผลประกอบการที่อาจเริ่มแย่ลงมากขึ้น
# ส่วนภาพตลาดหุ้นไทย InnovestX มองว่าดัชนีจะอยู่ในช่วงปรับฐานและมี Upside จำกัด หลังตลาดมี Valuation ค่อนข้างตึงตัว อีกทั้งยังขาดปัจจัยหนุนการลงทุนใหม่ ๆ และอยู่ระหว่างรอดูผลประกอบการไตรมาส 4/65 ของ Real Sector ที่จะกำลังทยอยประกาศออกมา ดังนั้นกลยุทธ์ลงทุนจึงแนะนำ “Selective Buy” ในธีมที่มีปัจจัยบวกเฉพาะ โดยเน้นรอซื้อเมื่อราคาอ่อนตัว ไม่ไล่ราคา ดังนี้
# แรงซื้อ “บลูชิพ” พยุง SET ปิดบวก 0.32 จุด แนวโน้มพรุ่งนี้ไซด์เวย์ ลุ้นเงินเฟ้อสหรัฐ
# SET ปิดเช้ารีบาวด์ 1 จุด เก็งกำไรรายตัว-รอเงินเฟ้อสหรัฐ
# 1)หุ้นที่มองไม่ต้องระวังแรงขายจากต่างชาติ (ปี 65 ต่างชาติขายสุทธิหรือซื้อสุทธิน้อย) ขณะที่ปี 66 จากต้นปีถึงปัจจุบันต่างชาติเริ่มพลิกซื้อสุทธิหรือซื้อต่อเนื่อง เลือก SCC, AMATA, ERW
# 2)หุ้นที่ราคายัง Laggard โดยมี PBV ต่ำกว่าค่าเฉลี่ยย้อนหลัง 5 ปี และปี 2566 คาดกำไรเติบโตดีจากงวดเดียวกันของปีก่อน อีกทั้ง Valuation ยังน่าสนใจ เลือก CPF, GPSC, SCGP, HMPRO
# 3)สำหรับนักลงทุนที่ชอบหุ้นปันผล แนะนำหุ้นที่คาดหลังรายงานงบปี 2565 จะประกาศจ่ายปันผล โดยให้ Div. Yield ปี 65 (หักที่จ่ายระหว่างกาลไปแล้ว) สูงเกิน 4% และคาดขึ้น XD แล้ว ราคาหุ้นจะยังปรับขึ้นต่อได้จากผลการดำเนินงานที่เติบโตดีในปี 66 เลือก TISCO, SAT, KTB, SCCC
# ขณะที่ช่วงสั้นแนะนำให้ เพิ่มความระมัดระวัง หรือ หลีกเลี่ยงการลงทุนออกไปก่อน สำหรับหุ้นที่คาดอาจจะเผชิญแรงขายจากนักลงทุนต่างชาติ ได้แก่ KBANK, BANPU, PTTEP, EA BH
# Tags
# CPF
# สุกิจ อุดมศิริกุล
# TISCO
# SCGP
# SCC
# มองอย่างเซียน
# HMPRO
# InnovestX
# KTB
# BANPU
# EA
# PTTEP
# ERW
# KBANK
# GPSC
# SAT
# SCCC
# AMATA
# BH
# fed
# 3089
# [('2023-02-13 00:00:00', 'มองตลาดหุ้นไทยปรับฐานเดือน ก.พ
# ภาพดังกล่าว ทำให้ InnovestX เชื่อว่า Fed จะขึ้นดอกเบี้ยถึงระดับ 5-5.25% หรือสูงกว่านั้น และมองว่าในระยะต่อไป ความผันผวนในตลาดจะมีมากขึ้น จากความเสี่ยงเงินเฟ้อ การขึ้นดอกเบี้ย และต้นทุนการเงินที่จะกลับมาเพิ่มขึ้น รวมถึงผลประกอบการที่อาจเริ่มแย่ลงมากขึ้น
# ส่วนภาพตลาดหุ้นไทย InnovestX มองว่าดัชนีจะอยู่ในช่วงปรับฐานและมี Upside จำกัด หลังตลาดมี Valuation ค่อนข้างตึงตัว อีกทั้งยังขาดปัจจัยหนุนการลงทุนใหม่ ๆ และอยู่ระหว่างรอดูผลประกอบการไตรมาส 4/65 ของ Real Sector ที่จะกำลังทยอยประกาศออกมา ดังนั้นกลยุทธ์ลงทุนจึงแนะนำ “Selective Buy” ในธีมที่มีปัจจัยบวกเฉพาะ โดยเน้นรอซื้อเมื่อราคาอ่อนตัว ไม่ไล่ราคา ดังนี้
# แรงซื้อ “บลูชิพ” พยุง SET ปิดบวก 0.32 จุด แนวโน้มพรุ่งนี้ไซด์เวย์ ลุ้นเงินเฟ้อสหรัฐ
# SET ปิดเช้ารีบาวด์ 1 จุด เก็งกำไรรายตัว-รอเงินเฟ้อสหรัฐ
# 1)หุ้นที่มองไม่ต้องระวังแรงขายจากต่างชาติ (ปี 65 ต่างชาติขายสุทธิหรือซื้อสุทธิน้อย) ขณะที่ปี 66 จากต้นปีถึงปัจจุบันต่างชาติเริ่มพลิกซื้อสุทธิหรือซื้อต่อเนื่อง เลือก SCC, AMATA, ERW
# 2)หุ้นที่ราคายัง Laggard โดยมี PBV ต่ำกว่าค่าเฉลี่ยย้อนหลัง 5 ปี และปี 2566 คาดกำไรเติบโตดีจากงวดเดียวกันของปีก่อน อีกทั้ง Valuation ยังน่าสนใจ เลือก CPF, GPSC, SCGP, HMPRO
# 3)สำหรับนักลงทุนที่ชอบหุ้นปันผล แนะนำหุ้นที่คาดหลังรายงานงบปี 2565 จะประกาศจ่ายปันผล โดยให้ Div. Yield ปี 65 (หักที่จ่ายระหว่างกาลไปแล้ว) สูงเกิน 4% และคาดขึ้น XD แล้ว ราคาหุ้นจะยังปรับขึ้นต่อได้จากผลการดำเนินงานที่เติบโตดีในปี 66 เลือก TISCO, SAT, KTB, SCCC
# ขณะที่ช่วงสั้นแนะนำให้ เพิ่มความระมัดระวัง หรือ หลีกเลี่ยงการลงทุนออกไปก่อน สำหรับหุ้นที่คาดอาจจะเผชิญแรงขายจากนักลงทุนต่างชาติ ได้แก่ KBANK, BANPU, PTTEP, EA BH
# Tags
# CPF
# สุกิจ อุดมศิริกุล
# TISCO
# SCGP
# SCC
# มองอย่างเซียน
# HMPRO
# InnovestX
# KTB
# BANPU
# EA
# PTTEP
# ERW
# KBANK
# GPSC
# SAT
# SCCC
# AMATA
# BH
# fed
# 3089
# [('2023-02-13 00:00:00', 'มองตลาดหุ้นไทยปรับฐานเดือน ก.พ.', 'https://www.kaohoon.com/column/588000', 'SCGP')]
# https://www.kaohoon.com/column/588000
# มองตลาดหุ้นไทยปรับฐานเดือน ก.พ.
# 2023-02-13 00:00:00
# SCGP
# InnovestX มองว่าการจ้างงานนอกภาคเกษตรของสหรัฐฯ เพิ่มขึ้นเกินคาดมาก ขณะที่อัตราว่างงานลดลงต่ำสุดในรอบ 53 ปี ด้านรายได้เฉลี่ยรายสัปดาห์เพิ่มขึ้น 4.7% ในเดือน ม.ค. จากปีก่อนหน้า เร่งตัวจาก 3.6% ในเดือน ธ.ค. บ่งชี้ว่า ภาพตลาดแรงงานที่ยังคงแข็งแกร่งมาก โดยเฉพาะภาคบริการ ทำให้แรงกดดันเงินเฟ้อจากค่าจ้างเริ่มกลับมาเพิ่มขึ้น โดยตัวเลขการจ้างงาน non farm ที่เพิ่มขึ้นมากและขัดแย้งกับตัวเลขการจ้างงานภาคเอกชน (ADP) ที่ชะลอแรงกว่าคาด (1.1 แสนตำแหน่งจากคาดที่ 1.7 แสนตำแหน่ง)
# บ่งชี้ว่าธุรกิจที่จ้างงานมากน่าจะเป็นธุรกิจขนาดเล็กและธุรกิจบริการมากกว่า ซึ่งในระยะสั้นยังได้รับประโยชน์จากเงินออมส่วนเกินที่ยังมีอยู่ และผู้คนอาจจะออกมาจับจ่ายในช่วงต้นปี ทำให้มี demand ของแรงงาน Unskilled worker ภาคบริการ แต่ระยะต่อไป เมื่อเศรษฐกิจชะลอมากขึ้น ก็อาจนำมาสู่การปลดคนงานได้เช่นเดียวกัน
# ในส่วนของมุมมองจากประธาน Fed ยังคงมองว่าเงินเฟ้อเริ่มลดลงแล้ว (Disinflationary process has begun) แต่จะใช้เวลายาวนาน เพราะ Disinflation เกิดในตลาดสินค้า ซึ่งเป็น 25% ของเศรษฐกิจสหรัฐ (แต่อีก 75% เป็น Service ซึ่งยังมีเงินเฟ้ออยู่) ดังนั้น ถ้าข้อมูลยังดีต่อเนื่อง เช่น ตัวเลขตลาดแรงงานและ/หรือ เงินเฟ้อยังสูงอยู่ ก็มีแนวโน้มที่จะขึ้นดอกเบี้ยสูงเกินกว่าคาด ซึ่ง InnovestX มองว่า การที่ประธาน Fed เน้นว่าเงินเฟ้อเริ่มลง แม้ว่าจะต้องใช้เวลานานกว่าจะหมดนั้น เป็นส่วนสำคัญที่ทำให้ผลตอบแทนพันธบัตรสหรัฐฯ ปรับขึ้นในช่วงที่ผ่านมา ซึ่งภาพเงินเฟ้อจะอยู่ระดับสูงยาวนานขึ้น ประกอบกับ ตัวเลขเศรษฐกิจบางตัวที่ดูแข็งแกร่งขึ้น ทำให้ Fed ต้องคงดอกเบี้ยสูงมากขึ้น และ/หรือขึ้นดอกเบี้ยต่อเนื่อง
# ภาพดังกล่าว ทำให้ InnovestX เชื่อว่า Fed จะขึ้นดอกเบี้ยถึงระดับ 5-5.25% หรือสูงกว่านั้น และมองว่าในระยะต่อไป ความผันผวนในตลาดจะมีมากขึ้น จากความเสี่ยงเงินเฟ้อ การขึ้นดอกเบี้ย และต้นทุนการเงินที่จะกลับมาเพิ่มขึ้น รวมถึงผลประกอบการที่อาจเริ่มแย่ลงมากขึ้น
# ส่วนภาพตลาดหุ้นไทย InnovestX มองว่าดัชนีจะอยู่ในช่วงปรับฐานและมี Upside จำกัด หลังตลาดมี Valuation ค่อนข้างตึงตัว อีกทั้งยังขาดปัจจัยหนุนการลงทุนใหม่ ๆ และอยู่ระหว่างรอดูผลประกอบการไตรมาส 4/65 ของ Real Sector ที่จะกำลังทยอยประกาศออกมา ดังนั้นกลยุทธ์ลงทุนจึงแนะนำ “Selective Buy” ในธีมที่มีปัจจัยบวกเฉพาะ โดยเน้นรอซื้อเมื่อราคาอ่อนตัว ไม่ไล่ราคา ดังนี้
# แรงซื้อ “บลูชิพ” พยุง SET ปิดบวก 0.32 จุด แนวโน้มพรุ่งนี้ไซด์เวย์ ลุ้นเงินเฟ้อสหรัฐ
# SET ปิดเช้ารีบาวด์ 1 จุด เก็งกำไรรายตัว-รอเงินเฟ้อสหรัฐ
# 1)หุ้นที่มองไม่ต้องระวังแรงขายจากต่างชาติ (ปี 65 ต่างชาติขายสุทธิหรือซื้อสุทธิน้อย) ขณะที่ปี 66 จากต้นปีถึงปัจจุบันต่างชาติเริ่มพลิกซื้อสุทธิหรือซื้อต่อเนื่อง เลือก SCC, AMATA, ERW
# 2)หุ้นที่ราคายัง Laggard โดยมี PBV ต่ำกว่าค่าเฉลี่ยย้อนหลัง 5 ปี และปี 2566 คาดกำไรเติบโตดีจากงวดเดียวกันของปีก่อน อีกทั้ง Valuation ยังน่าสนใจ เลือก CPF, GPSC, SCGP, HMPRO
# 3)สำหรับนักลงทุนที่ชอบหุ้นปันผล แนะนำหุ้นที่คาดหลังรายงานงบปี 2565 จะประกาศจ่ายปันผล โดยให้ Div. Yield ปี 65 (หักที่จ่ายระหว่างกาลไปแล้ว) สูงเกิน 4% และคาดขึ้น XD แล้ว ราคาหุ้นจะยังปรับขึ้นต่อได้จากผลการดำเนินงานที่เติบโตดีในปี 66 เลือก TISCO, SAT, KTB, SCCC
# ...
# จับตา AOT ปิดงบไตรมาส 1/2566 (ต.ค.-ธ.ค. 2565) พลิกมีกำไร 342.77 ล้านบาท จากปีก่อนที่ขาดทุนสุทธิกว่า 4.2 พันล้านบาท หลังจำนวนผู้โดยสารเพิ่มขึ้นเป็น 23 ล้านคน โต 232.93% พร้อมมีเที่ยวบินรวมกว่า 1.5 แสนเที่ยวบิน เพิ่มขึ้น 105.04% เหตุโควิดคลี่คลาย-เข้าสู่ไฮซีซั่น คาดปีงบประมาณ 2566 (ต.ค. 2565-ก.ย. 2566) ท่าอากาศยานทั้ง 6 แห่ง จะมีผู้โดยสารรวม 95.70 ล้านคน ฟื้นตัวขึ้น 68% จากปี 2562 ซึ่งเป็นช่วงก่อนการแพร่ระบาดของไวรัสโควิด-19 และคาดว่าในปีงบประมาณ 2567 (ต.ค. 2566-ก.ย. 2567) จะมีผู้โดยสารรวม 141.57 ล้านคน ฟื้นตัว 99% หรือคิดเป็นการฟื้นตัวกลับคืนมาในระดับเดียวกับปี 2562
# SABUY เตรียมเปิดขายหุ้นกู้อายุ 2 ปี 6 เดือน อัตราดอกเบี้ยสูง 6.45% จ่ายดอกเบี้ยทุก ๆ 3 เดือน จองซื้อขั้นต่ำ 1 แสนบาท มูลค่ารวมไม่เกิน 1,500 ล้านบาท เสนอขายระหว่างวันที่ 14-16 ก.พ. 2566 ชูจุดเด่นกำไรโตต่อเนื่อง ธุรกิจขยายตัวสูง หนี้น้อย ความสามารถในการชำระหนี้สูง หวังระดมเงินไปต่อยอดลงทุนในธุรกิจใหม่ที่เกี่ยวข้องราว 1,200 ล้านบาท รวมถึงลงทุนในธุรกิจด้าน Payment Gateway ในภูมิภาคเอเชียตะวันออกเฉียงใต้ และการลงทุนในธุรกิจเกมออนไลน์ที่เติบโตสูง อีกทั้งจะใช้เป็นเงินทุนหมุนเวียนในกิจการต่าง ๆ
# NEX เซ็นสัญญาแต่งตั้ง “ทีซี อินดัสเตรียล อิควิปเมนท์ (ประเทศไทย)” หรือ TCIE บริษัทในเครือของกลุ่มตันจง อินเตอร์เนชั่นแนล กรุ๊ป เป็นตัวแทนจำหน่ายยานยนต์ไฟฟ้าเชิงพาณิชย์ ระดับ 3S (Sales, Service, Spare parts) เพื่อจำหน่ายรถไฟฟ้าเพื่อการพาณิชย์ทั้งแบบ 6 ล้อ 10 ล้อ หัวลาก รถเหมือง EV และรถโดยสารไฟฟ้า EV โดยตั้งเป้าจำหน่ายในปี 2566 จำนวน 50 คัน
# แรงซื้อ “บลูชิพ” พยุง SET ปิดบวก 0.32 จุด แนวโน้มพรุ่งนี้ไซด์เวย์ ลุ้นเงินเฟ้อสหรัฐ
# BEM โบรกแนะซื้อเป้า 10.80 บ. รับผู้โดยสาร MRT ม.ค. โตทะลัก 114% แตะ 3.7 แสนเที่ยว/วัน
# หุ้นไอพีโอน้องใหม่ “เมพ คอร์ปอเรชั่น” หรือ MEB เตรียมตัวเข้าเทรดในตลาดหลักทรัพย์ mai วันวาเลนไทน์ (14 ก.พ.) หลังขายหุ้นไอพีโอ 75.50 ล้านหุ้น ราคา 28.50 บาท/หุ้น จัดว่าได้รับความสนใจจากนักลงทุนอย่างล้นหลาม โดยสถาบันจองซื้อถึง 50.33% ชูจุดแข็งเป็นเบอร์หนึ่งเมืองไทยสำหรับการจำหน่าย E-book ซึ่งมีจำนวนหนังสือและผู้ใช้บริการมากที่สุด สะท้อนจากผู้ใช้บริการในแพลตฟอร์มทั้ง meb และ readAwrite ทะลุ 8 ล้านราย และมีแนวโน้มเพิ่มขึ้นอย่างต่อเนื่อง ส่งผลให้ MEB มีอนาคตไกลจากแนวโน้มการเติบโตสูงในอุตสาหกรรมวรรณกรรมออนไลน์
# TOP ปิดงบปี 2565 กำไร 3.26 หมื่นล้านบาท พุ่งกระฉูด 160% จากราคาขายผลิตภัณฑ์ปรับเพิ่มขึ้น ดีมานด์น้ำมันหนุนหลังมาตรการเปิดเมือง ส่วนปีนี้คาดจะยังมีแนวโน้มที่ดีขึ้นกว่าช่วงก่อนโควิด-19 เพราะเศรษฐกิจโลกมีแนวโน้มเติบโตและประเทศจีนมีการยกเลิกมาตรการควบคุมการแพร่ระบาดโควิด-19
# Tags
# สโนว์แมน
# หุ้นไทย
# NEX
# SABUY
# หุ้นวันนี้
# ข่าวหุ้นวันนี้
# เมพ คอร์ปอเรชั่น
# MEB
# TCIE
# ตันจง อินเตอร์เนชั่นแนล กรุ๊ป
# SET
# การไฟฟ้าแห่งชาติมาเลเซีย
# mai
# ทีซี อินดัสเตรียล อิควิปเมนท์ (ประเทศไทย)
# AOT
# TOP
# สังคมข่าวหุ้น
# BGRIM
# 3194
# [('2023-02-13 00:00:00', 'สังคมข่าวหุ้น', 'https://www.kaohoon.com/column/587996', 'TOP')]
# https://www.kaohoon.com/column/587996
# สังคมข่าวหุ้น
# 2023-02-13 00:00:00
# TOP
# ADVERTISEMENT
# NEX เซ็นสัญญาแต่งตั้ง “ทีซี อินดัสเตรียล อิควิปเมนท์ (ประเทศไทย)” หรือ TCIE บริษัทในเครือของกลุ่มตันจง อินเตอร์เนชั่นแนล กรุ๊ป เป็นตัวแทนจำหน่ายยานยนต์ไฟฟ้าเชิงพาณิชย์ ระดับ 3S (Sales, Service, Spare parts) เพื่อจำหน่ายรถไฟฟ้าเพื่อการพาณิชย์ทั้งแบบ 6 ล้อ 10 ล้อ หัวลาก รถเหมือง EV และรถโดยสารไฟฟ้า EV โดยตั้งเป้าจำหน่ายในปี 2566 จำนวน 50 คัน
# แรงซื้อ “บลูชิพ” พยุง SET ปิดบวก 0.32 จุด แนวโน้มพรุ่งนี้ไซด์เวย์ ลุ้นเงินเฟ้อสหรัฐ
# BEM โบรกแนะซื้อเป้า 10.80 บ. รับผู้โดยสาร MRT ม.ค. โตทะลัก 114% แตะ 3.7 แสนเที่ยว/วัน
# หุ้นไอพีโอน้องใหม่ “เมพ คอร์ปอเรชั่น” หรือ MEB เตรียมตัวเข้าเทรดในตลาดหลักทรัพย์ mai วันวาเลนไทน์ (14 ก.พ.) หลังขายหุ้นไอพีโอ 75.50 ล้านหุ้น ราคา 28.50 บาท/หุ้น จัดว่าได้รับความสนใจจากนักลงทุนอย่างล้นหลาม โดยสถาบันจองซื้อถึง 50.33% ชูจุดแข็งเป็นเบอร์หนึ่งเมืองไทยสำหรับการจำหน่าย E-book ซึ่งมีจำนวนหนังสือและผู้ใช้บริการมากที่สุด สะท้อนจากผู้ใช้บริการในแพลตฟอร์มทั้ง meb และ readAwrite ทะลุ 8 ล้านราย และมีแนวโน้มเพิ่มขึ้นอย่างต่อเนื่อง ส่งผลให้ MEB มีอนาคตไกลจากแนวโน้มการเติบโตสูงในอุตสาหกรรมวรรณกรรมออนไลน์
# TOP ปิดงบปี 2565 กำไร 3.26 หมื่นล้านบาท พุ่งกระฉูด 160% จากราคาขายผลิตภัณฑ์ปรับเพิ่มขึ้น ดีมานด์น้ำมันหนุนหลังมาตรการเปิดเมือง ส่วนปีนี้คาดจะยังมีแนวโน้มที่ดีขึ้นกว่าช่วงก่อนโควิด-19 เพราะเศรษฐกิจโลกมีแนวโน้มเติบโตและประเทศจีนมีการยกเลิกมาตรการควบคุมการแพร่ระบาดโควิด-19
# Tags
# สโนว์แมน
# หุ้นไทย
# NEX
# SABUY
# หุ้นวันนี้
# ข่าวหุ้นวันนี้
# เมพ คอร์ปอเรชั่น
# MEB
# TCIE
# ตันจง อินเตอร์เนชั่นแนล กรุ๊ป
# SET
# การไฟฟ้าแห่งชาติมาเลเซีย
# mai
# ทีซี อินดัสเตรียล อิควิปเมนท์ (ประเทศไทย)
# AOT
# TOP
# สังคมข่าวหุ้น
# BGRIM
# 3194
# [('2023-02-13 00:00:00', 'สังคมข่าวหุ้น', 'https://www.kaohoon.com/column/587996', 'BGRIM')]
# https://www.kaohoon.com/column/587996
# สังคมข่าวหุ้น
# 2023-02-13 00:00:00
# BGRIM
# ADVERTISEMENT
# ดัชนีตลาดหุ้นไทยปิดที่ระดับ 1,664.57 จุด ลดลง 4.60 จุด มูลค่าการซื้อขาย 58,917.38 ล้านบาท จับตาการทยอยประกาศผลการดำเนินงานของบริษัทจดทะเบียน ติดตามตัวเลขเงินเฟ้อสหรัฐฯ ที่จะประกาศวันที่ 14 ก.พ. และ ตัวเลข GDP ของไทยในวันที่ 17 ก.พ.นี้
# BEM โบรกแนะซื้อเป้า 10.80 บ. รับผู้โดยสาร MRT ม.ค. โตทะลัก 114% แตะ 3.7 แสนเที่ยว/วัน
# หุ้นไอพีโอน้องใหม่ “เมพ คอร์ปอเรชั่น” หรือ MEB เตรียมตัวเข้าเทรดในตลาดหลักทรัพย์ mai วันวาเลนไทน์ (14 ก.พ.) หลังขายหุ้นไอพีโอ 75.50 ล้านหุ้น ราคา 28.50 บาท/หุ้น จัดว่าได้รับความสนใจจากนักลงทุนอย่างล้นหลาม โดยสถาบันจองซื้อถึง 50.33% ชูจุดแข็งเป็นเบอร์หนึ่งเมืองไทยสำหรับการจำหน่าย E-book ซึ่งมีจำนวนหนังสือและผู้ใช้บริการมากที่สุด สะท้อนจากผู้ใช้บริการในแพลตฟอร์มทั้ง meb และ readAwrite ทะลุ 8 ล้านราย และมีแนวโน้มเพิ่มขึ้นอย่างต่อเนื่อง ส่งผลให้ MEB มีอนาคตไกลจากแนวโน้มการเติบโตสูงในอุตสาหกรรมวรรณกรรมออนไลน์
# TOP ปิดงบปี 2565 กำไร 3.26 หมื่นล้านบาท พุ่งกระฉูด 160% จากราคาขายผลิตภัณฑ์ปรับเพิ่มขึ้น ดีมานด์น้ำมันหนุนหลังมาตรการเปิดเมือง ส่วนปีนี้คาดจะยังมีแนวโน้มที่ดีขึ้นกว่าช่วงก่อนโควิด-19 เพราะเศรษฐกิจโลกมีแนวโน้มเติบโตและประเทศจีนมีการยกเลิกมาตรการควบคุมการแพร่ระบาดโควิด-19
# Tags
# สโนว์แมน
# หุ้นไทย
# NEX
# SABUY
# หุ้นวันนี้
# ข่าวหุ้นวันนี้
# เมพ คอร์ปอเรชั่น
# MEB
# TCIE
# ตันจง อินเตอร์เนชั่นแนล กรุ๊ป
# SET
# การไฟฟ้าแห่งชาติมาเลเซีย
# mai
# ทีซี อินดัสเตรียล อิควิปเมนท์ (ประเทศไทย)
# AOT
# TOP
# สังคมข่าวหุ้น
# BGRIM
# 3194
# ---------------------------------------------------
# ---------------------------------------------------
# [('2023-02-13 00:00:00', 'เดินอย่างสุข', 'https://www.kaohoon.com/column/587992', 'DTAC')]
# https://www.kaohoon.com/column/587992
# เดินอย่างสุข
# 2023-02-13 00:00:00
# DTAC
# โหงวเฮ้งหุ้น
# “เดินช้า” กว่าคนอื่นก็ไม่ต้องไปเดินแข่งกับเขา
# แต่เรามีความสุขในทุกก้าวที่เราเดินก็พอแล้ว..
# วันนี้เป็นวันหยิ่มอิ้ง ดวงวันนี้มีเกณฑ์ที่จะอำนวยให้ใครได้ดิบได้ดีบ้าง ส่วนการงานด้านอื่นคงดำเนินไปได้ ธุรกิจวันนี้ การค้าธุรกิจต่าง ๆ ไม่มีมรสุมหรือเหตุร้ายใด ๆ ผลที่ได้รับจะขึ้นอยู่กับความสามารถและดวงของแต่ละบุคคล
# หุ้นแนะนำให้ซื้อคือ INTUCH หรือ GPSC
# BEM โบรกแนะซื้อเป้า 10.80 บ. รับผู้โดยสาร MRT ม.ค. โตทะลัก 114% แตะ 3.7 แสนเที่ยว/วัน
# AU โบรกเชียร์ซื้อเป้า 13 บ. รับ SSSG ฟื้น-ยอด Dine in พุ่ง จับตากำไรปี 65 โตแรง 26 เท่า
# หุ้นที่ไม่แนะนำลงทุนช่วงนี้คือ DTAC และ TRUE
# คติวันนี้ “คนอกตัญญู..ไม่มีคุณค่า”
# Tags
# DTAC
# GPSC
# โหงวเฮ้ง
# ดวง
# ดวงหุ้น
# หุ้นเด่นวันนี้
# โหงวเฮ้งหุ้น
# ดวงวันนี้
# หุ้นเด่น
# วันมงคล
# TRUE
# ซินแส
# INTUCH
# 719
# [('2023-02-13 00:00:00', 'เดินอย่างสุข', 'https://www.kaohoon.com/column/587992', 'GPSC')]
# https://www.kaohoon.com/column/587992
# เดินอย่างสุข
# 2023-02-13 00:00:00
# GPSC
# โหงวเฮ้งหุ้น
# “เดินช้า” กว่าคนอื่นก็ไม่ต้องไปเดินแข่งกับเขา
# แต่เรามีความสุขในทุกก้าวที่เราเดินก็พอแล้ว..
# วันนี้เป็นวันหยิ่มอิ้ง ดวงวันนี้มีเกณฑ์ที่จะอำนวยให้ใครได้ดิบได้ดีบ้าง ส่วนการงานด้านอื่นคงดำเนินไปได้ ธุรกิจวันนี้ การค้าธุรกิจต่าง ๆ ไม่มีมรสุมหรือเหตุร้ายใด ๆ ผลที่ได้รับจะขึ้นอยู่กับความสามารถและดวงของแต่ละบุคคล
# หุ้นแนะนำให้ซื้อคือ INTUCH หรือ GPSC
# BEM โบรกแนะซื้อเป้า 10.80 บ. รับผู้โดยสาร MRT ม.ค. โตทะลัก 114% แตะ 3.7 แสนเที่ยว/วัน
# AU โบรกเชียร์ซื้อเป้า 13 บ. รับ SSSG ฟื้น-ยอด Dine in พุ่ง จับตากำไรปี 65 โตแรง 26 เท่า
# หุ้นที่ไม่แนะนำลงทุนช่วงนี้คือ DTAC และ TRUE
# คติวันนี้ “คนอกตัญญู..ไม่มีคุณค่า”
# Tags
# DTAC
# GPSC
# โหงวเฮ้ง
# ดวง
# ดวงหุ้น
# หุ้นเด่นวันนี้
# โหงวเฮ้งหุ้น
# ดวงวันนี้
# หุ้นเด่น
# วันมงคล
# TRUE
# ซินแส
# INTUCH
# 719
# [('2023-02-13 00:00:00', 'เดินอย่างสุข', 'https://www.kaohoon.com/column/587992', 'TRUE')]
# https://www.kaohoon.com/column/587992
# เดินอย่างสุข
# 2023-02-13 00:00:00
# TRUE
# โหงวเฮ้งหุ้น
# “เดินช้า” กว่าคนอื่นก็ไม่ต้องไปเดินแข่งกับเขา
# แต่เรามีความสุขในทุกก้าวที่เราเดินก็พอแล้ว..
# วันนี้เป็นวันหยิ่มอิ้ง ดวงวันนี้มีเกณฑ์ที่จะอำนวยให้ใครได้ดิบได้ดีบ้าง ส่วนการงานด้านอื่นคงดำเนินไปได้ ธุรกิจวันนี้ การค้าธุรกิจต่าง ๆ ไม่มีมรสุมหรือเหตุร้ายใด ๆ ผลที่ได้รับจะขึ้นอยู่กับความสามารถและดวงของแต่ละบุคคล
# หุ้นแนะนำให้ซื้อคือ INTUCH หรือ GPSC
# BEM โบรกแนะซื้อเป้า 10.80 บ. รับผู้โดยสาร MRT ม.ค. โตทะลัก 114% แตะ 3.7 แสนเที่ยว/วัน
# AU โบรกเชียร์ซื้อเป้า 13 บ. รับ SSSG ฟื้น-ยอด Dine in พุ่ง จับตากำไรปี 65 โตแรง 26 เท่า
# หุ้นที่ไม่แนะนำลงทุนช่วงนี้คือ DTAC และ TRUE
# คติวันนี้ “คนอกตัญญู..ไม่มีคุณค่า”
# Tags
# DTAC
# GPSC
# โหงวเฮ้ง
# ดวง
# ดวงหุ้น
# หุ้นเด่นวันนี้
# โหงวเฮ้งหุ้น
# ดวงวันนี้
# หุ้นเด่น
# วันมงคล
# TRUE
# ซินแส
# INTUCH
# 719
# [('2023-02-13 00:00:00', 'เดินอย่างสุข', 'https://www.kaohoon.com/column/587992', 'INTUCH')]
# https://www.kaohoon.com/column/587992
# เดินอย่างสุข
# 2023-02-13 00:00:00
# INTUCH
# โหงวเฮ้งหุ้น
# “เดินช้า” กว่าคนอื่นก็ไม่ต้องไปเดินแข่งกับเขา
# แต่เรามีความสุขในทุกก้าวที่เราเดินก็พอแล้ว..
# วันนี้เป็นวันหยิ่มอิ้ง ดวงวันนี้มีเกณฑ์ที่จะอำนวยให้ใครได้ดิบได้ดีบ้าง ส่วนการงานด้านอื่นคงดำเนินไปได้ ธุรกิจวันนี้ การค้าธุรกิจต่าง ๆ ไม่มีมรสุมหรือเหตุร้ายใด ๆ ผลที่ได้รับจะขึ้นอยู่กับความสามารถและดวงของแต่ละบุคคล
# หุ้นแนะนำให้ซื้อคือ INTUCH หรือ GPSC
# BEM โบรกแนะซื้อเป้า 10.80 บ. รับผู้โดยสาร MRT ม.ค. โตทะลัก 114% แตะ 3.7 แสนเที่ยว/วัน
# AU โบรกเชียร์ซื้อเป้า 13 บ. รับ SSSG ฟื้น-ยอด Dine in พุ่ง จับตากำไรปี 65 โตแรง 26 เท่า
# หุ้นที่ไม่แนะนำลงทุนช่วงนี้คือ DTAC และ TRUE
# คติวันนี้ “คนอกตัญญู..ไม่มีคุณค่า”
# Tags
# DTAC
# GPSC
# โหงวเฮ้ง
# ดวง
# ดวงหุ้น
# หุ้นเด่นวันนี้
# โหงวเฮ้งหุ้น
# ดวงวันนี้
# หุ้นเด่น
# วันมงคล
# TRUE
# ซินแส
# INTUCH
# 719
# ---------------------------------------------------
# ---------------------------------------------------
# [('2023-02-12 00:00:00', 'CPF ปลื้มติดอันดับดัชนีความยั่งยืน S&P Global ต่อเนื่อง 3 ปี', 'https://www.kaohoon.com/pr/587985', 'CPF')]
# https://www.kaohoon.com/pr/587985
# CPF ปลื้มติดอันดับดัชนีความยั่งยืน S&P Global ต่อเนื่อง 3 ปี
# 2023-02-12 00:00:00
# CPF
# นายประสิทธิ์ บุญดวงประเสริฐ ประธานคณะผู้บริหาร บริษัท เจริญโภคภัณฑ์อาหาร จำกัด (มหาชน) หรือ CPF เปิดเผยว่า บริษัทฯ ยังรักษาความเป็นผู้นำในกลุ่มอุตสาหกรรมผลิตภัณฑ์อาหาร โดย S&P Global ได้ประกาศรายชื่อ องค์กรชั้นนำที่เป็นสมาชิกดัชนีความยั่งยืนดาวโจนส์ และบริษัทได้รับการบันทึกในรายงาน The Sustainability Yearbook 2023 
# WHA รับบรรจุ “S&P Global Sustainability Yearbook 2023” เด่นด้านพัฒนาความยั่งยืน
# ขายหนีตาย?
# Tags
# หุ้น CPF
# S&P Global
# The Sustainability Yearbook 2023
# CPF
# ประสิทธิ์ บุญดวงประเสริฐ
# เจริญโภคภัณฑ์อาหาร
# 2501
# ---------------------------------------------------

# %%
import sqlite3
from datetime import datetime

# Create a SQL connection to our SQLite database
con = sqlite3.connect("stock.sqlite")
cur = con.cursor()
date = '2023-02-13'
date_format = "%Y-%m-%d"
date_obj = datetime.strptime(date, date_format)
title = 'BGRIM ผนึก “อินโนพาวเวอร์” ชู 5 แนวคิด มุ่งสู่สังคมคาร์บอนต่ำ'
get_url = 'https://www.kaohoon.com/news/588123'
ticker = 'BGRIM'
query = uery = "SELECT * FROM stock_news WHERE DATETIME = '%s' AND Title = '%s' AND Link = '%s' AND Ticker = '%s'" %(date_obj, title, get_url, ticker)
cur.execute(query)
data = cur.fetchall()
if data != []:
    print(data)
else:
    print('add')
# Out:
# [('2023-02-13 00:00:00', 'BGRIM ผนึก “อินโนพาวเวอร์” ชู 5 แนวคิด มุ่งสู่สังคมคาร์บอนต่ำ', 'https://www.kaohoon.com/news/588123', 'BGRIM')]

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By 
import sqlite3
from datetime import datetime

nasdaq = []

# Create a SQL connection to our SQLite database
con = sqlite3.connect("stock.sqlite")
cur = con.cursor()

op = webdriver.ChromeOptions()
#op.add_argument('headless') 
driver = webdriver.Chrome(options=op) 
driver.get('https://www.nasdaq.com/market-activity/quotes/nasdaq-ndx-index')
elements = driver.find_elements(By.XPATH, '//th[@class="nasdaq-ndx-index__cell nasdaq-ndx-index__cell--heading"]')

for element in elements:
    nasdaq.append(element.text)

# %%
print(nasdaq)
# Out:
# ['ABNB', 'ADBE', 'ADI', 'ADP', 'ADSK', 'AEP', 'ALGN', 'AMAT', 'AMD', 'AMGN', 'ANSS', 'ASML', 'ATVI', 'AVGO', 'AZN', 'BIIB', 'BKNG', 'BKR', 'CDNS', 'CEG', 'CHTR', 'CMCSA', 'COST', 'CPRT', 'CRWD', 'CSCO', 'CSGP', 'CSX', 'CTAS', 'CTSH', 'DDOG', 'DLTR', 'DXCM', 'EA', 'EBAY', 'ENPH', 'EXC', 'FANG', 'FAST', 'FISV', 'FTNT', 'GFS', 'GILD', 'GOOG', 'GOOGL', 'HON', 'IDXX', 'ILMN', 'INTC', 'INTU', 'ISRG', 'JD', 'KDP', 'KHC', 'KLAC', 'LCID', 'LRCX', 'LULU', 'MAR', 'MCHP', 'MDLZ', 'MELI', 'META', 'MNST', 'MRNA', 'MRVL', 'MU', 'NFLX', 'NXPI', 'ODFL', 'ORLY', 'PANW', 'PAYX', 'PCAR', 'PDD', 'PEP', 'PYPL', 'QCOM', 'REGN', 'RIVN', 'ROST', 'SBUX', 'SGEN', 'SIRI', 'SNPS', 'TEAM', 'TMUS', 'TXN', 'VRSK', 'VRTX', 'WBA', 'WBD', 'WDAY', 'XEL', 'ZM', 'ZS']

# %%
import yfinance as yf
for stock in nasdaq:
    data = yf.download(tickers=stock,period="2y",interval="1h")
    data['Ticker'] = stock
    print(data)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                            Open        High         Low       Close  \
# Datetime
# 2021-02-11 09:30:00