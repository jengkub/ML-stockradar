# 2022-12-22 15:00:00  72.75  72.75  72.50  72.50      72.50   428956
# 2022-12-22 16:00:00  72.75  73.00  72.50  72.75      72.75  2853631
# 2022-12-23 10:00:00  72.75  73.00  72.50  73.00      73.00        0
# 2022-12-23 11:00:00  73.00  73.25  73.00  73.25      73.25   988075
# 2022-12-23 12:00:00  73.25  73.25  73.00  73.25      73.25   140099
# 2022-12-23 14:00:00  73.00  73.25  73.00  73.25      73.25   203171
# 2022-12-23 15:00:00  73.25  73.25  72.75  73.00      73.00  6541180
# 2022-12-23 16:00:00  73.25  73.25  73.00  73.00      73.00  2222176

# %%
msft = yf.Ticker("AOT.BK")
hist = msft.history(period="max")
msft.history_metadata
# Out:
# {'currency': 'THB',
#  'symbol': 'AOT.BK',
#  'exchangeName': 'SET',
#  'instrumentType': 'EQUITY',
#  'firstTradeDate': 1078974000,
#  'regularMarketTime': 1671596250,
#  'gmtoffset': 25200,
#  'timezone': 'ICT',
#  'exchangeTimezoneName': 'Asia/Bangkok',
#  'regularMarketPrice': 73.0,
#  'chartPreviousClose': 4.8,
#  'priceHint': 2,
#  'currentTradingPeriod': {'pre': {'timezone': 'ICT',
#    'end': 1671591600,
#    'start': 1671591600,
#    'gmtoffset': 25200},
#   'regular': {'timezone': 'ICT',
#    'end': 1671615000,
#    'start': 1671591600,
#    'gmtoffset': 25200},
#   'post': {'timezone': 'ICT',
#    'end': 1671615000,
#    'start': 1671615000,
#    'gmtoffset': 25200}},
#  'dataGranularity': '1d',
#  'range': '',
#  'validRanges': ['1d',
#   '5d',
#   '1mo',
#   '3mo',
#   '6mo',
#   '1y',
#   '2y',
#   '5y',
#   '10y',
#   'ytd',
#   'max']}

# %%
from pandas_datareader import data as pdr

import yfinance as yf
yf.pdr_override() # <== that's all it takes :-)

# download dataframe
data = pdr.get_data_yahoo("SPY", start="2017-01-01", end="2017-04-30")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Raw Package
import numpy as np
import pandas as pd

#Data Source
import yfinance as yf

#Data viz
import plotly.graph_objs as go

#Interval required 1 minute
data = yf.download(tickers='UBER', period='1d', interval='1m')

#declare figure
fig = go.Figure()

#Candlestick
fig.add_trace(go.Candlestick(x=data.index,
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close'], name = 'market data'))

# Add titles
fig.update_layout(
    title='Uber live share price evolution',
    yaxis_title='Stock Price (USD per Shares)')

# X-Axes
fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=15, label="15m", step="minute", stepmode="backward"),
            dict(count=45, label="45m", step="minute", stepmode="backward"),
            dict(count=1, label="HTD", step="hour", stepmode="todate"),
            dict(count=3, label="3h", step="hour", stepmode="backward"),
            dict(step="all")
        ])
    )
)

#Show
fig.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#Interval required 5 minutes
Ticker = 'NKE'
data = yf.download(tickers=Ticker, period='10d', interval='1h')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
type(data)
data.to_csv("data.csv",mode='a')

# %%
import csv

# open the file in the write mode
f = open('data.csv', 'a')

# create the csv writer
writer = csv.writer(f)

# write a row to the csv file
writer.writerow([Ticker])
f.close()
data.to_csv("data.csv",mode='a')

# %%
#clear csv file
f = open('data.csv', 'w')

# create the csv writer
writer = csv.writer(f)

# write a row to the csv file
writer.writerow('')

# close the file
f.close()

# %%
#test ระบบ
import csv

# open the file in the write mode
with open('data.csv', 'a') as f:
    # create the csv writer
    writer = csv.writer(f)

    # write a row to the csv file
    writer.writerow([Ticker])

data.to_csv("data.csv",mode='a')

# %%
import csv
with open("test.csv",'r') as file:
    reader = csv.reader(file)
    for row in reader:
        if row[7] == 'GC=F':
            print(row)
# Out:
# ['2022-12-20 00:00:00', '1799.0', '1800.5999755859375', '1795.5999755859375', '1797.5999755859375', '1797.5999755859375', '0', 'GC=F']
# ['2022-12-20 01:00:00', '1797.699951171875', '1802.699951171875', '1797.0999755859375', '1801.5999755859375', '1801.5999755859375', '5636', 'GC=F']
# ['2022-12-20 02:00:00', '1801.800048828125', '1805.0', '1801.199951171875', '1803.300048828125', '1803.300048828125', '7360', 'GC=F']
# ['2022-12-20 03:00:00', '1803.300048828125', '1815.199951171875', '1803.199951171875', '1812.9000244140625', '1812.9000244140625', '15315', 'GC=F']
# ['2022-12-20 04:00:00', '1812.9000244140625', '1817.5999755859375', '1811.300048828125', '1816.800048828125', '1816.800048828125', '9363', 'GC=F']
# ['2022-12-20 05:00:00', '1816.699951171875', '1817.0', '1814.5', '1816.300048828125', '1816.300048828125', '5059', 'GC=F']
# ['2022-12-20 06:00:00', '1816.199951171875', '1819.199951171875', '1814.0999755859375', '1817.300048828125', '1817.300048828125', '7797', 'GC=F']
# ['2022-12-20 07:00:00', '1817.300048828125', '1817.5999755859375', '1807.5999755859375', '1810.199951171875', '1810.199951171875', '10926', 'GC=F']
# ['2022-12-23 07:00:00', '1805.800048828125', '1806.5999755859375', '1804.300048828125', '1805.199951171875', '1805.199951171875', '3685', 'GC=F']
# ['2022-12-23 08:00:00', '1805.199951171875', '1808.5999755859375', '1801.4000244140625', '1802.5', '1802.5', '14097', 'GC=F']
# ['2022-12-23 09:00:00', '1802.699951171875', '1803.699951171875', '1798.9000244140625', '1802.0', '1802.0', '11131', 'GC=F']
# ['2022-12-23 10:00:00', '1802.0', '1809.300048828125', '1799.800048828125', '1808.699951171875', '1808.699951171875', '12190', 'GC=F']
# ['2022-12-23 11:00:00', '1808.5999755859375', '1812.199951171875', '1808.4000244140625', '1808.699951171875', '1808.699951171875', '8965', 'GC=F']
# ['2022-12-23 12:00:00', '1808.699951171875', '1809.4000244140625', '1805.0', '1805.300048828125', '1805.300048828125', '4952', 'GC=F']
# ['2022-12-23 13:00:00', '1805.4000244140625', '1805.800048828125', '1801.699951171875', '1803.800048828125', '1803.800048828125', '5562', 'GC=F']
# ['2022-12-23 14:00:00', '1803.699951171875', '1805.199951171875', '1803.300048828125', '1805.0', '1805.0', '2801', 'GC=F']
# ['2022-12-23 15:00:00', '1805.0', '1805.4000244140625', '1803.0999755859375', '1805.4000244140625', '1805.4000244140625', '1947', 'GC=F']
# ['2022-12-23 16:00:00', '1805.300048828125', '1806.4000244140625', '1805.0999755859375', '1806.0', '1806.0', '1159', 'GC=F']

# %%
#หลายๆตัว
TickerStrings = ['NKE','GC=F','SI=F','GOOGL']
df_list = list()
for ticker in TickerStrings:
    data = yf.download(tickers=ticker, period='2y', interval='1h')
    data['ticker'] = ticker
    df_list.append(data)

df = pd.concat(df_list)
df.to_csv('test.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
import csv
import datetime
#read csv
with open("test.csv",'r') as file:
    reader = csv.reader(file)
    for row in reader:
        if row[7] == 'NKE':
            last = row
#update
x = datetime.datetime.now()
count = 0
DayMo365 = {'1':31,'2':28,'3':31,'4':30,'5':31,'6':30,'7':31,'8':31,'9':30,'10':31,'11':30,'12':31}
DayMo366 = {'1':31,'2':29,'3':31,'4':30,'5':31,'6':30,'7':31,'8':31,'9':30,'10':31,'11':30,'12':31}
LastDate = last[0].split()[0].split('-')
DiffMo = int(x.month) - int(LastDate[1])
DiffYe = int(x.year) - int(LastDate[0])
if DiffYe == 0:
    if DiffMo == 0:
        DiffDay = int(x.day) - int(LastDate[2])
        if DiffDay != 0:
            DiffDay = str(DiffDay) + 'd'
            data = yf.download(tickers='NKE', period=DiffDay, interval='1h')
    elif DiffMo != 0 :
            DiffDay = DayMo365[LastDate[1]] - int(LastDate[2]) + int(x.day)
            DiffDay = str(DiffDay) + 'd'
            data = yf.download(tickers='NKE', period=DiffDay, interval='1h')
elif DiffYe != 0:
    dayly = 0
    dayn = 0
    for j in range(1,int(LastDate[1])):
        dayly = dayly + DayMo365[str(j)]
    for i in range(1,int(x.month)):
        dayn = dayn + DayMo365[str(i)]
    DiffDay = (365*DiffYe) - dayly + dayn - int(LastDate[2]) + int(x.day)
    DiffDay = str(DiffDay) + 'd'
    data = yf.download(tickers='NKE', period=DiffDay, interval='1h')

for i in data.index.day:
    if data.index.year[count] == int(LastDate[0]):
        if data.index.month[count] == int(LastDate[1]):
            if i > int(LastDate[2]):
                break
    count += 1
data['ticker'] = 'NKE'
data = data.iloc[count:,:]
data.to_csv('test.csv',mode='a',header=False)
# Out:
# 1d
# [*********************100%***********************]  1 of 1 completed
