# %%
# Raw Package
import numpy as np
import pandas as pd
from datetime import timedelta, datetime
#Data Source
import yfinance as yf

#Data viz
import plotly.graph_objs as go

# %%
#Interval required 5 minutes
data = yf.download(tickers='NKE', period='6d', interval='1h')
#Print data
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                            Open        High         Low       Close  \
# Datetime
# 2022-12-16 09:30:00  106.870003  107.610001  106.120003  106.120003
# 2022-12-16 10:30:00  106.135002  106.440002  105.839996  106.010002
# 2022-12-16 11:30:00  106.004997  106.529999  105.660004  105.980003
# 2022-12-16 12:30:00  105.980003  106.144997  105.519997  105.639999
# 2022-12-16 13:30:00  105.639999  105.980003  105.309998  105.309998
# 2022-12-16 14:30:00  105.309998  105.989998  105.120003  105.925003
# 2022-12-16 15:30:00  105.930000  106.089996  105.699997  105.870003
# 2022-12-19 09:30:00  104.989998  105.510002  104.300003  104.540001
# 2022-12-19 10:30:00  104.529999  104.629997  103.714996  104.180000
# 2022-12-19 11:30:00  104.169998  104.180000  103.220001  103.820000
# 2022-12-19 12:30:00  103.825699  103.859901  103.279999  103.290001
# 2022-12-19 13:30:00  103.279999  103.339996  102.459999  102.459999
# ...

# %%
list(data)
print(data)
# Out:
#                       Open   High    Low  Close  Adj Close   Volume
# Datetime
# 2022-12-19 10:00:00  73.75  73.75  73.25  73.50      73.50        0
# 2022-12-19 11:00:00  73.50  73.75  73.25  73.75      73.75  1124194
# 2022-12-19 12:00:00  73.50  73.75  73.50  73.50      73.50   199046
# 2022-12-19 14:00:00  73.50  73.50  73.25  73.50      73.50  3211569
# 2022-12-19 15:00:00  73.50  73.50  73.25  73.25      73.25   386631
# 2022-12-19 16:00:00  73.50  73.75  73.25  73.75      73.75  1801626
# 2022-12-20 10:00:00  73.50  73.75  73.25  73.25      73.25        0
# 2022-12-20 11:00:00  73.25  73.50  73.00  73.25      73.25  4575630
# 2022-12-20 12:00:00  73.00  73.50  73.00  73.50      73.50   778861
# 2022-12-20 14:00:00  73.25  73.50  73.25  73.25      73.25   956688
# 2022-12-20 15:00:00  73.50  73.50  73.00  73.25      73.25  3888102
# 2022-12-20 16:00:00  73.25  73.50  73.25  73.50      73.50   617150
# 2022-12-21 10:00:00  73.75  73.75  72.75  73.00      73.00        0
# ...

# %%
msft = yf.Ticker("3k-bat.bk")
hist = msft.history(period="max")
msft.info
# Out:
# {'zip': '10280',
#  'sector': 'Industrials',
#  'longBusinessSummary': 'Thai Energy Storage Technology Public Company Limited manufactures and sells batteries in Thailand and internationally. It provides automotive, motorcycle, traction, EB, forklift, lighting, and golf cart batteries. The company was founded in 1986 and is headquartered in Mueang Samut Prakan, Thailand. Thai Energy Storage Technology Public Company Limited is a subsidiary of Sustainable Battery Solutions, Inc.',
#  'city': 'Mueang Samut Prakan',
#  'phone': '66 2 709 3535',
#  'country': 'Thailand',
#  'companyOfficers': [],
#  'website': 'https://www.3kbattery.com',
#  'maxAge': 1,
#  'address1': '387, Moo 4, Sukhumvit Road',
#  'fax': '66 2 393 2509',
#  'industry': 'Electrical Equipment & Parts',
#  'address2': 'Phraek Sa Sub-district',
#  'ebitdaMargins': 0.06369,
#  'profitMargins': 0.0382,
#  'grossMargins': 0.19431,
#  'operatingCashflow': -402301248,
#  'revenueGrowth': 0.024,
# ...

# %%
from pandas_datareader import data as pdr

import yfinance as yf
yf.pdr_override() # <== that's all it takes :-)

# download dataframe
data = pdr.get_data_yahoo("SPY", start="2017-01-01", end="2017-04-30")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Raw Package
import numpy as np
import pandas as pd

#Data Source
import yfinance as yf

#Data viz
import plotly.graph_objs as go

#Interval required 1 minute
data = yf.download(tickers='UBER', period='1d', interval='1m')

#declare figure
fig = go.Figure()

#Candlestick
fig.add_trace(go.Candlestick(x=data.index,
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close'], name = 'market data'))

# Add titles
fig.update_layout(
    title='Uber live share price evolution',
    yaxis_title='Stock Price (USD per Shares)')

# X-Axes
fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=15, label="15m", step="minute", stepmode="backward"),
            dict(count=45, label="45m", step="minute", stepmode="backward"),
            dict(count=1, label="HTD", step="hour", stepmode="todate"),
            dict(count=3, label="3h", step="hour", stepmode="backward"),
            dict(step="all")
        ])
    )
)

#Show
fig.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#Interval required 5 minutes
Ticker = 'NKE'
data = yf.download(tickers=Ticker, period='5d', interval='1h')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
type(data)
data.to_csv("data.csv",mode='a')

# %%
import csv

# open the file in the write mode
f = open('data.csv', 'a')

# create the csv writer
writer = csv.writer(f)

# write a row to the csv file
writer.writerow([Ticker])
f.close()
data.to_csv("data.csv",mode='a')

# %%
#clear csv file
f = open('data.csv', 'w')

# create the csv writer
writer = csv.writer(f)

# write a row to the csv file
writer.writerow('')

# close the file
f.close()

# %%
#test ระบบ
import csv

# open the file in the write mode
with open('data.csv', 'a') as f:
    # create the csv writer
    writer = csv.writer(f)

    # write a row to the csv file
    writer.writerow([Ticker])

data.to_csv("data.csv",mode='a')

# %%
import csv
with open("test.csv",'r') as file:
    reader = csv.reader(file)
    for row in reader:
        if row[7] == 'GC=F':
            print(row[0])
# Out:
# 2021-12-26 18:00:00
# 2021-12-26 19:00:00
# 2021-12-26 20:00:00
# 2021-12-26 21:00:00
# 2021-12-26 22:00:00
# 2021-12-26 23:00:00
# 2021-12-27 00:00:00
# 2021-12-27 01:00:00
# 2021-12-27 02:00:00
# 2021-12-27 03:00:00
# 2021-12-27 04:00:00
# 2021-12-27 05:00:00
# 2021-12-27 06:00:00
# 2021-12-27 07:00:00
# 2021-12-27 08:00:00
# 2021-12-27 09:00:00
# 2021-12-27 10:00:00
# 2021-12-27 11:00:00
# 2021-12-27 12:00:00
# 2021-12-27 13:00:00
# 2021-12-27 14:00:00
# 2021-12-27 15:00:00
# 2021-12-27 16:00:00
# 2021-12-27 18:00:00
# 2021-12-27 19:00:00
# 2021-12-27 20:00:00
# 2021-12-27 21:00:00
# 2021-12-27 22:00:00
# 2021-12-27 23:00:00
# 2021-12-28 00:00:00
# 2021-12-28 01:00:00
# 2021-12-28 02:00:00
# 2021-12-28 03:00:00
# 2021-12-28 04:00:00
# 2021-12-28 05:00:00
# 2021-12-28 06:00:00
# 2021-12-28 07:00:00
# 2021-12-28 08:00:00
# 2021-12-28 09:00:00
# 2021-12-28 10:00:00
# 2021-12-28 11:00:00
# 2021-12-28 12:00:00
# 2021-12-28 13:00:00
# 2021-12-28 14:00:00
# 2021-12-28 15:00:00
# ...

# %%
#หลายๆตัว
TickerStrings = ['NKE','GC=F','SI=F']
df_list = list()
for ticker in TickerStrings:
    data = yf.download(tickers=ticker, period='1y', interval='1h')
    data['ticker'] = ticker
    df_list.append(data)

df = pd.concat(df_list)
df.to_csv('test.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
