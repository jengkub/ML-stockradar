# %%
# Raw Package
import numpy as np
import pandas as pd

#Data Source
import yfinance as yf

#Data viz
import plotly.graph_objs as go

# %%
#Interval required 5 minutes
data = yf.download(tickers='AOT.BK', period='5d', interval='1h')
#Print data
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                       Open   High    Low  Close  Adj Close    Volume
# Datetime
# 2022-12-15 10:00:00  74.25  74.25  73.75  73.75      73.75         0
# 2022-12-15 11:00:00  73.75  74.00  73.50  73.50      73.50   1904758
# 2022-12-15 12:00:00  73.50  73.75  73.50  73.50      73.50    421614
# 2022-12-15 14:00:00  73.75  74.00  73.50  73.50      73.50   3306730
# 2022-12-15 15:00:00  73.50  73.75  73.25  73.25      73.25  10441998
# 2022-12-15 16:00:00  73.25  73.50  73.25  73.25      73.25    609781
# 2022-12-16 10:00:00  73.00  73.75  73.00  73.75      73.75         0
# 2022-12-16 11:00:00  73.75  73.75  73.25  73.25      73.25   1271643
# 2022-12-16 12:00:00  73.50  73.50  73.25  73.25      73.25    702821
# 2022-12-16 14:00:00  73.25  73.50  73.25  73.50      73.50   1659795
# 2022-12-16 15:00:00  73.50  73.50  73.25  73.50      73.50   6450370
# 2022-12-16 16:00:00  73.50  73.50  73.25  73.50      73.50   1516769
# 2022-12-19 10:00:00  73.75  73.75  73.25  73.50      73.50         0
# 2022-12-19 11:00:00  73.50  73.75  73.25  73.75      73.75   1124194
# 2022-12-19 12:00:00  73.50  73.75  73.50  73.50      73.50    199046
# 2022-12-19 14:00:00  73.50  73.50  73.25  73.50      73.50   3211569
# 2022-12-19 15:00:00  73.50  73.50  73.25  73.25      73.25    386631
# 2022-12-19 16:00:00  73.50  73.75  73.25  73.75      73.75   1801626
# 2022-12-20 10:00:00  73.50  73.75  73.25  73.25      73.25         0
# 2022-12-20 11:00:00  73.25  73.50  73.00  73.25      73.25   4575630
# 2022-12-20 12:00:00  73.00  73.50  73.00  73.50      73.50    778861
# 2022-12-20 14:00:00  73.25  73.50  73.25  73.25      73.25    956688
# 2022-12-20 15:00:00  73.50  73.50  73.00  73.25      73.25   3888102
# 2022-12-20 16:00:00  73.25  73.50  73.25  73.50      73.50    617150
# 2022-12-21 10:00:00  73.75  73.75  72.75  73.00      73.00   6256785
# 2022-12-21 11:00:00  73.00  73.00  72.75  73.00      73.00    872946

# %%
msft = yf.Ticker("AOT.BK")
hist = msft.history(period="max")
msft.history_metadata
# Out:
# {'currency': 'THB',
#  'symbol': 'AOT.BK',
#  'exchangeName': 'SET',
#  'instrumentType': 'EQUITY',
#  'firstTradeDate': 1078974000,
#  'regularMarketTime': 1671596250,
#  'gmtoffset': 25200,
#  'timezone': 'ICT',
#  'exchangeTimezoneName': 'Asia/Bangkok',
#  'regularMarketPrice': 73.0,
#  'chartPreviousClose': 4.8,
#  'priceHint': 2,
#  'currentTradingPeriod': {'pre': {'timezone': 'ICT',
#    'end': 1671591600,
#    'start': 1671591600,
#    'gmtoffset': 25200},
#   'regular': {'timezone': 'ICT',
#    'end': 1671615000,
#    'start': 1671591600,
#    'gmtoffset': 25200},
#   'post': {'timezone': 'ICT',
#    'end': 1671615000,
#    'start': 1671615000,
#    'gmtoffset': 25200}},
#  'dataGranularity': '1d',
#  'range': '',
#  'validRanges': ['1d',
#   '5d',
#   '1mo',
#   '3mo',
#   '6mo',
#   '1y',
#   '2y',
#   '5y',
#   '10y',
#   'ytd',
#   'max']}

# %%
from pandas_datareader import data as pdr

import yfinance as yf
yf.pdr_override() # <== that's all it takes :-)

# download dataframe
data = pdr.get_data_yahoo("SPY", start="2017-01-01", end="2017-04-30")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Raw Package
import numpy as np
import pandas as pd

#Data Source
import yfinance as yf

#Data viz
import plotly.graph_objs as go

#Interval required 1 minute
data = yf.download(tickers='UBER', period='1d', interval='1m')

#declare figure
fig = go.Figure()

#Candlestick
fig.add_trace(go.Candlestick(x=data.index,
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close'], name = 'market data'))

# Add titles
fig.update_layout(
    title='Uber live share price evolution',
    yaxis_title='Stock Price (USD per Shares)')

# X-Axes
fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=15, label="15m", step="minute", stepmode="backward"),
            dict(count=45, label="45m", step="minute", stepmode="backward"),
            dict(count=1, label="HTD", step="hour", stepmode="todate"),
            dict(count=3, label="3h", step="hour", stepmode="backward"),
            dict(step="all")
        ])
    )
)

#Show
fig.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
